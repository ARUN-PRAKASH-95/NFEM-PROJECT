# %%
import numpy as np
import matplotlib.pyplot as plt

step = 0.01
t=np.arange(step,1,step)

poissons_ratio = 0.3
E = 0.1
mu = E/(2*(1+poissons_ratio))
Lambda=poissons_ratio*E/((1-2*poissons_ratio)*(1+poissons_ratio))
volumetric_strain = -0.01
yield_stress = 200e-6 #N/micromm^2

# Mesh generation
Inner_radius = 25
Outer_radius = 100
n=100
meshrefinementfactor = 5
q=meshrefinementfactor**(1/(n-1))

l=(Outer_radius-Inner_radius)*(1-q)/(1-meshrefinementfactor*q)
rnode=Inner_radius
coordinate=np.array([Inner_radius])

for i in range(n):
        rnode=rnode+l
        coordinate=np.append(coordinate,rnode)
        l=l*q



C = np.array([[Lambda+2*mu,Lambda,Lambda],
              [Lambda,Lambda+2*mu,Lambda],
              [Lambda,Lambda,Lambda+2*mu]])

#Tangent stiffness parameters
a=np.eye(3)
c=np.outer(a,a)
Kay = 3*Lambda+2*mu
b=np.eye(9)
d=np.zeros((9,9))
d[0,0]=1; d[1,3]=1;d[2,6]=1;d[3,1]=1;d[4,4]=1;d[5,7]=1;d[6,2]=1;d[7,5]=1;d[8,8]=1
I = (1/2*(b+d))-(1/3*c)


Global_F_ext = np.zeros((n+1,1))
Global_plastic_strain = np.zeros((n,3,1))
Global_displacement = np.zeros((n+1,1)) 
Reduced_displacement = np.delete(Global_displacement,(0),axis=0)
sigma_rr_ri = []
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
for time,tau in enumerate(t):
    Global_displacement[0]=1/3*tau*(-volumetric_strain)*Inner_radius
    print((time+1),''+'-'*100)
    delta_u = np.array([1,1])
    G_red = np.array([1,1])
    Global_F_int = np.array([1,1])
    plastic_strain = np.zeros((n,3,1))
    sigma_rr = np.zeros_like(coordinate)
    sigma_phi = np.zeros_like(coordinate)
   
    while np.linalg.norm(delta_u,np.inf)>(0.005*np.linalg.norm(Reduced_displacement,np.inf)) or np.linalg.norm(G_red,np.inf)>(0.005*np.linalg.norm(Global_F_int,np.inf)) :
        Global_K = np.zeros((n+1,n+1))
        Global_F_int= np.zeros((n+1,1))
        print("NEWT")
        for i in range(len(coordinate)-1):

            def element_routine(coordinate,Lambda,mu,tau):
                Derivative_N = np.array([-1/2,1/2])
                Jacobian = Derivative_N@np.array([[coordinate[i]],
                                                  [coordinate[i+1]]])
                J_inv = np.asscalar(1/Jacobian)

                B = np.array([[-1/2*J_inv,1/2*J_inv],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])]])
                B_T = np.transpose(B)
                C_matrix,I_stress = material_routine(coordinate)
                Element_stiffness = 2*(B_T@C_matrix@B)*Jacobian*((coordinate[i]+coordinate[i+1])/2)**2
                Internal_force = 2*(B_T@I_stress)*Jacobian*((coordinate[i]+coordinate[i+1])/2)**2
                return Element_stiffness,Internal_force
            


            def material_routine(coordinate):
                Derivative_N = np.array([-1/2,1/2])
                Jacobian = Derivative_N@np.array([[coordinate[i]],
                                                  [coordinate[i+1]]])
                J_inv = np.asscalar(1/Jacobian)

                B_matrix = np.array([[-1/2*J_inv,1/2*J_inv],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])]])
           
                Current_strain = B_matrix@np.array([Global_displacement[i],Global_displacement[i+1]]) 
                Trial_stress = C@(Current_strain - Global_plastic_strain[i])
                Trial_dev = Trial_stress - 1/3*np.sum(Trial_stress)
                Trial_eq = np.sqrt(3/2*(np.sum(np.square(Trial_dev))))
                dev_tensor = np.diagflat(Trial_dev)
                dev_outer = np.outer(dev_tensor,dev_tensor)

                if Trial_eq - yield_stress < 0:
                    sigma_rr[i]=np.asscalar(Trial_stress[0])
                    sigma_phi[i]= np.asscalar(Trial_stress[1])
                    print('ELASTIC',tau,i)
                    return C,Trial_stress
                else:
                    
                    del_lamda = (Trial_eq - yield_stress)/(3*mu)
                    print('PLASTIC',tau,i)
                    if i==1:
                        print('PLASTIC INITIATION----------------------------------------------------')
                    plastic_strain[i] = Global_plastic_strain[i] + del_lamda * 1.5 * (Trial_dev/Trial_eq)
                    new_stress = C@(Current_strain-plastic_strain[i])
                    sigma_rr[i]=np.asscalar(new_stress[0])
                    sigma_phi[i]= np.asscalar(new_stress[1])
                    new_dev = new_stress - 1/3*np.sum(new_stress)
                    new_eq = np.sqrt(3/2*(np.sum(np.square(new_dev))))
                    tangent_stiffness = Kay/3*(c)+2*mu*((Trial_eq-3*mu*del_lamda)/Trial_eq)*I-(3*mu*(1/Trial_eq**2)*dev_outer)
                    skip = tangent_stiffness[0::4]
                    C_t = skip[np.nonzero(skip)].reshape(3,3)
                    return C_t,new_stress

            Ke,Fe_int = element_routine(coordinate,Lambda,mu,tau)

            #Assignmnet matrix
            Ae = np.zeros((2,n+1))
            Ae[0,i]=1                                            # [0,n-1]=1 [1,n]=1
            Ae[1,i+1]  =1
            AeT = np.transpose(Ae)


            #Global stiffness matrix
            K=AeT@Ke@Ae                                          # Stiffness matrix  of each element after transformation
            Global_K = np.add(Global_K,K)  
            #Internal force
            F_int = AeT@Fe_int
            Global_F_int = np.add(Global_F_int,F_int)

        K_red = np.delete(Global_K,(0),axis=0)
        K_red = np.delete(K_red,(0),axis=1)

        #Newton Raphson method

        G_matrix = Global_F_int - Global_F_ext
        G_red = np.delete(G_matrix,(0),axis=0)
        delta_u = np.linalg.inv(K_red)@G_red
        Reduced_displacement = Reduced_displacement - delta_u
        Global_displacement = np.insert(Reduced_displacement,(0),(1/3*(tau)*(-volumetric_strain)*Inner_radius)).reshape(n+1,1)
        
    sigma_rr_ri.append(sigma_rr[0])
    Global_plastic_strain=plastic_strain
    
ax[0,0].plot(coordinate,sigma_rr)
ax[0,0].set_title('Sigma_rr Stress Plot',pad=20)
ax[0,0].set_xlabel('Radius')
ax[0,0].set_ylabel('Sigma_rr')
ax[0,1].plot(coordinate,Global_displacement)
ax[0,1].set_title('Displacement Plot')
ax[0,1].set_xlabel('Radius')
ax[0,1].set_ylabel('Displacement')
ax[1,0].plot(coordinate,sigma_phi)
ax[1,0].set_title('Sigma_phi Stress plot')
ax[1,0].set_xlabel('Radius')
ax[1,0].set_ylabel('Sigma_phi')
ax[1,1].plot(t,sigma_rr_ri)
ax[1,1].set_title('Stress at inner most node')
ax[1,1].set_xlabel('No of iterations')
ax[1,1].set_ylabel('sigma_rr_ri')
plt.tight_layout()
# plt.show()
plt.savefig('plots.png')
# Out:
# 1 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.01 0
# ELASTIC 0.01 1
# ELASTIC 0.01 2
# ELASTIC 0.01 3
# ELASTIC 0.01 4
# ELASTIC 0.01 5
# ELASTIC 0.01 6
# ELASTIC 0.01 7
# ELASTIC 0.01 8
# ELASTIC 0.01 9
# ELASTIC 0.01 10
# ELASTIC 0.01 11
# ELASTIC 0.01 12
# ELASTIC 0.01 13
# ELASTIC 0.01 14
# ELASTIC 0.01 15
# ELASTIC 0.01 16
# ELASTIC 0.01 17
# ELASTIC 0.01 18
# ELASTIC 0.01 19
# ELASTIC 0.01 20
# ELASTIC 0.01 21
# ELASTIC 0.01 22
# ELASTIC 0.01 23
# ELASTIC 0.01 24
# ELASTIC 0.01 25
# ELASTIC 0.01 26
# ELASTIC 0.01 27
# ELASTIC 0.01 28
# ELASTIC 0.01 29
# ELASTIC 0.01 30
# ELASTIC 0.01 31
# ELASTIC 0.01 32
# ELASTIC 0.01 33
# ELASTIC 0.01 34
# ELASTIC 0.01 35
# ELASTIC 0.01 36
# ELASTIC 0.01 37
# ELASTIC 0.01 38
# ELASTIC 0.01 39
# ELASTIC 0.01 40
# ELASTIC 0.01 41
# ELASTIC 0.01 42
# ELASTIC 0.01 43
# ELASTIC 0.01 44
# ELASTIC 0.01 45
# ELASTIC 0.01 46
# ELASTIC 0.01 47
# ELASTIC 0.01 48
# ELASTIC 0.01 49
# ELASTIC 0.01 50
# ELASTIC 0.01 51
# ELASTIC 0.01 52
# ELASTIC 0.01 53
# ELASTIC 0.01 54
# ELASTIC 0.01 55
# ELASTIC 0.01 56
# ELASTIC 0.01 57
# ELASTIC 0.01 58
# ELASTIC 0.01 59
# ELASTIC 0.01 60
# ELASTIC 0.01 61
# ELASTIC 0.01 62
# ELASTIC 0.01 63
# ELASTIC 0.01 64
# ELASTIC 0.01 65
# ELASTIC 0.01 66
# ELASTIC 0.01 67
# ELASTIC 0.01 68
# ELASTIC 0.01 69
# ELASTIC 0.01 70
# ELASTIC 0.01 71
# ELASTIC 0.01 72
# ELASTIC 0.01 73
# ELASTIC 0.01 74
# ELASTIC 0.01 75
# ELASTIC 0.01 76
# ELASTIC 0.01 77
# ELASTIC 0.01 78
# ELASTIC 0.01 79
# ELASTIC 0.01 80
# ELASTIC 0.01 81
# ELASTIC 0.01 82
# ELASTIC 0.01 83
# ELASTIC 0.01 84
# ELASTIC 0.01 85
# ELASTIC 0.01 86
# ELASTIC 0.01 87
# ELASTIC 0.01 88
# ELASTIC 0.01 89
# ELASTIC 0.01 90
# ELASTIC 0.01 91
# ELASTIC 0.01 92
# ELASTIC 0.01 93
# ELASTIC 0.01 94
# ELASTIC 0.01 95
# ELASTIC 0.01 96
# ELASTIC 0.01 97
# ELASTIC 0.01 98
# ELASTIC 0.01 99
# NEWT
# ELASTIC 0.01 0
# ELASTIC 0.01 1
# ELASTIC 0.01 2
# ELASTIC 0.01 3
# ELASTIC 0.01 4
# ELASTIC 0.01 5
# ELASTIC 0.01 6
# ELASTIC 0.01 7
# ELASTIC 0.01 8
# ELASTIC 0.01 9
# ELASTIC 0.01 10
# ELASTIC 0.01 11
# ELASTIC 0.01 12
# ELASTIC 0.01 13
# ELASTIC 0.01 14
# ELASTIC 0.01 15
# ELASTIC 0.01 16
# ELASTIC 0.01 17
# ELASTIC 0.01 18
# ELASTIC 0.01 19
# ELASTIC 0.01 20
# ELASTIC 0.01 21
# ELASTIC 0.01 22
# ELASTIC 0.01 23
# ELASTIC 0.01 24
# ELASTIC 0.01 25
# ELASTIC 0.01 26
# ELASTIC 0.01 27
# ELASTIC 0.01 28
# ELASTIC 0.01 29
# ELASTIC 0.01 30
# ELASTIC 0.01 31
# ELASTIC 0.01 32
# ELASTIC 0.01 33
# ELASTIC 0.01 34
# ELASTIC 0.01 35
# ELASTIC 0.01 36
# ELASTIC 0.01 37
# ELASTIC 0.01 38
# ELASTIC 0.01 39
# ELASTIC 0.01 40
# ELASTIC 0.01 41
# ELASTIC 0.01 42
# ELASTIC 0.01 43
# ELASTIC 0.01 44
# ELASTIC 0.01 45
# ELASTIC 0.01 46
# ELASTIC 0.01 47
# ELASTIC 0.01 48
# ELASTIC 0.01 49
# ELASTIC 0.01 50
# ELASTIC 0.01 51
# ELASTIC 0.01 52
# ELASTIC 0.01 53
# ELASTIC 0.01 54
# ELASTIC 0.01 55
# ELASTIC 0.01 56
# ELASTIC 0.01 57
# ELASTIC 0.01 58
# ELASTIC 0.01 59
# ELASTIC 0.01 60
# ELASTIC 0.01 61
# ELASTIC 0.01 62
# ELASTIC 0.01 63
# ELASTIC 0.01 64
# ELASTIC 0.01 65
# ELASTIC 0.01 66
# ELASTIC 0.01 67
# ELASTIC 0.01 68
# ELASTIC 0.01 69
# ELASTIC 0.01 70
# ELASTIC 0.01 71
# ELASTIC 0.01 72
# ELASTIC 0.01 73
# ELASTIC 0.01 74
# ELASTIC 0.01 75
# ELASTIC 0.01 76
# ELASTIC 0.01 77
# ELASTIC 0.01 78
# ELASTIC 0.01 79
# ELASTIC 0.01 80
# ELASTIC 0.01 81
# ELASTIC 0.01 82
# ELASTIC 0.01 83
# ELASTIC 0.01 84
# ELASTIC 0.01 85
# ELASTIC 0.01 86
# ELASTIC 0.01 87
# ELASTIC 0.01 88
# ELASTIC 0.01 89
# ELASTIC 0.01 90
# ELASTIC 0.01 91
# ELASTIC 0.01 92
# ELASTIC 0.01 93
# ELASTIC 0.01 94
# ELASTIC 0.01 95
# ELASTIC 0.01 96
# ELASTIC 0.01 97
# ELASTIC 0.01 98
# ELASTIC 0.01 99
# NEWT
# ELASTIC 0.01 0
# ELASTIC 0.01 1
# ELASTIC 0.01 2
# ELASTIC 0.01 3
# ELASTIC 0.01 4
# ELASTIC 0.01 5
# ELASTIC 0.01 6
# ELASTIC 0.01 7
# ELASTIC 0.01 8
# ELASTIC 0.01 9
# ELASTIC 0.01 10
# ELASTIC 0.01 11
# ELASTIC 0.01 12
# ELASTIC 0.01 13
# ELASTIC 0.01 14
# ELASTIC 0.01 15
# ELASTIC 0.01 16
# ELASTIC 0.01 17
# ELASTIC 0.01 18
# ELASTIC 0.01 19
# ELASTIC 0.01 20
# ELASTIC 0.01 21
# ELASTIC 0.01 22
# ELASTIC 0.01 23
# ELASTIC 0.01 24
# ELASTIC 0.01 25
# ELASTIC 0.01 26
# ELASTIC 0.01 27
# ELASTIC 0.01 28
# ELASTIC 0.01 29
# ELASTIC 0.01 30
# ELASTIC 0.01 31
# ELASTIC 0.01 32
# ELASTIC 0.01 33
# ELASTIC 0.01 34
# ELASTIC 0.01 35
# ELASTIC 0.01 36
# ELASTIC 0.01 37
# ELASTIC 0.01 38
# ELASTIC 0.01 39
# ELASTIC 0.01 40
# ELASTIC 0.01 41
# ELASTIC 0.01 42
# ELASTIC 0.01 43
# ELASTIC 0.01 44
# ELASTIC 0.01 45
# ELASTIC 0.01 46
# ELASTIC 0.01 47
# ELASTIC 0.01 48
# ELASTIC 0.01 49
# ELASTIC 0.01 50
# ELASTIC 0.01 51
# ELASTIC 0.01 52
# ELASTIC 0.01 53
# ELASTIC 0.01 54
# ELASTIC 0.01 55
# ELASTIC 0.01 56
# ELASTIC 0.01 57
# ELASTIC 0.01 58
# ELASTIC 0.01 59
# ELASTIC 0.01 60
# ELASTIC 0.01 61
# ELASTIC 0.01 62
# ELASTIC 0.01 63
# ELASTIC 0.01 64
# ELASTIC 0.01 65
# ELASTIC 0.01 66
# ELASTIC 0.01 67
# ELASTIC 0.01 68
# ELASTIC 0.01 69
# ELASTIC 0.01 70
# ELASTIC 0.01 71
# ELASTIC 0.01 72
# ELASTIC 0.01 73
# ELASTIC 0.01 74
# ELASTIC 0.01 75
# ELASTIC 0.01 76
# ELASTIC 0.01 77
# ELASTIC 0.01 78
# ELASTIC 0.01 79
# ELASTIC 0.01 80
# ELASTIC 0.01 81
# ELASTIC 0.01 82
# ELASTIC 0.01 83
# ELASTIC 0.01 84
# ELASTIC 0.01 85
# ELASTIC 0.01 86
# ELASTIC 0.01 87
# ELASTIC 0.01 88
# ELASTIC 0.01 89
# ELASTIC 0.01 90
# ELASTIC 0.01 91
# ELASTIC 0.01 92
# ELASTIC 0.01 93
# ELASTIC 0.01 94
# ELASTIC 0.01 95
# ELASTIC 0.01 96
# ELASTIC 0.01 97
# ELASTIC 0.01 98
# ELASTIC 0.01 99
# 2 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.02 0
# ELASTIC 0.02 1
# ELASTIC 0.02 2
# ELASTIC 0.02 3
# ELASTIC 0.02 4
# ELASTIC 0.02 5
# ELASTIC 0.02 6
# ELASTIC 0.02 7
# ELASTIC 0.02 8
# ELASTIC 0.02 9
# ELASTIC 0.02 10
# ELASTIC 0.02 11
# ELASTIC 0.02 12
# ELASTIC 0.02 13
# ELASTIC 0.02 14
# ELASTIC 0.02 15
# ELASTIC 0.02 16
# ELASTIC 0.02 17
# ELASTIC 0.02 18
# ELASTIC 0.02 19
# ELASTIC 0.02 20
# ELASTIC 0.02 21
# ELASTIC 0.02 22
# ELASTIC 0.02 23
# ELASTIC 0.02 24
# ELASTIC 0.02 25
# ELASTIC 0.02 26
# ELASTIC 0.02 27
# ELASTIC 0.02 28
# ELASTIC 0.02 29
# ELASTIC 0.02 30
# ELASTIC 0.02 31
# ELASTIC 0.02 32
# ELASTIC 0.02 33
# ELASTIC 0.02 34
# ELASTIC 0.02 35
# ELASTIC 0.02 36
# ELASTIC 0.02 37
# ELASTIC 0.02 38
# ELASTIC 0.02 39
# ELASTIC 0.02 40
# ELASTIC 0.02 41
# ELASTIC 0.02 42
# ELASTIC 0.02 43
# ELASTIC 0.02 44
# ELASTIC 0.02 45
# ELASTIC 0.02 46
# ELASTIC 0.02 47
# ELASTIC 0.02 48
# ELASTIC 0.02 49
# ELASTIC 0.02 50
# ELASTIC 0.02 51
# ELASTIC 0.02 52
# ELASTIC 0.02 53
# ELASTIC 0.02 54
# ELASTIC 0.02 55
# ELASTIC 0.02 56
# ELASTIC 0.02 57
# ELASTIC 0.02 58
# ELASTIC 0.02 59
# ELASTIC 0.02 60
# ELASTIC 0.02 61
# ELASTIC 0.02 62
# ELASTIC 0.02 63
# ELASTIC 0.02 64
# ELASTIC 0.02 65
# ELASTIC 0.02 66
# ELASTIC 0.02 67
# ELASTIC 0.02 68
# ELASTIC 0.02 69
# ELASTIC 0.02 70
# ELASTIC 0.02 71
# ELASTIC 0.02 72
# ELASTIC 0.02 73
# ELASTIC 0.02 74
# ELASTIC 0.02 75
# ELASTIC 0.02 76
# ELASTIC 0.02 77
# ELASTIC 0.02 78
# ELASTIC 0.02 79
# ELASTIC 0.02 80
# ELASTIC 0.02 81
# ELASTIC 0.02 82
# ELASTIC 0.02 83
# ELASTIC 0.02 84
# ELASTIC 0.02 85
# ELASTIC 0.02 86
# ELASTIC 0.02 87
# ELASTIC 0.02 88
# ELASTIC 0.02 89
# ELASTIC 0.02 90
# ELASTIC 0.02 91
# ELASTIC 0.02 92
# ELASTIC 0.02 93
# ELASTIC 0.02 94
# ELASTIC 0.02 95
# ELASTIC 0.02 96
# ELASTIC 0.02 97
# ELASTIC 0.02 98
# ELASTIC 0.02 99
# NEWT
# ELASTIC 0.02 0
# ELASTIC 0.02 1
# ELASTIC 0.02 2
# ELASTIC 0.02 3
# ELASTIC 0.02 4
# ELASTIC 0.02 5
# ELASTIC 0.02 6
# ELASTIC 0.02 7
# ELASTIC 0.02 8
# ELASTIC 0.02 9
# ELASTIC 0.02 10
# ELASTIC 0.02 11
# ELASTIC 0.02 12
# ELASTIC 0.02 13
# ELASTIC 0.02 14
# ELASTIC 0.02 15
# ELASTIC 0.02 16
# ELASTIC 0.02 17
# ELASTIC 0.02 18
# ELASTIC 0.02 19
# ELASTIC 0.02 20
# ELASTIC 0.02 21
# ELASTIC 0.02 22
# ELASTIC 0.02 23
# ELASTIC 0.02 24
# ELASTIC 0.02 25
# ELASTIC 0.02 26
# ELASTIC 0.02 27
# ELASTIC 0.02 28
# ELASTIC 0.02 29
# ELASTIC 0.02 30
# ELASTIC 0.02 31
# ELASTIC 0.02 32
# ELASTIC 0.02 33
# ELASTIC 0.02 34
# ELASTIC 0.02 35
# ELASTIC 0.02 36
# ELASTIC 0.02 37
# ELASTIC 0.02 38
# ELASTIC 0.02 39
# ELASTIC 0.02 40
# ELASTIC 0.02 41
# ELASTIC 0.02 42
# ELASTIC 0.02 43
# ELASTIC 0.02 44
# ELASTIC 0.02 45
# ELASTIC 0.02 46
# ELASTIC 0.02 47
# ELASTIC 0.02 48
# ELASTIC 0.02 49
# ELASTIC 0.02 50
# ELASTIC 0.02 51
# ELASTIC 0.02 52
# ELASTIC 0.02 53
# ELASTIC 0.02 54
# ELASTIC 0.02 55
# ELASTIC 0.02 56
# ELASTIC 0.02 57
# ELASTIC 0.02 58
# ELASTIC 0.02 59
# ELASTIC 0.02 60
# ELASTIC 0.02 61
# ELASTIC 0.02 62
# ELASTIC 0.02 63
# ELASTIC 0.02 64
# ELASTIC 0.02 65
# ELASTIC 0.02 66
# ELASTIC 0.02 67
# ELASTIC 0.02 68
# ELASTIC 0.02 69
# ELASTIC 0.02 70
# ELASTIC 0.02 71
# ELASTIC 0.02 72
# ELASTIC 0.02 73
# ELASTIC 0.02 74
# ELASTIC 0.02 75
# ELASTIC 0.02 76
# ELASTIC 0.02 77
# ELASTIC 0.02 78
# ELASTIC 0.02 79
# ELASTIC 0.02 80
# ELASTIC 0.02 81
# ELASTIC 0.02 82
# ELASTIC 0.02 83
# ELASTIC 0.02 84
# ELASTIC 0.02 85
# ELASTIC 0.02 86
# ELASTIC 0.02 87
# ELASTIC 0.02 88
# ELASTIC 0.02 89
# ELASTIC 0.02 90
# ELASTIC 0.02 91
# ELASTIC 0.02 92
# ELASTIC 0.02 93
# ELASTIC 0.02 94
# ELASTIC 0.02 95
# ELASTIC 0.02 96
# ELASTIC 0.02 97
# ELASTIC 0.02 98
# ELASTIC 0.02 99
# NEWT
# ELASTIC 0.02 0
# ELASTIC 0.02 1
# ELASTIC 0.02 2
# ELASTIC 0.02 3
# ELASTIC 0.02 4
# ELASTIC 0.02 5
# ELASTIC 0.02 6
# ELASTIC 0.02 7
# ELASTIC 0.02 8
# ELASTIC 0.02 9
# ELASTIC 0.02 10
# ELASTIC 0.02 11
# ELASTIC 0.02 12
# ELASTIC 0.02 13
# ELASTIC 0.02 14
# ELASTIC 0.02 15
# ELASTIC 0.02 16
# ELASTIC 0.02 17
# ELASTIC 0.02 18
# ELASTIC 0.02 19
# ELASTIC 0.02 20
# ELASTIC 0.02 21
# ELASTIC 0.02 22
# ELASTIC 0.02 23
# ELASTIC 0.02 24
# ELASTIC 0.02 25
# ELASTIC 0.02 26
# ELASTIC 0.02 27
# ELASTIC 0.02 28
# ELASTIC 0.02 29
# ELASTIC 0.02 30
# ELASTIC 0.02 31
# ELASTIC 0.02 32
# ELASTIC 0.02 33
# ELASTIC 0.02 34
# ELASTIC 0.02 35
# ELASTIC 0.02 36
# ELASTIC 0.02 37
# ELASTIC 0.02 38
# ELASTIC 0.02 39
# ELASTIC 0.02 40
# ELASTIC 0.02 41
# ELASTIC 0.02 42
# ELASTIC 0.02 43
# ELASTIC 0.02 44
# ELASTIC 0.02 45
# ELASTIC 0.02 46
# ELASTIC 0.02 47
# ELASTIC 0.02 48
# ELASTIC 0.02 49
# ELASTIC 0.02 50
# ELASTIC 0.02 51
# ELASTIC 0.02 52
# ELASTIC 0.02 53
# ELASTIC 0.02 54
# ELASTIC 0.02 55
# ELASTIC 0.02 56
# ELASTIC 0.02 57
# ELASTIC 0.02 58
# ELASTIC 0.02 59
# ELASTIC 0.02 60
# ELASTIC 0.02 61
# ELASTIC 0.02 62
# ELASTIC 0.02 63
# ELASTIC 0.02 64
# ELASTIC 0.02 65
# ELASTIC 0.02 66
# ELASTIC 0.02 67
# ELASTIC 0.02 68
# ELASTIC 0.02 69
# ELASTIC 0.02 70
# ELASTIC 0.02 71
# ELASTIC 0.02 72
# ELASTIC 0.02 73
# ELASTIC 0.02 74
# ELASTIC 0.02 75
# ELASTIC 0.02 76
# ELASTIC 0.02 77
# ELASTIC 0.02 78
# ELASTIC 0.02 79
# ELASTIC 0.02 80
# ELASTIC 0.02 81
# ELASTIC 0.02 82
# ELASTIC 0.02 83
# ELASTIC 0.02 84
# ELASTIC 0.02 85
# ELASTIC 0.02 86
# ELASTIC 0.02 87
# ELASTIC 0.02 88
# ELASTIC 0.02 89
# ELASTIC 0.02 90
# ELASTIC 0.02 91
# ELASTIC 0.02 92
# ELASTIC 0.02 93
# ELASTIC 0.02 94
# ELASTIC 0.02 95
# ELASTIC 0.02 96
# ELASTIC 0.02 97
# ELASTIC 0.02 98
# ELASTIC 0.02 99
# 3 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.03 0
# ELASTIC 0.03 1
# ELASTIC 0.03 2
# ELASTIC 0.03 3
# ELASTIC 0.03 4
# ELASTIC 0.03 5
# ELASTIC 0.03 6
# ELASTIC 0.03 7
# ELASTIC 0.03 8
# ELASTIC 0.03 9
# ELASTIC 0.03 10
# ELASTIC 0.03 11
# ELASTIC 0.03 12
# ELASTIC 0.03 13
# ELASTIC 0.03 14
# ELASTIC 0.03 15
# ELASTIC 0.03 16
# ELASTIC 0.03 17
# ELASTIC 0.03 18
# ELASTIC 0.03 19
# ELASTIC 0.03 20
# ELASTIC 0.03 21
# ELASTIC 0.03 22
# ELASTIC 0.03 23
# ELASTIC 0.03 24
# ELASTIC 0.03 25
# ELASTIC 0.03 26
# ELASTIC 0.03 27
# ELASTIC 0.03 28
# ELASTIC 0.03 29
# ELASTIC 0.03 30
# ELASTIC 0.03 31
# ELASTIC 0.03 32
# ELASTIC 0.03 33
# ELASTIC 0.03 34
# ELASTIC 0.03 35
# ELASTIC 0.03 36
# ELASTIC 0.03 37
# ELASTIC 0.03 38
# ELASTIC 0.03 39
# ELASTIC 0.03 40
# ELASTIC 0.03 41
# ELASTIC 0.03 42
# ELASTIC 0.03 43
# ELASTIC 0.03 44
# ELASTIC 0.03 45
# ELASTIC 0.03 46
# ELASTIC 0.03 47
# ELASTIC 0.03 48
# ELASTIC 0.03 49
# ELASTIC 0.03 50
# ELASTIC 0.03 51
# ELASTIC 0.03 52
# ELASTIC 0.03 53
# ELASTIC 0.03 54
# ELASTIC 0.03 55
# ELASTIC 0.03 56
# ELASTIC 0.03 57
# ELASTIC 0.03 58
# ELASTIC 0.03 59
# ELASTIC 0.03 60
# ELASTIC 0.03 61
# ELASTIC 0.03 62
# ELASTIC 0.03 63
# ELASTIC 0.03 64
# ELASTIC 0.03 65
# ELASTIC 0.03 66
# ELASTIC 0.03 67
# ELASTIC 0.03 68
# ELASTIC 0.03 69
# ELASTIC 0.03 70
# ELASTIC 0.03 71
# ELASTIC 0.03 72
# ELASTIC 0.03 73
# ELASTIC 0.03 74
# ELASTIC 0.03 75
# ELASTIC 0.03 76
# ELASTIC 0.03 77
# ELASTIC 0.03 78
# ELASTIC 0.03 79
# ELASTIC 0.03 80
# ELASTIC 0.03 81
# ELASTIC 0.03 82
# ELASTIC 0.03 83
# ELASTIC 0.03 84
# ELASTIC 0.03 85
# ELASTIC 0.03 86
# ELASTIC 0.03 87
# ELASTIC 0.03 88
# ELASTIC 0.03 89
# ELASTIC 0.03 90
# ELASTIC 0.03 91
# ELASTIC 0.03 92
# ELASTIC 0.03 93
# ELASTIC 0.03 94
# ELASTIC 0.03 95
# ELASTIC 0.03 96
# ELASTIC 0.03 97
# ELASTIC 0.03 98
# ELASTIC 0.03 99
# NEWT
# ELASTIC 0.03 0
# ELASTIC 0.03 1
# ELASTIC 0.03 2
# ELASTIC 0.03 3
# ELASTIC 0.03 4
# ELASTIC 0.03 5
# ELASTIC 0.03 6
# ELASTIC 0.03 7
# ELASTIC 0.03 8
# ELASTIC 0.03 9
# ELASTIC 0.03 10
# ELASTIC 0.03 11
# ELASTIC 0.03 12
# ELASTIC 0.03 13
# ELASTIC 0.03 14
# ELASTIC 0.03 15
# ELASTIC 0.03 16
# ELASTIC 0.03 17
# ELASTIC 0.03 18
# ELASTIC 0.03 19
# ELASTIC 0.03 20
# ELASTIC 0.03 21
# ELASTIC 0.03 22
# ELASTIC 0.03 23
# ELASTIC 0.03 24
# ELASTIC 0.03 25
# ELASTIC 0.03 26
# ELASTIC 0.03 27
# ELASTIC 0.03 28
# ELASTIC 0.03 29
# ELASTIC 0.03 30
# ELASTIC 0.03 31
# ELASTIC 0.03 32
# ELASTIC 0.03 33
# ELASTIC 0.03 34
# ELASTIC 0.03 35
# ELASTIC 0.03 36
# ELASTIC 0.03 37
# ELASTIC 0.03 38
# ELASTIC 0.03 39
# ELASTIC 0.03 40
# ELASTIC 0.03 41
# ELASTIC 0.03 42
# ELASTIC 0.03 43
# ELASTIC 0.03 44
# ELASTIC 0.03 45
# ELASTIC 0.03 46
# ELASTIC 0.03 47
# ELASTIC 0.03 48
# ELASTIC 0.03 49
# ELASTIC 0.03 50
# ELASTIC 0.03 51
# ELASTIC 0.03 52
# ELASTIC 0.03 53
# ELASTIC 0.03 54
# ELASTIC 0.03 55
# ELASTIC 0.03 56
# ELASTIC 0.03 57
# ELASTIC 0.03 58
# ELASTIC 0.03 59
# ELASTIC 0.03 60
# ELASTIC 0.03 61
# ELASTIC 0.03 62
# ELASTIC 0.03 63
# ELASTIC 0.03 64
# ELASTIC 0.03 65
# ELASTIC 0.03 66
# ELASTIC 0.03 67
# ELASTIC 0.03 68
# ELASTIC 0.03 69
# ELASTIC 0.03 70
# ELASTIC 0.03 71
# ELASTIC 0.03 72
# ELASTIC 0.03 73
# ELASTIC 0.03 74
# ELASTIC 0.03 75
# ELASTIC 0.03 76
# ELASTIC 0.03 77
# ELASTIC 0.03 78
# ELASTIC 0.03 79
# ELASTIC 0.03 80
# ELASTIC 0.03 81
# ELASTIC 0.03 82
# ELASTIC 0.03 83
# ELASTIC 0.03 84
# ELASTIC 0.03 85
# ELASTIC 0.03 86
# ELASTIC 0.03 87
# ELASTIC 0.03 88
# ELASTIC 0.03 89
# ELASTIC 0.03 90
# ELASTIC 0.03 91
# ELASTIC 0.03 92
# ELASTIC 0.03 93
# ELASTIC 0.03 94
# ELASTIC 0.03 95
# ELASTIC 0.03 96
# ELASTIC 0.03 97
# ELASTIC 0.03 98
# ELASTIC 0.03 99
# NEWT
# ELASTIC 0.03 0
# ELASTIC 0.03 1
# ELASTIC 0.03 2
# ELASTIC 0.03 3
# ELASTIC 0.03 4
# ELASTIC 0.03 5
# ELASTIC 0.03 6
# ELASTIC 0.03 7
# ELASTIC 0.03 8
# ELASTIC 0.03 9
# ELASTIC 0.03 10
# ELASTIC 0.03 11
# ELASTIC 0.03 12
# ELASTIC 0.03 13
# ELASTIC 0.03 14
# ELASTIC 0.03 15
# ELASTIC 0.03 16
# ELASTIC 0.03 17
# ELASTIC 0.03 18
# ELASTIC 0.03 19
# ELASTIC 0.03 20
# ELASTIC 0.03 21
# ELASTIC 0.03 22
# ELASTIC 0.03 23
# ELASTIC 0.03 24
# ELASTIC 0.03 25
# ELASTIC 0.03 26
# ELASTIC 0.03 27
# ELASTIC 0.03 28
# ELASTIC 0.03 29
# ELASTIC 0.03 30
# ELASTIC 0.03 31
# ELASTIC 0.03 32
# ELASTIC 0.03 33
# ELASTIC 0.03 34
# ELASTIC 0.03 35
# ELASTIC 0.03 36
# ELASTIC 0.03 37
# ELASTIC 0.03 38
# ELASTIC 0.03 39
# ELASTIC 0.03 40
# ELASTIC 0.03 41
# ELASTIC 0.03 42
# ELASTIC 0.03 43
# ELASTIC 0.03 44
# ELASTIC 0.03 45
# ELASTIC 0.03 46
# ELASTIC 0.03 47
# ELASTIC 0.03 48
# ELASTIC 0.03 49
# ELASTIC 0.03 50
# ELASTIC 0.03 51
# ELASTIC 0.03 52
# ELASTIC 0.03 53
# ELASTIC 0.03 54
# ELASTIC 0.03 55
# ELASTIC 0.03 56
# ELASTIC 0.03 57
# ELASTIC 0.03 58
# ELASTIC 0.03 59
# ELASTIC 0.03 60
# ELASTIC 0.03 61
# ELASTIC 0.03 62
# ELASTIC 0.03 63
# ELASTIC 0.03 64
# ELASTIC 0.03 65
# ELASTIC 0.03 66
# ELASTIC 0.03 67
# ELASTIC 0.03 68
# ELASTIC 0.03 69
# ELASTIC 0.03 70
# ELASTIC 0.03 71
# ELASTIC 0.03 72
# ELASTIC 0.03 73
# ELASTIC 0.03 74
# ELASTIC 0.03 75
# ELASTIC 0.03 76
# ELASTIC 0.03 77
# ELASTIC 0.03 78
# ELASTIC 0.03 79
# ELASTIC 0.03 80
# ELASTIC 0.03 81
# ELASTIC 0.03 82
# ELASTIC 0.03 83
# ELASTIC 0.03 84
# ELASTIC 0.03 85
# ELASTIC 0.03 86
# ELASTIC 0.03 87
# ELASTIC 0.03 88
# ELASTIC 0.03 89
# ELASTIC 0.03 90
# ELASTIC 0.03 91
# ELASTIC 0.03 92
# ELASTIC 0.03 93
# ELASTIC 0.03 94
# ELASTIC 0.03 95
# ELASTIC 0.03 96
# ELASTIC 0.03 97
# ELASTIC 0.03 98
# ELASTIC 0.03 99
# 4 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.04 0
# ELASTIC 0.04 1
# ELASTIC 0.04 2
# ELASTIC 0.04 3
# ELASTIC 0.04 4
# ELASTIC 0.04 5
# ELASTIC 0.04 6
# ELASTIC 0.04 7
# ELASTIC 0.04 8
# ELASTIC 0.04 9
# ELASTIC 0.04 10
# ELASTIC 0.04 11
# ELASTIC 0.04 12
# ELASTIC 0.04 13
# ELASTIC 0.04 14
# ELASTIC 0.04 15
# ELASTIC 0.04 16
# ELASTIC 0.04 17
# ELASTIC 0.04 18
# ELASTIC 0.04 19
# ELASTIC 0.04 20
# ELASTIC 0.04 21
# ELASTIC 0.04 22
# ELASTIC 0.04 23
# ELASTIC 0.04 24
# ELASTIC 0.04 25
# ELASTIC 0.04 26
# ELASTIC 0.04 27
# ELASTIC 0.04 28
# ELASTIC 0.04 29
# ELASTIC 0.04 30
# ELASTIC 0.04 31
# ELASTIC 0.04 32
# ELASTIC 0.04 33
# ELASTIC 0.04 34
# ELASTIC 0.04 35
# ELASTIC 0.04 36
# ELASTIC 0.04 37
# ELASTIC 0.04 38
# ELASTIC 0.04 39
# ELASTIC 0.04 40
# ELASTIC 0.04 41
# ELASTIC 0.04 42
# ELASTIC 0.04 43
# ELASTIC 0.04 44
# ELASTIC 0.04 45
# ELASTIC 0.04 46
# ELASTIC 0.04 47
# ELASTIC 0.04 48
# ELASTIC 0.04 49
# ELASTIC 0.04 50
# ELASTIC 0.04 51
# ELASTIC 0.04 52
# ELASTIC 0.04 53
# ELASTIC 0.04 54
# ELASTIC 0.04 55
# ELASTIC 0.04 56
# ELASTIC 0.04 57
# ELASTIC 0.04 58
# ELASTIC 0.04 59
# ELASTIC 0.04 60
# ELASTIC 0.04 61
# ELASTIC 0.04 62
# ELASTIC 0.04 63
# ELASTIC 0.04 64
# ELASTIC 0.04 65
# ELASTIC 0.04 66
# ELASTIC 0.04 67
# ELASTIC 0.04 68
# ELASTIC 0.04 69
# ELASTIC 0.04 70
# ELASTIC 0.04 71
# ELASTIC 0.04 72
# ELASTIC 0.04 73
# ELASTIC 0.04 74
# ELASTIC 0.04 75
# ELASTIC 0.04 76
# ELASTIC 0.04 77
# ELASTIC 0.04 78
# ELASTIC 0.04 79
# ELASTIC 0.04 80
# ELASTIC 0.04 81
# ELASTIC 0.04 82
# ELASTIC 0.04 83
# ELASTIC 0.04 84
# ELASTIC 0.04 85
# ELASTIC 0.04 86
# ELASTIC 0.04 87
# ELASTIC 0.04 88
# ELASTIC 0.04 89
# ELASTIC 0.04 90
# ELASTIC 0.04 91
# ELASTIC 0.04 92
# ELASTIC 0.04 93
# ELASTIC 0.04 94
# ELASTIC 0.04 95
# ELASTIC 0.04 96
# ELASTIC 0.04 97
# ELASTIC 0.04 98
# ELASTIC 0.04 99
# NEWT
# ELASTIC 0.04 0
# ELASTIC 0.04 1
# ELASTIC 0.04 2
# ELASTIC 0.04 3
# ELASTIC 0.04 4
# ELASTIC 0.04 5
# ELASTIC 0.04 6
# ELASTIC 0.04 7
# ELASTIC 0.04 8
# ELASTIC 0.04 9
# ELASTIC 0.04 10
# ELASTIC 0.04 11
# ELASTIC 0.04 12
# ELASTIC 0.04 13
# ELASTIC 0.04 14
# ELASTIC 0.04 15
# ELASTIC 0.04 16
# ELASTIC 0.04 17
# ELASTIC 0.04 18
# ELASTIC 0.04 19
# ELASTIC 0.04 20
# ELASTIC 0.04 21
# ELASTIC 0.04 22
# ELASTIC 0.04 23
# ELASTIC 0.04 24
# ELASTIC 0.04 25
# ELASTIC 0.04 26
# ELASTIC 0.04 27
# ELASTIC 0.04 28
# ELASTIC 0.04 29
# ELASTIC 0.04 30
# ELASTIC 0.04 31
# ELASTIC 0.04 32
# ELASTIC 0.04 33
# ELASTIC 0.04 34
# ELASTIC 0.04 35
# ELASTIC 0.04 36
# ELASTIC 0.04 37
# ELASTIC 0.04 38
# ELASTIC 0.04 39
# ELASTIC 0.04 40
# ELASTIC 0.04 41
# ELASTIC 0.04 42
# ELASTIC 0.04 43
# ELASTIC 0.04 44
# ELASTIC 0.04 45
# ELASTIC 0.04 46
# ELASTIC 0.04 47
# ELASTIC 0.04 48
# ELASTIC 0.04 49
# ELASTIC 0.04 50
# ELASTIC 0.04 51
# ELASTIC 0.04 52
# ELASTIC 0.04 53
# ELASTIC 0.04 54
# ELASTIC 0.04 55
# ELASTIC 0.04 56
# ELASTIC 0.04 57
# ELASTIC 0.04 58
# ELASTIC 0.04 59
# ELASTIC 0.04 60
# ELASTIC 0.04 61
# ELASTIC 0.04 62
# ELASTIC 0.04 63
# ELASTIC 0.04 64
# ELASTIC 0.04 65
# ELASTIC 0.04 66
# ELASTIC 0.04 67
# ELASTIC 0.04 68
# ELASTIC 0.04 69
# ELASTIC 0.04 70
# ELASTIC 0.04 71
# ELASTIC 0.04 72
# ELASTIC 0.04 73
# ELASTIC 0.04 74
# ELASTIC 0.04 75
# ELASTIC 0.04 76
# ELASTIC 0.04 77
# ELASTIC 0.04 78
# ELASTIC 0.04 79
# ELASTIC 0.04 80
# ELASTIC 0.04 81
# ELASTIC 0.04 82
# ELASTIC 0.04 83
# ELASTIC 0.04 84
# ELASTIC 0.04 85
# ELASTIC 0.04 86
# ELASTIC 0.04 87
# ELASTIC 0.04 88
# ELASTIC 0.04 89
# ELASTIC 0.04 90
# ELASTIC 0.04 91
# ELASTIC 0.04 92
# ELASTIC 0.04 93
# ELASTIC 0.04 94
# ELASTIC 0.04 95
# ELASTIC 0.04 96
# ELASTIC 0.04 97
# ELASTIC 0.04 98
# ELASTIC 0.04 99
# NEWT
# ELASTIC 0.04 0
# ELASTIC 0.04 1
# ELASTIC 0.04 2
# ELASTIC 0.04 3
# ELASTIC 0.04 4
# ELASTIC 0.04 5
# ELASTIC 0.04 6
# ELASTIC 0.04 7
# ELASTIC 0.04 8
# ELASTIC 0.04 9
# ELASTIC 0.04 10
# ELASTIC 0.04 11
# ELASTIC 0.04 12
# ELASTIC 0.04 13
# ELASTIC 0.04 14
# ELASTIC 0.04 15
# ELASTIC 0.04 16
# ELASTIC 0.04 17
# ELASTIC 0.04 18
# ELASTIC 0.04 19
# ELASTIC 0.04 20
# ELASTIC 0.04 21
# ELASTIC 0.04 22
# ELASTIC 0.04 23
# ELASTIC 0.04 24
# ELASTIC 0.04 25
# ELASTIC 0.04 26
# ELASTIC 0.04 27
# ELASTIC 0.04 28
# ELASTIC 0.04 29
# ELASTIC 0.04 30
# ELASTIC 0.04 31
# ELASTIC 0.04 32
# ELASTIC 0.04 33
# ELASTIC 0.04 34
# ELASTIC 0.04 35
# ELASTIC 0.04 36
# ELASTIC 0.04 37
# ELASTIC 0.04 38
# ELASTIC 0.04 39
# ELASTIC 0.04 40
# ELASTIC 0.04 41
# ELASTIC 0.04 42
# ELASTIC 0.04 43
# ELASTIC 0.04 44
# ELASTIC 0.04 45
# ELASTIC 0.04 46
# ELASTIC 0.04 47
# ELASTIC 0.04 48
# ELASTIC 0.04 49
# ELASTIC 0.04 50
# ELASTIC 0.04 51
# ELASTIC 0.04 52
# ELASTIC 0.04 53
# ELASTIC 0.04 54
# ELASTIC 0.04 55
# ELASTIC 0.04 56
# ELASTIC 0.04 57
# ELASTIC 0.04 58
# ELASTIC 0.04 59
# ELASTIC 0.04 60
# ELASTIC 0.04 61
# ELASTIC 0.04 62
# ELASTIC 0.04 63
# ELASTIC 0.04 64
# ELASTIC 0.04 65
# ELASTIC 0.04 66
# ELASTIC 0.04 67
# ELASTIC 0.04 68
# ELASTIC 0.04 69
# ELASTIC 0.04 70
# ELASTIC 0.04 71
# ELASTIC 0.04 72
# ELASTIC 0.04 73
# ELASTIC 0.04 74
# ELASTIC 0.04 75
# ELASTIC 0.04 76
# ELASTIC 0.04 77
# ELASTIC 0.04 78
# ELASTIC 0.04 79
# ELASTIC 0.04 80
# ELASTIC 0.04 81
# ELASTIC 0.04 82
# ELASTIC 0.04 83
# ELASTIC 0.04 84
# ELASTIC 0.04 85
# ELASTIC 0.04 86
# ELASTIC 0.04 87
# ELASTIC 0.04 88
# ELASTIC 0.04 89
# ELASTIC 0.04 90
# ELASTIC 0.04 91
# ELASTIC 0.04 92
# ELASTIC 0.04 93
# ELASTIC 0.04 94
# ELASTIC 0.04 95
# ELASTIC 0.04 96
# ELASTIC 0.04 97
# ELASTIC 0.04 98
# ELASTIC 0.04 99
# 5 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.05 0
# ELASTIC 0.05 1
# ELASTIC 0.05 2
# ELASTIC 0.05 3
# ELASTIC 0.05 4
# ELASTIC 0.05 5
# ELASTIC 0.05 6
# ELASTIC 0.05 7
# ELASTIC 0.05 8
# ELASTIC 0.05 9
# ELASTIC 0.05 10
# ELASTIC 0.05 11
# ELASTIC 0.05 12
# ELASTIC 0.05 13
# ELASTIC 0.05 14
# ELASTIC 0.05 15
# ELASTIC 0.05 16
# ELASTIC 0.05 17
# ELASTIC 0.05 18
# ELASTIC 0.05 19
# ELASTIC 0.05 20
# ELASTIC 0.05 21
# ELASTIC 0.05 22
# ELASTIC 0.05 23
# ELASTIC 0.05 24
# ELASTIC 0.05 25
# ELASTIC 0.05 26
# ELASTIC 0.05 27
# ELASTIC 0.05 28
# ELASTIC 0.05 29
# ELASTIC 0.05 30
# ELASTIC 0.05 31
# ELASTIC 0.05 32
# ELASTIC 0.05 33
# ELASTIC 0.05 34
# ELASTIC 0.05 35
# ELASTIC 0.05 36
# ELASTIC 0.05 37
# ELASTIC 0.05 38
# ELASTIC 0.05 39
# ELASTIC 0.05 40
# ELASTIC 0.05 41
# ELASTIC 0.05 42
# ELASTIC 0.05 43
# ELASTIC 0.05 44
# ELASTIC 0.05 45
# ELASTIC 0.05 46
# ELASTIC 0.05 47
# ELASTIC 0.05 48
# ELASTIC 0.05 49
# ELASTIC 0.05 50
# ELASTIC 0.05 51
# ELASTIC 0.05 52
# ELASTIC 0.05 53
# ELASTIC 0.05 54
# ELASTIC 0.05 55
# ELASTIC 0.05 56
# ELASTIC 0.05 57
# ELASTIC 0.05 58
# ELASTIC 0.05 59
# ELASTIC 0.05 60
# ELASTIC 0.05 61
# ELASTIC 0.05 62
# ELASTIC 0.05 63
# ELASTIC 0.05 64
# ELASTIC 0.05 65
# ELASTIC 0.05 66
# ELASTIC 0.05 67
# ELASTIC 0.05 68
# ELASTIC 0.05 69
# ELASTIC 0.05 70
# ELASTIC 0.05 71
# ELASTIC 0.05 72
# ELASTIC 0.05 73
# ELASTIC 0.05 74
# ELASTIC 0.05 75
# ELASTIC 0.05 76
# ELASTIC 0.05 77
# ELASTIC 0.05 78
# ELASTIC 0.05 79
# ELASTIC 0.05 80
# ELASTIC 0.05 81
# ELASTIC 0.05 82
# ELASTIC 0.05 83
# ELASTIC 0.05 84
# ELASTIC 0.05 85
# ELASTIC 0.05 86
# ELASTIC 0.05 87
# ELASTIC 0.05 88
# ELASTIC 0.05 89
# ELASTIC 0.05 90
# ELASTIC 0.05 91
# ELASTIC 0.05 92
# ELASTIC 0.05 93
# ELASTIC 0.05 94
# ELASTIC 0.05 95
# ELASTIC 0.05 96
# ELASTIC 0.05 97
# ELASTIC 0.05 98
# ELASTIC 0.05 99
# NEWT
# ELASTIC 0.05 0
# ELASTIC 0.05 1
# ELASTIC 0.05 2
# ELASTIC 0.05 3
# ELASTIC 0.05 4
# ELASTIC 0.05 5
# ELASTIC 0.05 6
# ELASTIC 0.05 7
# ELASTIC 0.05 8
# ELASTIC 0.05 9
# ELASTIC 0.05 10
# ELASTIC 0.05 11
# ELASTIC 0.05 12
# ELASTIC 0.05 13
# ELASTIC 0.05 14
# ELASTIC 0.05 15
# ELASTIC 0.05 16
# ELASTIC 0.05 17
# ELASTIC 0.05 18
# ELASTIC 0.05 19
# ELASTIC 0.05 20
# ELASTIC 0.05 21
# ELASTIC 0.05 22
# ELASTIC 0.05 23
# ELASTIC 0.05 24
# ELASTIC 0.05 25
# ELASTIC 0.05 26
# ELASTIC 0.05 27
# ELASTIC 0.05 28
# ELASTIC 0.05 29
# ELASTIC 0.05 30
# ELASTIC 0.05 31
# ELASTIC 0.05 32
# ELASTIC 0.05 33
# ELASTIC 0.05 34
# ELASTIC 0.05 35
# ELASTIC 0.05 36
# ELASTIC 0.05 37
# ELASTIC 0.05 38
# ELASTIC 0.05 39
# ELASTIC 0.05 40
# ELASTIC 0.05 41
# ELASTIC 0.05 42
# ELASTIC 0.05 43
# ELASTIC 0.05 44
# ELASTIC 0.05 45
# ELASTIC 0.05 46
# ELASTIC 0.05 47
# ELASTIC 0.05 48
# ELASTIC 0.05 49
# ELASTIC 0.05 50
# ELASTIC 0.05 51
# ELASTIC 0.05 52
# ELASTIC 0.05 53
# ELASTIC 0.05 54
# ELASTIC 0.05 55
# ELASTIC 0.05 56
# ELASTIC 0.05 57
# ELASTIC 0.05 58
# ELASTIC 0.05 59
# ELASTIC 0.05 60
# ELASTIC 0.05 61
# ELASTIC 0.05 62
# ELASTIC 0.05 63
# ELASTIC 0.05 64
# ELASTIC 0.05 65
# ELASTIC 0.05 66
# ELASTIC 0.05 67
# ELASTIC 0.05 68
# ELASTIC 0.05 69
# ELASTIC 0.05 70
# ELASTIC 0.05 71
# ELASTIC 0.05 72
# ELASTIC 0.05 73
# ELASTIC 0.05 74
# ELASTIC 0.05 75
# ELASTIC 0.05 76
# ELASTIC 0.05 77
# ELASTIC 0.05 78
# ELASTIC 0.05 79
# ELASTIC 0.05 80
# ELASTIC 0.05 81
# ELASTIC 0.05 82
# ELASTIC 0.05 83
# ELASTIC 0.05 84
# ELASTIC 0.05 85
# ELASTIC 0.05 86
# ELASTIC 0.05 87
# ELASTIC 0.05 88
# ELASTIC 0.05 89
# ELASTIC 0.05 90
# ELASTIC 0.05 91
# ELASTIC 0.05 92
# ELASTIC 0.05 93
# ELASTIC 0.05 94
# ELASTIC 0.05 95
# ELASTIC 0.05 96
# ELASTIC 0.05 97
# ELASTIC 0.05 98
# ELASTIC 0.05 99
# NEWT
# ELASTIC 0.05 0
# ELASTIC 0.05 1
# ELASTIC 0.05 2
# ELASTIC 0.05 3
# ELASTIC 0.05 4
# ELASTIC 0.05 5
# ELASTIC 0.05 6
# ELASTIC 0.05 7
# ELASTIC 0.05 8
# ELASTIC 0.05 9
# ELASTIC 0.05 10
# ELASTIC 0.05 11
# ELASTIC 0.05 12
# ELASTIC 0.05 13
# ELASTIC 0.05 14
# ELASTIC 0.05 15
# ELASTIC 0.05 16
# ELASTIC 0.05 17
# ELASTIC 0.05 18
# ELASTIC 0.05 19
# ELASTIC 0.05 20
# ELASTIC 0.05 21
# ELASTIC 0.05 22
# ELASTIC 0.05 23
# ELASTIC 0.05 24
# ELASTIC 0.05 25
# ELASTIC 0.05 26
# ELASTIC 0.05 27
# ELASTIC 0.05 28
# ELASTIC 0.05 29
# ELASTIC 0.05 30
# ELASTIC 0.05 31
# ELASTIC 0.05 32
# ELASTIC 0.05 33
# ELASTIC 0.05 34
# ELASTIC 0.05 35
# ELASTIC 0.05 36
# ELASTIC 0.05 37
# ELASTIC 0.05 38
# ELASTIC 0.05 39
# ELASTIC 0.05 40
# ELASTIC 0.05 41
# ELASTIC 0.05 42
# ELASTIC 0.05 43
# ELASTIC 0.05 44
# ELASTIC 0.05 45
# ELASTIC 0.05 46
# ELASTIC 0.05 47
# ELASTIC 0.05 48
# ELASTIC 0.05 49
# ELASTIC 0.05 50
# ELASTIC 0.05 51
# ELASTIC 0.05 52
# ELASTIC 0.05 53
# ELASTIC 0.05 54
# ELASTIC 0.05 55
# ELASTIC 0.05 56
# ELASTIC 0.05 57
# ELASTIC 0.05 58
# ELASTIC 0.05 59
# ELASTIC 0.05 60
# ELASTIC 0.05 61
# ELASTIC 0.05 62
# ELASTIC 0.05 63
# ELASTIC 0.05 64
# ELASTIC 0.05 65
# ELASTIC 0.05 66
# ELASTIC 0.05 67
# ELASTIC 0.05 68
# ELASTIC 0.05 69
# ELASTIC 0.05 70
# ELASTIC 0.05 71
# ELASTIC 0.05 72
# ELASTIC 0.05 73
# ELASTIC 0.05 74
# ELASTIC 0.05 75
# ELASTIC 0.05 76
# ELASTIC 0.05 77
# ELASTIC 0.05 78
# ELASTIC 0.05 79
# ELASTIC 0.05 80
# ELASTIC 0.05 81
# ELASTIC 0.05 82
# ELASTIC 0.05 83
# ELASTIC 0.05 84
# ELASTIC 0.05 85
# ELASTIC 0.05 86
# ELASTIC 0.05 87
# ELASTIC 0.05 88
# ELASTIC 0.05 89
# ELASTIC 0.05 90
# ELASTIC 0.05 91
# ELASTIC 0.05 92
# ELASTIC 0.05 93
# ELASTIC 0.05 94
# ELASTIC 0.05 95
# ELASTIC 0.05 96
# ELASTIC 0.05 97
# ELASTIC 0.05 98
# ELASTIC 0.05 99
# 6 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.060000000000000005 0
# ELASTIC 0.060000000000000005 1
# ELASTIC 0.060000000000000005 2
# ELASTIC 0.060000000000000005 3
# ELASTIC 0.060000000000000005 4
# ELASTIC 0.060000000000000005 5
# ELASTIC 0.060000000000000005 6
# ELASTIC 0.060000000000000005 7
# ELASTIC 0.060000000000000005 8
# ELASTIC 0.060000000000000005 9
# ELASTIC 0.060000000000000005 10
# ELASTIC 0.060000000000000005 11
# ELASTIC 0.060000000000000005 12
# ELASTIC 0.060000000000000005 13
# ELASTIC 0.060000000000000005 14
# ELASTIC 0.060000000000000005 15
# ELASTIC 0.060000000000000005 16
# ELASTIC 0.060000000000000005 17
# ELASTIC 0.060000000000000005 18
# ELASTIC 0.060000000000000005 19
# ELASTIC 0.060000000000000005 20
# ELASTIC 0.060000000000000005 21
# ELASTIC 0.060000000000000005 22
# ELASTIC 0.060000000000000005 23
# ELASTIC 0.060000000000000005 24
# ELASTIC 0.060000000000000005 25
# ELASTIC 0.060000000000000005 26
# ELASTIC 0.060000000000000005 27
# ELASTIC 0.060000000000000005 28
# ELASTIC 0.060000000000000005 29
# ELASTIC 0.060000000000000005 30
# ELASTIC 0.060000000000000005 31
# ELASTIC 0.060000000000000005 32
# ELASTIC 0.060000000000000005 33
# ELASTIC 0.060000000000000005 34
# ELASTIC 0.060000000000000005 35
# ELASTIC 0.060000000000000005 36
# ELASTIC 0.060000000000000005 37
# ELASTIC 0.060000000000000005 38
# ELASTIC 0.060000000000000005 39
# ELASTIC 0.060000000000000005 40
# ELASTIC 0.060000000000000005 41
# ELASTIC 0.060000000000000005 42
# ELASTIC 0.060000000000000005 43
# ELASTIC 0.060000000000000005 44
# ELASTIC 0.060000000000000005 45
# ELASTIC 0.060000000000000005 46
# ELASTIC 0.060000000000000005 47
# ELASTIC 0.060000000000000005 48
# ELASTIC 0.060000000000000005 49
# ELASTIC 0.060000000000000005 50
# ELASTIC 0.060000000000000005 51
# ELASTIC 0.060000000000000005 52
# ELASTIC 0.060000000000000005 53
# ELASTIC 0.060000000000000005 54
# ELASTIC 0.060000000000000005 55
# ELASTIC 0.060000000000000005 56
# ELASTIC 0.060000000000000005 57
# ELASTIC 0.060000000000000005 58
# ELASTIC 0.060000000000000005 59
# ELASTIC 0.060000000000000005 60
# ELASTIC 0.060000000000000005 61
# ELASTIC 0.060000000000000005 62
# ELASTIC 0.060000000000000005 63
# ELASTIC 0.060000000000000005 64
# ELASTIC 0.060000000000000005 65
# ELASTIC 0.060000000000000005 66
# ELASTIC 0.060000000000000005 67
# ELASTIC 0.060000000000000005 68
# ELASTIC 0.060000000000000005 69
# ELASTIC 0.060000000000000005 70
# ELASTIC 0.060000000000000005 71
# ELASTIC 0.060000000000000005 72
# ELASTIC 0.060000000000000005 73
# ELASTIC 0.060000000000000005 74
# ELASTIC 0.060000000000000005 75
# ELASTIC 0.060000000000000005 76
# ELASTIC 0.060000000000000005 77
# ELASTIC 0.060000000000000005 78
# ELASTIC 0.060000000000000005 79
# ELASTIC 0.060000000000000005 80
# ELASTIC 0.060000000000000005 81
# ELASTIC 0.060000000000000005 82
# ELASTIC 0.060000000000000005 83
# ELASTIC 0.060000000000000005 84
# ELASTIC 0.060000000000000005 85
# ELASTIC 0.060000000000000005 86
# ELASTIC 0.060000000000000005 87
# ELASTIC 0.060000000000000005 88
# ELASTIC 0.060000000000000005 89
# ELASTIC 0.060000000000000005 90
# ELASTIC 0.060000000000000005 91
# ELASTIC 0.060000000000000005 92
# ELASTIC 0.060000000000000005 93
# ELASTIC 0.060000000000000005 94
# ELASTIC 0.060000000000000005 95
# ELASTIC 0.060000000000000005 96
# ELASTIC 0.060000000000000005 97
# ELASTIC 0.060000000000000005 98
# ELASTIC 0.060000000000000005 99
# NEWT
# ELASTIC 0.060000000000000005 0
# ELASTIC 0.060000000000000005 1
# ELASTIC 0.060000000000000005 2
# ELASTIC 0.060000000000000005 3
# ELASTIC 0.060000000000000005 4
# ELASTIC 0.060000000000000005 5
# ELASTIC 0.060000000000000005 6
# ELASTIC 0.060000000000000005 7
# ELASTIC 0.060000000000000005 8
# ELASTIC 0.060000000000000005 9
# ELASTIC 0.060000000000000005 10
# ELASTIC 0.060000000000000005 11
# ELASTIC 0.060000000000000005 12
# ELASTIC 0.060000000000000005 13
# ELASTIC 0.060000000000000005 14
# ELASTIC 0.060000000000000005 15
# ELASTIC 0.060000000000000005 16
# ELASTIC 0.060000000000000005 17
# ELASTIC 0.060000000000000005 18
# ELASTIC 0.060000000000000005 19
# ELASTIC 0.060000000000000005 20
# ELASTIC 0.060000000000000005 21
# ELASTIC 0.060000000000000005 22
# ELASTIC 0.060000000000000005 23
# ELASTIC 0.060000000000000005 24
# ELASTIC 0.060000000000000005 25
# ELASTIC 0.060000000000000005 26
# ELASTIC 0.060000000000000005 27
# ELASTIC 0.060000000000000005 28
# ELASTIC 0.060000000000000005 29
# ELASTIC 0.060000000000000005 30
# ELASTIC 0.060000000000000005 31
# ELASTIC 0.060000000000000005 32
# ELASTIC 0.060000000000000005 33
# ELASTIC 0.060000000000000005 34
# ELASTIC 0.060000000000000005 35
# ELASTIC 0.060000000000000005 36
# ELASTIC 0.060000000000000005 37
# ELASTIC 0.060000000000000005 38
# ELASTIC 0.060000000000000005 39
# ELASTIC 0.060000000000000005 40
# ELASTIC 0.060000000000000005 41
# ELASTIC 0.060000000000000005 42
# ELASTIC 0.060000000000000005 43
# ELASTIC 0.060000000000000005 44
# ELASTIC 0.060000000000000005 45
# ELASTIC 0.060000000000000005 46
# ELASTIC 0.060000000000000005 47
# ELASTIC 0.060000000000000005 48
# ELASTIC 0.060000000000000005 49
# ELASTIC 0.060000000000000005 50
# ELASTIC 0.060000000000000005 51
# ELASTIC 0.060000000000000005 52
# ELASTIC 0.060000000000000005 53
# ELASTIC 0.060000000000000005 54
# ELASTIC 0.060000000000000005 55
# ELASTIC 0.060000000000000005 56
# ELASTIC 0.060000000000000005 57
# ELASTIC 0.060000000000000005 58
# ELASTIC 0.060000000000000005 59
# ELASTIC 0.060000000000000005 60
# ELASTIC 0.060000000000000005 61
# ELASTIC 0.060000000000000005 62
# ELASTIC 0.060000000000000005 63
# ELASTIC 0.060000000000000005 64
# ELASTIC 0.060000000000000005 65
# ELASTIC 0.060000000000000005 66
# ELASTIC 0.060000000000000005 67
# ELASTIC 0.060000000000000005 68
# ELASTIC 0.060000000000000005 69
# ELASTIC 0.060000000000000005 70
# ELASTIC 0.060000000000000005 71
# ELASTIC 0.060000000000000005 72
# ELASTIC 0.060000000000000005 73
# ELASTIC 0.060000000000000005 74
# ELASTIC 0.060000000000000005 75
# ELASTIC 0.060000000000000005 76
# ELASTIC 0.060000000000000005 77
# ELASTIC 0.060000000000000005 78
# ELASTIC 0.060000000000000005 79
# ELASTIC 0.060000000000000005 80
# ELASTIC 0.060000000000000005 81
# ELASTIC 0.060000000000000005 82
# ELASTIC 0.060000000000000005 83
# ELASTIC 0.060000000000000005 84
# ELASTIC 0.060000000000000005 85
# ELASTIC 0.060000000000000005 86
# ELASTIC 0.060000000000000005 87
# ELASTIC 0.060000000000000005 88
# ELASTIC 0.060000000000000005 89
# ELASTIC 0.060000000000000005 90
# ELASTIC 0.060000000000000005 91
# ELASTIC 0.060000000000000005 92
# ELASTIC 0.060000000000000005 93
# ELASTIC 0.060000000000000005 94
# ELASTIC 0.060000000000000005 95
# ELASTIC 0.060000000000000005 96
# ELASTIC 0.060000000000000005 97
# ELASTIC 0.060000000000000005 98
# ELASTIC 0.060000000000000005 99
# NEWT
# ELASTIC 0.060000000000000005 0
# ELASTIC 0.060000000000000005 1
# ELASTIC 0.060000000000000005 2
# ELASTIC 0.060000000000000005 3
# ELASTIC 0.060000000000000005 4
# ELASTIC 0.060000000000000005 5
# ELASTIC 0.060000000000000005 6
# ELASTIC 0.060000000000000005 7
# ELASTIC 0.060000000000000005 8
# ELASTIC 0.060000000000000005 9
# ELASTIC 0.060000000000000005 10
# ELASTIC 0.060000000000000005 11
# ELASTIC 0.060000000000000005 12
# ELASTIC 0.060000000000000005 13
# ELASTIC 0.060000000000000005 14
# ELASTIC 0.060000000000000005 15
# ELASTIC 0.060000000000000005 16
# ELASTIC 0.060000000000000005 17
# ELASTIC 0.060000000000000005 18
# ELASTIC 0.060000000000000005 19
# ELASTIC 0.060000000000000005 20
# ELASTIC 0.060000000000000005 21
# ELASTIC 0.060000000000000005 22
# ELASTIC 0.060000000000000005 23
# ELASTIC 0.060000000000000005 24
# ELASTIC 0.060000000000000005 25
# ELASTIC 0.060000000000000005 26
# ELASTIC 0.060000000000000005 27
# ELASTIC 0.060000000000000005 28
# ELASTIC 0.060000000000000005 29
# ELASTIC 0.060000000000000005 30
# ELASTIC 0.060000000000000005 31
# ELASTIC 0.060000000000000005 32
# ELASTIC 0.060000000000000005 33
# ELASTIC 0.060000000000000005 34
# ELASTIC 0.060000000000000005 35
# ELASTIC 0.060000000000000005 36
# ELASTIC 0.060000000000000005 37
# ELASTIC 0.060000000000000005 38
# ELASTIC 0.060000000000000005 39
# ELASTIC 0.060000000000000005 40
# ELASTIC 0.060000000000000005 41
# ELASTIC 0.060000000000000005 42
# ELASTIC 0.060000000000000005 43
# ELASTIC 0.060000000000000005 44
# ELASTIC 0.060000000000000005 45
# ELASTIC 0.060000000000000005 46
# ELASTIC 0.060000000000000005 47
# ELASTIC 0.060000000000000005 48
# ELASTIC 0.060000000000000005 49
# ELASTIC 0.060000000000000005 50
# ELASTIC 0.060000000000000005 51
# ELASTIC 0.060000000000000005 52
# ELASTIC 0.060000000000000005 53
# ELASTIC 0.060000000000000005 54
# ELASTIC 0.060000000000000005 55
# ELASTIC 0.060000000000000005 56
# ELASTIC 0.060000000000000005 57
# ELASTIC 0.060000000000000005 58
# ELASTIC 0.060000000000000005 59
# ELASTIC 0.060000000000000005 60
# ELASTIC 0.060000000000000005 61
# ELASTIC 0.060000000000000005 62
# ELASTIC 0.060000000000000005 63
# ELASTIC 0.060000000000000005 64
# ELASTIC 0.060000000000000005 65
# ELASTIC 0.060000000000000005 66
# ELASTIC 0.060000000000000005 67
# ELASTIC 0.060000000000000005 68
# ELASTIC 0.060000000000000005 69
# ELASTIC 0.060000000000000005 70
# ELASTIC 0.060000000000000005 71
# ELASTIC 0.060000000000000005 72
# ELASTIC 0.060000000000000005 73
# ELASTIC 0.060000000000000005 74
# ELASTIC 0.060000000000000005 75
# ELASTIC 0.060000000000000005 76
# ELASTIC 0.060000000000000005 77
# ELASTIC 0.060000000000000005 78
# ELASTIC 0.060000000000000005 79
# ELASTIC 0.060000000000000005 80
# ELASTIC 0.060000000000000005 81
# ELASTIC 0.060000000000000005 82
# ELASTIC 0.060000000000000005 83
# ELASTIC 0.060000000000000005 84
# ELASTIC 0.060000000000000005 85
# ELASTIC 0.060000000000000005 86
# ELASTIC 0.060000000000000005 87
# ELASTIC 0.060000000000000005 88
# ELASTIC 0.060000000000000005 89
# ELASTIC 0.060000000000000005 90
# ELASTIC 0.060000000000000005 91
# ELASTIC 0.060000000000000005 92
# ELASTIC 0.060000000000000005 93
# ELASTIC 0.060000000000000005 94
# ELASTIC 0.060000000000000005 95
# ELASTIC 0.060000000000000005 96
# ELASTIC 0.060000000000000005 97
# ELASTIC 0.060000000000000005 98
# ELASTIC 0.060000000000000005 99
# 7 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.06999999999999999 0
# ELASTIC 0.06999999999999999 1
# ELASTIC 0.06999999999999999 2
# ELASTIC 0.06999999999999999 3
# ELASTIC 0.06999999999999999 4
# ELASTIC 0.06999999999999999 5
# ELASTIC 0.06999999999999999 6
# ELASTIC 0.06999999999999999 7
# ELASTIC 0.06999999999999999 8
# ELASTIC 0.06999999999999999 9
# ELASTIC 0.06999999999999999 10
# ELASTIC 0.06999999999999999 11
# ELASTIC 0.06999999999999999 12
# ELASTIC 0.06999999999999999 13
# ELASTIC 0.06999999999999999 14
# ELASTIC 0.06999999999999999 15
# ELASTIC 0.06999999999999999 16
# ELASTIC 0.06999999999999999 17
# ELASTIC 0.06999999999999999 18
# ELASTIC 0.06999999999999999 19
# ELASTIC 0.06999999999999999 20
# ELASTIC 0.06999999999999999 21
# ELASTIC 0.06999999999999999 22
# ELASTIC 0.06999999999999999 23
# ELASTIC 0.06999999999999999 24
# ELASTIC 0.06999999999999999 25
# ELASTIC 0.06999999999999999 26
# ELASTIC 0.06999999999999999 27
# ELASTIC 0.06999999999999999 28
# ELASTIC 0.06999999999999999 29
# ELASTIC 0.06999999999999999 30
# ELASTIC 0.06999999999999999 31
# ELASTIC 0.06999999999999999 32
# ELASTIC 0.06999999999999999 33
# ELASTIC 0.06999999999999999 34
# ELASTIC 0.06999999999999999 35
# ELASTIC 0.06999999999999999 36
# ELASTIC 0.06999999999999999 37
# ELASTIC 0.06999999999999999 38
# ELASTIC 0.06999999999999999 39
# ELASTIC 0.06999999999999999 40
# ELASTIC 0.06999999999999999 41
# ELASTIC 0.06999999999999999 42
# ELASTIC 0.06999999999999999 43
# ELASTIC 0.06999999999999999 44
# ELASTIC 0.06999999999999999 45
# ELASTIC 0.06999999999999999 46
# ELASTIC 0.06999999999999999 47
# ELASTIC 0.06999999999999999 48
# ELASTIC 0.06999999999999999 49
# ELASTIC 0.06999999999999999 50
# ELASTIC 0.06999999999999999 51
# ELASTIC 0.06999999999999999 52
# ELASTIC 0.06999999999999999 53
# ELASTIC 0.06999999999999999 54
# ELASTIC 0.06999999999999999 55
# ELASTIC 0.06999999999999999 56
# ELASTIC 0.06999999999999999 57
# ELASTIC 0.06999999999999999 58
# ELASTIC 0.06999999999999999 59
# ELASTIC 0.06999999999999999 60
# ELASTIC 0.06999999999999999 61
# ELASTIC 0.06999999999999999 62
# ELASTIC 0.06999999999999999 63
# ELASTIC 0.06999999999999999 64
# ELASTIC 0.06999999999999999 65
# ELASTIC 0.06999999999999999 66
# ELASTIC 0.06999999999999999 67
# ELASTIC 0.06999999999999999 68
# ELASTIC 0.06999999999999999 69
# ELASTIC 0.06999999999999999 70
# ELASTIC 0.06999999999999999 71
# ELASTIC 0.06999999999999999 72
# ELASTIC 0.06999999999999999 73
# ELASTIC 0.06999999999999999 74
# ELASTIC 0.06999999999999999 75
# ELASTIC 0.06999999999999999 76
# ELASTIC 0.06999999999999999 77
# ELASTIC 0.06999999999999999 78
# ELASTIC 0.06999999999999999 79
# ELASTIC 0.06999999999999999 80
# ELASTIC 0.06999999999999999 81
# ELASTIC 0.06999999999999999 82
# ELASTIC 0.06999999999999999 83
# ELASTIC 0.06999999999999999 84
# ELASTIC 0.06999999999999999 85
# ELASTIC 0.06999999999999999 86
# ELASTIC 0.06999999999999999 87
# ELASTIC 0.06999999999999999 88
# ELASTIC 0.06999999999999999 89
# ELASTIC 0.06999999999999999 90
# ELASTIC 0.06999999999999999 91
# ELASTIC 0.06999999999999999 92
# ELASTIC 0.06999999999999999 93
# ELASTIC 0.06999999999999999 94
# ELASTIC 0.06999999999999999 95
# ELASTIC 0.06999999999999999 96
# ELASTIC 0.06999999999999999 97
# ELASTIC 0.06999999999999999 98
# ELASTIC 0.06999999999999999 99
# NEWT
# ELASTIC 0.06999999999999999 0
# ELASTIC 0.06999999999999999 1
# ELASTIC 0.06999999999999999 2
# ELASTIC 0.06999999999999999 3
# ELASTIC 0.06999999999999999 4
# ELASTIC 0.06999999999999999 5
# ELASTIC 0.06999999999999999 6
# ELASTIC 0.06999999999999999 7
# ELASTIC 0.06999999999999999 8
# ELASTIC 0.06999999999999999 9
# ELASTIC 0.06999999999999999 10
# ELASTIC 0.06999999999999999 11
# ELASTIC 0.06999999999999999 12
# ELASTIC 0.06999999999999999 13
# ELASTIC 0.06999999999999999 14
# ELASTIC 0.06999999999999999 15
# ELASTIC 0.06999999999999999 16
# ELASTIC 0.06999999999999999 17
# ELASTIC 0.06999999999999999 18
# ELASTIC 0.06999999999999999 19
# ELASTIC 0.06999999999999999 20
# ELASTIC 0.06999999999999999 21
# ELASTIC 0.06999999999999999 22
# ELASTIC 0.06999999999999999 23
# ELASTIC 0.06999999999999999 24
# ELASTIC 0.06999999999999999 25
# ELASTIC 0.06999999999999999 26
# ELASTIC 0.06999999999999999 27
# ELASTIC 0.06999999999999999 28
# ELASTIC 0.06999999999999999 29
# ELASTIC 0.06999999999999999 30
# ELASTIC 0.06999999999999999 31
# ELASTIC 0.06999999999999999 32
# ELASTIC 0.06999999999999999 33
# ELASTIC 0.06999999999999999 34
# ELASTIC 0.06999999999999999 35
# ELASTIC 0.06999999999999999 36
# ELASTIC 0.06999999999999999 37
# ELASTIC 0.06999999999999999 38
# ELASTIC 0.06999999999999999 39
# ELASTIC 0.06999999999999999 40
# ELASTIC 0.06999999999999999 41
# ELASTIC 0.06999999999999999 42
# ELASTIC 0.06999999999999999 43
# ELASTIC 0.06999999999999999 44
# ELASTIC 0.06999999999999999 45
# ELASTIC 0.06999999999999999 46
# ELASTIC 0.06999999999999999 47
# ELASTIC 0.06999999999999999 48
# ELASTIC 0.06999999999999999 49
# ELASTIC 0.06999999999999999 50
# ELASTIC 0.06999999999999999 51
# ELASTIC 0.06999999999999999 52
# ELASTIC 0.06999999999999999 53
# ELASTIC 0.06999999999999999 54
# ELASTIC 0.06999999999999999 55
# ELASTIC 0.06999999999999999 56
# ELASTIC 0.06999999999999999 57
# ELASTIC 0.06999999999999999 58
# ELASTIC 0.06999999999999999 59
# ELASTIC 0.06999999999999999 60
# ELASTIC 0.06999999999999999 61
# ELASTIC 0.06999999999999999 62
# ELASTIC 0.06999999999999999 63
# ELASTIC 0.06999999999999999 64
# ELASTIC 0.06999999999999999 65
# ELASTIC 0.06999999999999999 66
# ELASTIC 0.06999999999999999 67
# ELASTIC 0.06999999999999999 68
# ELASTIC 0.06999999999999999 69
# ELASTIC 0.06999999999999999 70
# ELASTIC 0.06999999999999999 71
# ELASTIC 0.06999999999999999 72
# ELASTIC 0.06999999999999999 73
# ELASTIC 0.06999999999999999 74
# ELASTIC 0.06999999999999999 75
# ELASTIC 0.06999999999999999 76
# ELASTIC 0.06999999999999999 77
# ELASTIC 0.06999999999999999 78
# ELASTIC 0.06999999999999999 79
# ELASTIC 0.06999999999999999 80
# ELASTIC 0.06999999999999999 81
# ELASTIC 0.06999999999999999 82
# ELASTIC 0.06999999999999999 83
# ELASTIC 0.06999999999999999 84
# ELASTIC 0.06999999999999999 85
# ELASTIC 0.06999999999999999 86
# ELASTIC 0.06999999999999999 87
# ELASTIC 0.06999999999999999 88
# ELASTIC 0.06999999999999999 89
# ELASTIC 0.06999999999999999 90
# ELASTIC 0.06999999999999999 91
# ELASTIC 0.06999999999999999 92
# ELASTIC 0.06999999999999999 93
# ELASTIC 0.06999999999999999 94
# ELASTIC 0.06999999999999999 95
# ELASTIC 0.06999999999999999 96
# ELASTIC 0.06999999999999999 97
# ELASTIC 0.06999999999999999 98
# ELASTIC 0.06999999999999999 99
# NEWT
# ELASTIC 0.06999999999999999 0
# ELASTIC 0.06999999999999999 1
# ELASTIC 0.06999999999999999 2
# ELASTIC 0.06999999999999999 3
# ELASTIC 0.06999999999999999 4
# ELASTIC 0.06999999999999999 5
# ELASTIC 0.06999999999999999 6
# ELASTIC 0.06999999999999999 7
# ELASTIC 0.06999999999999999 8
# ELASTIC 0.06999999999999999 9
# ELASTIC 0.06999999999999999 10
# ELASTIC 0.06999999999999999 11
# ELASTIC 0.06999999999999999 12
# ELASTIC 0.06999999999999999 13
# ELASTIC 0.06999999999999999 14
# ELASTIC 0.06999999999999999 15
# ELASTIC 0.06999999999999999 16
# ELASTIC 0.06999999999999999 17
# ELASTIC 0.06999999999999999 18
# ELASTIC 0.06999999999999999 19
# ELASTIC 0.06999999999999999 20
# ELASTIC 0.06999999999999999 21
# ELASTIC 0.06999999999999999 22
# ELASTIC 0.06999999999999999 23
# ELASTIC 0.06999999999999999 24
# ELASTIC 0.06999999999999999 25
# ELASTIC 0.06999999999999999 26
# ELASTIC 0.06999999999999999 27
# ELASTIC 0.06999999999999999 28
# ELASTIC 0.06999999999999999 29
# ELASTIC 0.06999999999999999 30
# ELASTIC 0.06999999999999999 31
# ELASTIC 0.06999999999999999 32
# ELASTIC 0.06999999999999999 33
# ELASTIC 0.06999999999999999 34
# ELASTIC 0.06999999999999999 35
# ELASTIC 0.06999999999999999 36
# ELASTIC 0.06999999999999999 37
# ELASTIC 0.06999999999999999 38
# ELASTIC 0.06999999999999999 39
# ELASTIC 0.06999999999999999 40
# ELASTIC 0.06999999999999999 41
# ELASTIC 0.06999999999999999 42
# ELASTIC 0.06999999999999999 43
# ELASTIC 0.06999999999999999 44
# ELASTIC 0.06999999999999999 45
# ELASTIC 0.06999999999999999 46
# ELASTIC 0.06999999999999999 47
# ELASTIC 0.06999999999999999 48
# ELASTIC 0.06999999999999999 49
# ELASTIC 0.06999999999999999 50
# ELASTIC 0.06999999999999999 51
# ELASTIC 0.06999999999999999 52
# ELASTIC 0.06999999999999999 53
# ELASTIC 0.06999999999999999 54
# ELASTIC 0.06999999999999999 55
# ELASTIC 0.06999999999999999 56
# ELASTIC 0.06999999999999999 57
# ELASTIC 0.06999999999999999 58
# ELASTIC 0.06999999999999999 59
# ELASTIC 0.06999999999999999 60
# ELASTIC 0.06999999999999999 61
# ELASTIC 0.06999999999999999 62
# ELASTIC 0.06999999999999999 63
# ELASTIC 0.06999999999999999 64
# ELASTIC 0.06999999999999999 65
# ELASTIC 0.06999999999999999 66
# ELASTIC 0.06999999999999999 67
# ELASTIC 0.06999999999999999 68
# ELASTIC 0.06999999999999999 69
# ELASTIC 0.06999999999999999 70
# ELASTIC 0.06999999999999999 71
# ELASTIC 0.06999999999999999 72
# ELASTIC 0.06999999999999999 73
# ELASTIC 0.06999999999999999 74
# ELASTIC 0.06999999999999999 75
# ELASTIC 0.06999999999999999 76
# ELASTIC 0.06999999999999999 77
# ELASTIC 0.06999999999999999 78
# ELASTIC 0.06999999999999999 79
# ELASTIC 0.06999999999999999 80
# ELASTIC 0.06999999999999999 81
# ELASTIC 0.06999999999999999 82
# ELASTIC 0.06999999999999999 83
# ELASTIC 0.06999999999999999 84
# ELASTIC 0.06999999999999999 85
# ELASTIC 0.06999999999999999 86
# ELASTIC 0.06999999999999999 87
# ELASTIC 0.06999999999999999 88
# ELASTIC 0.06999999999999999 89
# ELASTIC 0.06999999999999999 90
# ELASTIC 0.06999999999999999 91
# ELASTIC 0.06999999999999999 92
# ELASTIC 0.06999999999999999 93
# ELASTIC 0.06999999999999999 94
# ELASTIC 0.06999999999999999 95
# ELASTIC 0.06999999999999999 96
# ELASTIC 0.06999999999999999 97
# ELASTIC 0.06999999999999999 98
# ELASTIC 0.06999999999999999 99
# 8 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.08 0
# ELASTIC 0.08 1
# ELASTIC 0.08 2
# ELASTIC 0.08 3
# ELASTIC 0.08 4
# ELASTIC 0.08 5
# ELASTIC 0.08 6
# ELASTIC 0.08 7
# ELASTIC 0.08 8
# ELASTIC 0.08 9
# ELASTIC 0.08 10
# ELASTIC 0.08 11
# ELASTIC 0.08 12
# ELASTIC 0.08 13
# ELASTIC 0.08 14
# ELASTIC 0.08 15
# ELASTIC 0.08 16
# ELASTIC 0.08 17
# ELASTIC 0.08 18
# ELASTIC 0.08 19
# ELASTIC 0.08 20
# ELASTIC 0.08 21
# ELASTIC 0.08 22
# ELASTIC 0.08 23
# ELASTIC 0.08 24
# ELASTIC 0.08 25
# ELASTIC 0.08 26
# ELASTIC 0.08 27
# ELASTIC 0.08 28
# ELASTIC 0.08 29
# ELASTIC 0.08 30
# ELASTIC 0.08 31
# ELASTIC 0.08 32
# ELASTIC 0.08 33
# ELASTIC 0.08 34
# ELASTIC 0.08 35
# ELASTIC 0.08 36
# ELASTIC 0.08 37
# ELASTIC 0.08 38
# ELASTIC 0.08 39
# ELASTIC 0.08 40
# ELASTIC 0.08 41
# ELASTIC 0.08 42
# ELASTIC 0.08 43
# ELASTIC 0.08 44
# ELASTIC 0.08 45
# ELASTIC 0.08 46
# ELASTIC 0.08 47
# ELASTIC 0.08 48
# ELASTIC 0.08 49
# ELASTIC 0.08 50
# ELASTIC 0.08 51
# ELASTIC 0.08 52
# ELASTIC 0.08 53
# ELASTIC 0.08 54
# ELASTIC 0.08 55
# ELASTIC 0.08 56
# ELASTIC 0.08 57
# ELASTIC 0.08 58
# ELASTIC 0.08 59
# ELASTIC 0.08 60
# ELASTIC 0.08 61
# ELASTIC 0.08 62
# ELASTIC 0.08 63
# ELASTIC 0.08 64
# ELASTIC 0.08 65
# ELASTIC 0.08 66
# ELASTIC 0.08 67
# ELASTIC 0.08 68
# ELASTIC 0.08 69
# ELASTIC 0.08 70
# ELASTIC 0.08 71
# ELASTIC 0.08 72
# ELASTIC 0.08 73
# ELASTIC 0.08 74
# ELASTIC 0.08 75
# ELASTIC 0.08 76
# ELASTIC 0.08 77
# ELASTIC 0.08 78
# ELASTIC 0.08 79
# ELASTIC 0.08 80
# ELASTIC 0.08 81
# ELASTIC 0.08 82
# ELASTIC 0.08 83
# ELASTIC 0.08 84
# ELASTIC 0.08 85
# ELASTIC 0.08 86
# ELASTIC 0.08 87
# ELASTIC 0.08 88
# ELASTIC 0.08 89
# ELASTIC 0.08 90
# ELASTIC 0.08 91
# ELASTIC 0.08 92
# ELASTIC 0.08 93
# ELASTIC 0.08 94
# ELASTIC 0.08 95
# ELASTIC 0.08 96
# ELASTIC 0.08 97
# ELASTIC 0.08 98
# ELASTIC 0.08 99
# NEWT
# ELASTIC 0.08 0
# ELASTIC 0.08 1
# ELASTIC 0.08 2
# ELASTIC 0.08 3
# ELASTIC 0.08 4
# ELASTIC 0.08 5
# ELASTIC 0.08 6
# ELASTIC 0.08 7
# ELASTIC 0.08 8
# ELASTIC 0.08 9
# ELASTIC 0.08 10
# ELASTIC 0.08 11
# ELASTIC 0.08 12
# ELASTIC 0.08 13
# ELASTIC 0.08 14
# ELASTIC 0.08 15
# ELASTIC 0.08 16
# ELASTIC 0.08 17
# ELASTIC 0.08 18
# ELASTIC 0.08 19
# ELASTIC 0.08 20
# ELASTIC 0.08 21
# ELASTIC 0.08 22
# ELASTIC 0.08 23
# ELASTIC 0.08 24
# ELASTIC 0.08 25
# ELASTIC 0.08 26
# ELASTIC 0.08 27
# ELASTIC 0.08 28
# ELASTIC 0.08 29
# ELASTIC 0.08 30
# ELASTIC 0.08 31
# ELASTIC 0.08 32
# ELASTIC 0.08 33
# ELASTIC 0.08 34
# ELASTIC 0.08 35
# ELASTIC 0.08 36
# ELASTIC 0.08 37
# ELASTIC 0.08 38
# ELASTIC 0.08 39
# ELASTIC 0.08 40
# ELASTIC 0.08 41
# ELASTIC 0.08 42
# ELASTIC 0.08 43
# ELASTIC 0.08 44
# ELASTIC 0.08 45
# ELASTIC 0.08 46
# ELASTIC 0.08 47
# ELASTIC 0.08 48
# ELASTIC 0.08 49
# ELASTIC 0.08 50
# ELASTIC 0.08 51
# ELASTIC 0.08 52
# ELASTIC 0.08 53
# ELASTIC 0.08 54
# ELASTIC 0.08 55
# ELASTIC 0.08 56
# ELASTIC 0.08 57
# ELASTIC 0.08 58
# ELASTIC 0.08 59
# ELASTIC 0.08 60
# ELASTIC 0.08 61
# ELASTIC 0.08 62
# ELASTIC 0.08 63
# ELASTIC 0.08 64
# ELASTIC 0.08 65
# ELASTIC 0.08 66
# ELASTIC 0.08 67
# ELASTIC 0.08 68
# ELASTIC 0.08 69
# ELASTIC 0.08 70
# ELASTIC 0.08 71
# ELASTIC 0.08 72
# ELASTIC 0.08 73
# ELASTIC 0.08 74
# ELASTIC 0.08 75
# ELASTIC 0.08 76
# ELASTIC 0.08 77
# ELASTIC 0.08 78
# ELASTIC 0.08 79
# ELASTIC 0.08 80
# ELASTIC 0.08 81
# ELASTIC 0.08 82
# ELASTIC 0.08 83
# ELASTIC 0.08 84
# ELASTIC 0.08 85
# ELASTIC 0.08 86
# ELASTIC 0.08 87
# ELASTIC 0.08 88
# ELASTIC 0.08 89
# ELASTIC 0.08 90
# ELASTIC 0.08 91
# ELASTIC 0.08 92
# ELASTIC 0.08 93
# ELASTIC 0.08 94
# ELASTIC 0.08 95
# ELASTIC 0.08 96
# ELASTIC 0.08 97
# ELASTIC 0.08 98
# ELASTIC 0.08 99
# NEWT
# ELASTIC 0.08 0
# ELASTIC 0.08 1
# ELASTIC 0.08 2
# ELASTIC 0.08 3
# ELASTIC 0.08 4
# ELASTIC 0.08 5
# ELASTIC 0.08 6
# ELASTIC 0.08 7
# ELASTIC 0.08 8
# ELASTIC 0.08 9
# ELASTIC 0.08 10
# ELASTIC 0.08 11
# ELASTIC 0.08 12
# ELASTIC 0.08 13
# ELASTIC 0.08 14
# ELASTIC 0.08 15
# ELASTIC 0.08 16
# ELASTIC 0.08 17
# ELASTIC 0.08 18
# ELASTIC 0.08 19
# ELASTIC 0.08 20
# ELASTIC 0.08 21
# ELASTIC 0.08 22
# ELASTIC 0.08 23
# ELASTIC 0.08 24
# ELASTIC 0.08 25
# ELASTIC 0.08 26
# ELASTIC 0.08 27
# ELASTIC 0.08 28
# ELASTIC 0.08 29
# ELASTIC 0.08 30
# ELASTIC 0.08 31
# ELASTIC 0.08 32
# ELASTIC 0.08 33
# ELASTIC 0.08 34
# ELASTIC 0.08 35
# ELASTIC 0.08 36
# ELASTIC 0.08 37
# ELASTIC 0.08 38
# ELASTIC 0.08 39
# ELASTIC 0.08 40
# ELASTIC 0.08 41
# ELASTIC 0.08 42
# ELASTIC 0.08 43
# ELASTIC 0.08 44
# ELASTIC 0.08 45
# ELASTIC 0.08 46
# ELASTIC 0.08 47
# ELASTIC 0.08 48
# ELASTIC 0.08 49
# ELASTIC 0.08 50
# ELASTIC 0.08 51
# ELASTIC 0.08 52
# ELASTIC 0.08 53
# ELASTIC 0.08 54
# ELASTIC 0.08 55
# ELASTIC 0.08 56
# ELASTIC 0.08 57
# ELASTIC 0.08 58
# ELASTIC 0.08 59
# ELASTIC 0.08 60
# ELASTIC 0.08 61
# ELASTIC 0.08 62
# ELASTIC 0.08 63
# ELASTIC 0.08 64
# ELASTIC 0.08 65
# ELASTIC 0.08 66
# ELASTIC 0.08 67
# ELASTIC 0.08 68
# ELASTIC 0.08 69
# ELASTIC 0.08 70
# ELASTIC 0.08 71
# ELASTIC 0.08 72
# ELASTIC 0.08 73
# ...
# ELASTIC 0.9600000000000001 70
# ELASTIC 0.9600000000000001 71
# ELASTIC 0.9600000000000001 72
# ELASTIC 0.9600000000000001 73
# ELASTIC 0.9600000000000001 74
# ELASTIC 0.9600000000000001 75
# ELASTIC 0.9600000000000001 76
# ELASTIC 0.9600000000000001 77
# ELASTIC 0.9600000000000001 78
# ELASTIC 0.9600000000000001 79
# ELASTIC 0.9600000000000001 80
# ELASTIC 0.9600000000000001 81
# ELASTIC 0.9600000000000001 82
# ELASTIC 0.9600000000000001 83
# ELASTIC 0.9600000000000001 84
# ELASTIC 0.9600000000000001 85
# ELASTIC 0.9600000000000001 86
# ELASTIC 0.9600000000000001 87
# ELASTIC 0.9600000000000001 88
# ELASTIC 0.9600000000000001 89
# ELASTIC 0.9600000000000001 90
# ELASTIC 0.9600000000000001 91
# ELASTIC 0.9600000000000001 92
# ELASTIC 0.9600000000000001 93
# ELASTIC 0.9600000000000001 94
# ELASTIC 0.9600000000000001 95
# ELASTIC 0.9600000000000001 96
# ELASTIC 0.9600000000000001 97
# ELASTIC 0.9600000000000001 98
# ELASTIC 0.9600000000000001 99
# 97 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.97 0
# ELASTIC 0.97 1
# PLASTIC 0.97 2
# PLASTIC 0.97 3
# PLASTIC 0.97 4
# ELASTIC 0.97 5
# PLASTIC 0.97 6
# ELASTIC 0.97 7
# PLASTIC 0.97 8
# PLASTIC 0.97 9
# ELASTIC 0.97 10
# PLASTIC 0.97 11
# PLASTIC 0.97 12
# PLASTIC 0.97 13
# PLASTIC 0.97 14
# ELASTIC 0.97 15
# PLASTIC 0.97 16
# PLASTIC 0.97 17
# ELASTIC 0.97 18
# ELASTIC 0.97 19
# ELASTIC 0.97 20
# ELASTIC 0.97 21
# ELASTIC 0.97 22
# ELASTIC 0.97 23
# ELASTIC 0.97 24
# ELASTIC 0.97 25
# ELASTIC 0.97 26
# PLASTIC 0.97 27
# ELASTIC 0.97 28
# ELASTIC 0.97 29
# ELASTIC 0.97 30
# ELASTIC 0.97 31
# ELASTIC 0.97 32
# ELASTIC 0.97 33
# ELASTIC 0.97 34
# ELASTIC 0.97 35
# ELASTIC 0.97 36
# ELASTIC 0.97 37
# ELASTIC 0.97 38
# ELASTIC 0.97 39
# ELASTIC 0.97 40
# ELASTIC 0.97 41
# ELASTIC 0.97 42
# ELASTIC 0.97 43
# ELASTIC 0.97 44
# ELASTIC 0.97 45
# ELASTIC 0.97 46
# ELASTIC 0.97 47
# ELASTIC 0.97 48
# ELASTIC 0.97 49
# ELASTIC 0.97 50
# ELASTIC 0.97 51
# ELASTIC 0.97 52
# ELASTIC 0.97 53
# ELASTIC 0.97 54
# ELASTIC 0.97 55
# ELASTIC 0.97 56
# ELASTIC 0.97 57
# ELASTIC 0.97 58
# ELASTIC 0.97 59
# ELASTIC 0.97 60
# ELASTIC 0.97 61
# ELASTIC 0.97 62
# ELASTIC 0.97 63
# ELASTIC 0.97 64
# ELASTIC 0.97 65
# ELASTIC 0.97 66
# ELASTIC 0.97 67
# ELASTIC 0.97 68
# ELASTIC 0.97 69
# ELASTIC 0.97 70
# ELASTIC 0.97 71
# ELASTIC 0.97 72
# ELASTIC 0.97 73
# ELASTIC 0.97 74
# ELASTIC 0.97 75
# ELASTIC 0.97 76
# ELASTIC 0.97 77
# ELASTIC 0.97 78
# ELASTIC 0.97 79
# ELASTIC 0.97 80
# ELASTIC 0.97 81
# ELASTIC 0.97 82
# ELASTIC 0.97 83
# ELASTIC 0.97 84
# ELASTIC 0.97 85
# ELASTIC 0.97 86
# ELASTIC 0.97 87
# ELASTIC 0.97 88
# ELASTIC 0.97 89
# ELASTIC 0.97 90
# ELASTIC 0.97 91
# ELASTIC 0.97 92
# ELASTIC 0.97 93
# ELASTIC 0.97 94
# ELASTIC 0.97 95
# ELASTIC 0.97 96
# ELASTIC 0.97 97
# ELASTIC 0.97 98
# ELASTIC 0.97 99
# NEWT
# ELASTIC 0.97 0
# PLASTIC 0.97 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.97 2
# PLASTIC 0.97 3
# PLASTIC 0.97 4
# PLASTIC 0.97 5
# PLASTIC 0.97 6
# PLASTIC 0.97 7
# PLASTIC 0.97 8
# PLASTIC 0.97 9
# PLASTIC 0.97 10
# PLASTIC 0.97 11
# PLASTIC 0.97 12
# PLASTIC 0.97 13
# PLASTIC 0.97 14
# PLASTIC 0.97 15
# PLASTIC 0.97 16
# PLASTIC 0.97 17
# PLASTIC 0.97 18
# PLASTIC 0.97 19
# PLASTIC 0.97 20
# PLASTIC 0.97 21
# PLASTIC 0.97 22
# PLASTIC 0.97 23
# PLASTIC 0.97 24
# PLASTIC 0.97 25
# PLASTIC 0.97 26
# PLASTIC 0.97 27
# PLASTIC 0.97 28
# PLASTIC 0.97 29
# ELASTIC 0.97 30
# ELASTIC 0.97 31
# ELASTIC 0.97 32
# ELASTIC 0.97 33
# ELASTIC 0.97 34
# ELASTIC 0.97 35
# ELASTIC 0.97 36
# ELASTIC 0.97 37
# ELASTIC 0.97 38
# ELASTIC 0.97 39
# ELASTIC 0.97 40
# ELASTIC 0.97 41
# ELASTIC 0.97 42
# ELASTIC 0.97 43
# ELASTIC 0.97 44
# ELASTIC 0.97 45
# ELASTIC 0.97 46
# ELASTIC 0.97 47
# ELASTIC 0.97 48
# ELASTIC 0.97 49
# ELASTIC 0.97 50
# ELASTIC 0.97 51
# ELASTIC 0.97 52
# ELASTIC 0.97 53
# ELASTIC 0.97 54
# ELASTIC 0.97 55
# ELASTIC 0.97 56
# ELASTIC 0.97 57
# ELASTIC 0.97 58
# ELASTIC 0.97 59
# ELASTIC 0.97 60
# ELASTIC 0.97 61
# ELASTIC 0.97 62
# ELASTIC 0.97 63
# ELASTIC 0.97 64
# ELASTIC 0.97 65
# ELASTIC 0.97 66
# ELASTIC 0.97 67
# ELASTIC 0.97 68
# ELASTIC 0.97 69
# ELASTIC 0.97 70
# ELASTIC 0.97 71
# ELASTIC 0.97 72
# ELASTIC 0.97 73
# ELASTIC 0.97 74
# ELASTIC 0.97 75
# ELASTIC 0.97 76
# ELASTIC 0.97 77
# ELASTIC 0.97 78
# ELASTIC 0.97 79
# ELASTIC 0.97 80
# ELASTIC 0.97 81
# ELASTIC 0.97 82
# ELASTIC 0.97 83
# ELASTIC 0.97 84
# ELASTIC 0.97 85
# ELASTIC 0.97 86
# ELASTIC 0.97 87
# ELASTIC 0.97 88
# ELASTIC 0.97 89
# ELASTIC 0.97 90
# ELASTIC 0.97 91
# ELASTIC 0.97 92
# ELASTIC 0.97 93
# ELASTIC 0.97 94
# ELASTIC 0.97 95
# ELASTIC 0.97 96
# ELASTIC 0.97 97
# ELASTIC 0.97 98
# ELASTIC 0.97 99
# NEWT
# ELASTIC 0.97 0
# PLASTIC 0.97 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.97 2
# PLASTIC 0.97 3
# PLASTIC 0.97 4
# PLASTIC 0.97 5
# PLASTIC 0.97 6
# PLASTIC 0.97 7
# PLASTIC 0.97 8
# PLASTIC 0.97 9
# PLASTIC 0.97 10
# PLASTIC 0.97 11
# PLASTIC 0.97 12
# PLASTIC 0.97 13
# PLASTIC 0.97 14
# PLASTIC 0.97 15
# PLASTIC 0.97 16
# PLASTIC 0.97 17
# PLASTIC 0.97 18
# PLASTIC 0.97 19
# PLASTIC 0.97 20
# PLASTIC 0.97 21
# PLASTIC 0.97 22
# PLASTIC 0.97 23
# PLASTIC 0.97 24
# PLASTIC 0.97 25
# PLASTIC 0.97 26
# PLASTIC 0.97 27
# PLASTIC 0.97 28
# PLASTIC 0.97 29
# ELASTIC 0.97 30
# ELASTIC 0.97 31
# ELASTIC 0.97 32
# ELASTIC 0.97 33
# ELASTIC 0.97 34
# ELASTIC 0.97 35
# ELASTIC 0.97 36
# ELASTIC 0.97 37
# ELASTIC 0.97 38
# ELASTIC 0.97 39
# ELASTIC 0.97 40
# ELASTIC 0.97 41
# ELASTIC 0.97 42
# ELASTIC 0.97 43
# ELASTIC 0.97 44
# ELASTIC 0.97 45
# ELASTIC 0.97 46
# ELASTIC 0.97 47
# ELASTIC 0.97 48
# ELASTIC 0.97 49
# ELASTIC 0.97 50
# ELASTIC 0.97 51
# ELASTIC 0.97 52
# ELASTIC 0.97 53
# ELASTIC 0.97 54
# ELASTIC 0.97 55
# ELASTIC 0.97 56
# ELASTIC 0.97 57
# ELASTIC 0.97 58
# ELASTIC 0.97 59
# ELASTIC 0.97 60
# ELASTIC 0.97 61
# ELASTIC 0.97 62
# ELASTIC 0.97 63
# ELASTIC 0.97 64
# ELASTIC 0.97 65
# ELASTIC 0.97 66
# ELASTIC 0.97 67
# ELASTIC 0.97 68
# ELASTIC 0.97 69
# ELASTIC 0.97 70
# ELASTIC 0.97 71
# ELASTIC 0.97 72
# ELASTIC 0.97 73
# ELASTIC 0.97 74
# ELASTIC 0.97 75
# ELASTIC 0.97 76
# ELASTIC 0.97 77
# ELASTIC 0.97 78
# ELASTIC 0.97 79
# ELASTIC 0.97 80
# ELASTIC 0.97 81
# ELASTIC 0.97 82
# ELASTIC 0.97 83
# ELASTIC 0.97 84
# ELASTIC 0.97 85
# ELASTIC 0.97 86
# ELASTIC 0.97 87
# ELASTIC 0.97 88
# ELASTIC 0.97 89
# ELASTIC 0.97 90
# ELASTIC 0.97 91
# ELASTIC 0.97 92
# ELASTIC 0.97 93
# ELASTIC 0.97 94
# ELASTIC 0.97 95
# ELASTIC 0.97 96
# ELASTIC 0.97 97
# ELASTIC 0.97 98
# ELASTIC 0.97 99
# 98 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.98 0
# ELASTIC 0.98 1
# PLASTIC 0.98 2
# PLASTIC 0.98 3
# PLASTIC 0.98 4
# ELASTIC 0.98 5
# PLASTIC 0.98 6
# ELASTIC 0.98 7
# PLASTIC 0.98 8
# PLASTIC 0.98 9
# ELASTIC 0.98 10
# PLASTIC 0.98 11
# PLASTIC 0.98 12
# PLASTIC 0.98 13
# PLASTIC 0.98 14
# ELASTIC 0.98 15
# PLASTIC 0.98 16
# PLASTIC 0.98 17
# ELASTIC 0.98 18
# ELASTIC 0.98 19
# ELASTIC 0.98 20
# ELASTIC 0.98 21
# ELASTIC 0.98 22
# ELASTIC 0.98 23
# ELASTIC 0.98 24
# ELASTIC 0.98 25
# ELASTIC 0.98 26
# PLASTIC 0.98 27
# ELASTIC 0.98 28
# ELASTIC 0.98 29
# ELASTIC 0.98 30
# ELASTIC 0.98 31
# ELASTIC 0.98 32
# ELASTIC 0.98 33
# ELASTIC 0.98 34
# ELASTIC 0.98 35
# ELASTIC 0.98 36
# ELASTIC 0.98 37
# ELASTIC 0.98 38
# ELASTIC 0.98 39
# ELASTIC 0.98 40
# ELASTIC 0.98 41
# ELASTIC 0.98 42
# ELASTIC 0.98 43
# ELASTIC 0.98 44
# ELASTIC 0.98 45
# ELASTIC 0.98 46
# ELASTIC 0.98 47
# ELASTIC 0.98 48
# ELASTIC 0.98 49
# ELASTIC 0.98 50
# ELASTIC 0.98 51
# ELASTIC 0.98 52
# ELASTIC 0.98 53
# ELASTIC 0.98 54
# ELASTIC 0.98 55
# ELASTIC 0.98 56
# ELASTIC 0.98 57
# ELASTIC 0.98 58
# ELASTIC 0.98 59
# ELASTIC 0.98 60
# ELASTIC 0.98 61
# ELASTIC 0.98 62
# ELASTIC 0.98 63
# ELASTIC 0.98 64
# ELASTIC 0.98 65
# ELASTIC 0.98 66
# ELASTIC 0.98 67
# ELASTIC 0.98 68
# ELASTIC 0.98 69
# ELASTIC 0.98 70
# ELASTIC 0.98 71
# ELASTIC 0.98 72
# ELASTIC 0.98 73
# ELASTIC 0.98 74
# ELASTIC 0.98 75
# ELASTIC 0.98 76
# ELASTIC 0.98 77
# ELASTIC 0.98 78
# ELASTIC 0.98 79
# ELASTIC 0.98 80
# ELASTIC 0.98 81
# ELASTIC 0.98 82
# ELASTIC 0.98 83
# ELASTIC 0.98 84
# ELASTIC 0.98 85
# ELASTIC 0.98 86
# ELASTIC 0.98 87
# ELASTIC 0.98 88
# ELASTIC 0.98 89
# ELASTIC 0.98 90
# ELASTIC 0.98 91
# ELASTIC 0.98 92
# ELASTIC 0.98 93
# ELASTIC 0.98 94
# ELASTIC 0.98 95
# ELASTIC 0.98 96
# ELASTIC 0.98 97
# ELASTIC 0.98 98
# ELASTIC 0.98 99
# NEWT
# ELASTIC 0.98 0
# PLASTIC 0.98 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.98 2
# PLASTIC 0.98 3
# PLASTIC 0.98 4
# PLASTIC 0.98 5
# PLASTIC 0.98 6
# PLASTIC 0.98 7
# PLASTIC 0.98 8
# PLASTIC 0.98 9
# PLASTIC 0.98 10
# PLASTIC 0.98 11
# PLASTIC 0.98 12
# PLASTIC 0.98 13
# PLASTIC 0.98 14
# PLASTIC 0.98 15
# PLASTIC 0.98 16
# PLASTIC 0.98 17
# PLASTIC 0.98 18
# PLASTIC 0.98 19
# PLASTIC 0.98 20
# PLASTIC 0.98 21
# PLASTIC 0.98 22
# PLASTIC 0.98 23
# PLASTIC 0.98 24
# PLASTIC 0.98 25
# PLASTIC 0.98 26
# PLASTIC 0.98 27
# PLASTIC 0.98 28
# PLASTIC 0.98 29
# ELASTIC 0.98 30
# ELASTIC 0.98 31
# ELASTIC 0.98 32
# ELASTIC 0.98 33
# ELASTIC 0.98 34
# ELASTIC 0.98 35
# ELASTIC 0.98 36
# ELASTIC 0.98 37
# ELASTIC 0.98 38
# ELASTIC 0.98 39
# ELASTIC 0.98 40
# ELASTIC 0.98 41
# ELASTIC 0.98 42
# ELASTIC 0.98 43
# ELASTIC 0.98 44
# ELASTIC 0.98 45
# ELASTIC 0.98 46
# ELASTIC 0.98 47
# ELASTIC 0.98 48
# ELASTIC 0.98 49
# ELASTIC 0.98 50
# ELASTIC 0.98 51
# ELASTIC 0.98 52
# ELASTIC 0.98 53
# ELASTIC 0.98 54
# ELASTIC 0.98 55
# ELASTIC 0.98 56
# ELASTIC 0.98 57
# ELASTIC 0.98 58
# ELASTIC 0.98 59
# ELASTIC 0.98 60
# ELASTIC 0.98 61
# ELASTIC 0.98 62
# ELASTIC 0.98 63
# ELASTIC 0.98 64
# ELASTIC 0.98 65
# ELASTIC 0.98 66
# ELASTIC 0.98 67
# ELASTIC 0.98 68
# ELASTIC 0.98 69
# ELASTIC 0.98 70
# ELASTIC 0.98 71
# ELASTIC 0.98 72
# ELASTIC 0.98 73
# ELASTIC 0.98 74
# ELASTIC 0.98 75
# ELASTIC 0.98 76
# ELASTIC 0.98 77
# ELASTIC 0.98 78
# ELASTIC 0.98 79
# ELASTIC 0.98 80
# ELASTIC 0.98 81
# ELASTIC 0.98 82
# ELASTIC 0.98 83
# ELASTIC 0.98 84
# ELASTIC 0.98 85
# ELASTIC 0.98 86
# ELASTIC 0.98 87
# ELASTIC 0.98 88
# ELASTIC 0.98 89
# ELASTIC 0.98 90
# ELASTIC 0.98 91
# ELASTIC 0.98 92
# ELASTIC 0.98 93
# ELASTIC 0.98 94
# ELASTIC 0.98 95
# ELASTIC 0.98 96
# ELASTIC 0.98 97
# ELASTIC 0.98 98
# ELASTIC 0.98 99
# NEWT
# ELASTIC 0.98 0
# PLASTIC 0.98 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.98 2
# PLASTIC 0.98 3
# PLASTIC 0.98 4
# PLASTIC 0.98 5
# PLASTIC 0.98 6
# PLASTIC 0.98 7
# PLASTIC 0.98 8
# PLASTIC 0.98 9
# PLASTIC 0.98 10
# PLASTIC 0.98 11
# PLASTIC 0.98 12
# PLASTIC 0.98 13
# PLASTIC 0.98 14
# PLASTIC 0.98 15
# PLASTIC 0.98 16
# PLASTIC 0.98 17
# PLASTIC 0.98 18
# PLASTIC 0.98 19
# PLASTIC 0.98 20
# PLASTIC 0.98 21
# PLASTIC 0.98 22
# PLASTIC 0.98 23
# PLASTIC 0.98 24
# PLASTIC 0.98 25
# PLASTIC 0.98 26
# PLASTIC 0.98 27
# PLASTIC 0.98 28
# PLASTIC 0.98 29
# ELASTIC 0.98 30
# ELASTIC 0.98 31
# ELASTIC 0.98 32
# ELASTIC 0.98 33
# ELASTIC 0.98 34
# ELASTIC 0.98 35
# ELASTIC 0.98 36
# ELASTIC 0.98 37
# ELASTIC 0.98 38
# ELASTIC 0.98 39
# ELASTIC 0.98 40
# ELASTIC 0.98 41
# ELASTIC 0.98 42
# ELASTIC 0.98 43
# ELASTIC 0.98 44
# ELASTIC 0.98 45
# ELASTIC 0.98 46
# ELASTIC 0.98 47
# ELASTIC 0.98 48
# ELASTIC 0.98 49
# ELASTIC 0.98 50
# ELASTIC 0.98 51
# ELASTIC 0.98 52
# ELASTIC 0.98 53
# ELASTIC 0.98 54
# ELASTIC 0.98 55
# ELASTIC 0.98 56
# ELASTIC 0.98 57
# ELASTIC 0.98 58
# ELASTIC 0.98 59
# ELASTIC 0.98 60
# ELASTIC 0.98 61
# ELASTIC 0.98 62
# ELASTIC 0.98 63
# ELASTIC 0.98 64
# ELASTIC 0.98 65
# ELASTIC 0.98 66
# ELASTIC 0.98 67
# ELASTIC 0.98 68
# ELASTIC 0.98 69
# ELASTIC 0.98 70
# ELASTIC 0.98 71
# ELASTIC 0.98 72
# ELASTIC 0.98 73
# ELASTIC 0.98 74
# ELASTIC 0.98 75
# ELASTIC 0.98 76
# ELASTIC 0.98 77
# ELASTIC 0.98 78
# ELASTIC 0.98 79
# ELASTIC 0.98 80
# ELASTIC 0.98 81
# ELASTIC 0.98 82
# ELASTIC 0.98 83
# ELASTIC 0.98 84
# ELASTIC 0.98 85
# ELASTIC 0.98 86
# ELASTIC 0.98 87
# ELASTIC 0.98 88
# ELASTIC 0.98 89
# ELASTIC 0.98 90
# ELASTIC 0.98 91
# ELASTIC 0.98 92
# ELASTIC 0.98 93
# ELASTIC 0.98 94
# ELASTIC 0.98 95
# ELASTIC 0.98 96
# ELASTIC 0.98 97
# ELASTIC 0.98 98
# ELASTIC 0.98 99
# 99 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.99 0
# ELASTIC 0.99 1
# PLASTIC 0.99 2
# PLASTIC 0.99 3
# PLASTIC 0.99 4
# ELASTIC 0.99 5
# PLASTIC 0.99 6
# ELASTIC 0.99 7
# PLASTIC 0.99 8
# PLASTIC 0.99 9
# ELASTIC 0.99 10
# PLASTIC 0.99 11
# PLASTIC 0.99 12
# PLASTIC 0.99 13
# PLASTIC 0.99 14
# ELASTIC 0.99 15
# PLASTIC 0.99 16
# PLASTIC 0.99 17
# ELASTIC 0.99 18
# ELASTIC 0.99 19
# ELASTIC 0.99 20
# ELASTIC 0.99 21
# ELASTIC 0.99 22
# ELASTIC 0.99 23
# ELASTIC 0.99 24
# ELASTIC 0.99 25
# ELASTIC 0.99 26
# PLASTIC 0.99 27
# ELASTIC 0.99 28
# ELASTIC 0.99 29
# ELASTIC 0.99 30
# ELASTIC 0.99 31
# ELASTIC 0.99 32
# ELASTIC 0.99 33
# ELASTIC 0.99 34
# ELASTIC 0.99 35
# ELASTIC 0.99 36
# ELASTIC 0.99 37
# ELASTIC 0.99 38
# ELASTIC 0.99 39
# ELASTIC 0.99 40
# ELASTIC 0.99 41
# ELASTIC 0.99 42
# ELASTIC 0.99 43
# ELASTIC 0.99 44
# ELASTIC 0.99 45
# ELASTIC 0.99 46
# ELASTIC 0.99 47
# ELASTIC 0.99 48
# ELASTIC 0.99 49
# ELASTIC 0.99 50
# ELASTIC 0.99 51
# ELASTIC 0.99 52
# ELASTIC 0.99 53
# ELASTIC 0.99 54
# ELASTIC 0.99 55
# ELASTIC 0.99 56
# ELASTIC 0.99 57
# ELASTIC 0.99 58
# ELASTIC 0.99 59
# ELASTIC 0.99 60
# ELASTIC 0.99 61
# ELASTIC 0.99 62
# ELASTIC 0.99 63
# ELASTIC 0.99 64
# ELASTIC 0.99 65
# ELASTIC 0.99 66
# ELASTIC 0.99 67
# ELASTIC 0.99 68
# ELASTIC 0.99 69
# ELASTIC 0.99 70
# ELASTIC 0.99 71
# ELASTIC 0.99 72
# ELASTIC 0.99 73
# ELASTIC 0.99 74
# ELASTIC 0.99 75
# ELASTIC 0.99 76
# ELASTIC 0.99 77
# ELASTIC 0.99 78
# ELASTIC 0.99 79
# ELASTIC 0.99 80
# ELASTIC 0.99 81
# ELASTIC 0.99 82
# ELASTIC 0.99 83
# ELASTIC 0.99 84
# ELASTIC 0.99 85
# ELASTIC 0.99 86
# ELASTIC 0.99 87
# ELASTIC 0.99 88
# ELASTIC 0.99 89
# ELASTIC 0.99 90
# ELASTIC 0.99 91
# ELASTIC 0.99 92
# ELASTIC 0.99 93
# ELASTIC 0.99 94
# ELASTIC 0.99 95
# ELASTIC 0.99 96
# ELASTIC 0.99 97
# ELASTIC 0.99 98
# ELASTIC 0.99 99
# NEWT
# ELASTIC 0.99 0
# PLASTIC 0.99 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.99 2
# PLASTIC 0.99 3
# PLASTIC 0.99 4
# PLASTIC 0.99 5
# PLASTIC 0.99 6
# PLASTIC 0.99 7
# PLASTIC 0.99 8
# PLASTIC 0.99 9
# PLASTIC 0.99 10
# PLASTIC 0.99 11
# PLASTIC 0.99 12
# PLASTIC 0.99 13
# PLASTIC 0.99 14
# PLASTIC 0.99 15
# PLASTIC 0.99 16
# PLASTIC 0.99 17
# PLASTIC 0.99 18
# PLASTIC 0.99 19
# PLASTIC 0.99 20
# PLASTIC 0.99 21
# PLASTIC 0.99 22
# PLASTIC 0.99 23
# PLASTIC 0.99 24
# PLASTIC 0.99 25
# PLASTIC 0.99 26
# PLASTIC 0.99 27
# PLASTIC 0.99 28
# PLASTIC 0.99 29
# ELASTIC 0.99 30
# ELASTIC 0.99 31
# ELASTIC 0.99 32
# ELASTIC 0.99 33
# ELASTIC 0.99 34
# ELASTIC 0.99 35
# ELASTIC 0.99 36
# ELASTIC 0.99 37
# ELASTIC 0.99 38
# ELASTIC 0.99 39
# ELASTIC 0.99 40
# ELASTIC 0.99 41
# ELASTIC 0.99 42
# ELASTIC 0.99 43
# ELASTIC 0.99 44
# ELASTIC 0.99 45
# ELASTIC 0.99 46
# ELASTIC 0.99 47
# ELASTIC 0.99 48
# ELASTIC 0.99 49
# ELASTIC 0.99 50
# ELASTIC 0.99 51
# ELASTIC 0.99 52
# ELASTIC 0.99 53
# ELASTIC 0.99 54
# ELASTIC 0.99 55
# ELASTIC 0.99 56
# ELASTIC 0.99 57
# ELASTIC 0.99 58
# ELASTIC 0.99 59
# ELASTIC 0.99 60
# ELASTIC 0.99 61
# ELASTIC 0.99 62
# ELASTIC 0.99 63
# ELASTIC 0.99 64
# ELASTIC 0.99 65
# ELASTIC 0.99 66
# ELASTIC 0.99 67
# ELASTIC 0.99 68
# ELASTIC 0.99 69
# ELASTIC 0.99 70
# ELASTIC 0.99 71
# ELASTIC 0.99 72
# ELASTIC 0.99 73
# ELASTIC 0.99 74
# ELASTIC 0.99 75
# ELASTIC 0.99 76
# ELASTIC 0.99 77
# ELASTIC 0.99 78
# ELASTIC 0.99 79
# ELASTIC 0.99 80
# ELASTIC 0.99 81
# ELASTIC 0.99 82
# ELASTIC 0.99 83
# ELASTIC 0.99 84
# ELASTIC 0.99 85
# ELASTIC 0.99 86
# ELASTIC 0.99 87
# ELASTIC 0.99 88
# ELASTIC 0.99 89
# ELASTIC 0.99 90
# ELASTIC 0.99 91
# ELASTIC 0.99 92
# ELASTIC 0.99 93
# ELASTIC 0.99 94
# ELASTIC 0.99 95
# ELASTIC 0.99 96
# ELASTIC 0.99 97
# ELASTIC 0.99 98
# ELASTIC 0.99 99
# NEWT
# ELASTIC 0.99 0
# PLASTIC 0.99 1
# PLASTIC INITIATION----------------------------------------------------
# PLASTIC 0.99 2
# PLASTIC 0.99 3
# PLASTIC 0.99 4
# PLASTIC 0.99 5
# PLASTIC 0.99 6
# PLASTIC 0.99 7
# PLASTIC 0.99 8
# PLASTIC 0.99 9
# PLASTIC 0.99 10
# PLASTIC 0.99 11
# PLASTIC 0.99 12
# PLASTIC 0.99 13
# PLASTIC 0.99 14
# PLASTIC 0.99 15
# PLASTIC 0.99 16
# PLASTIC 0.99 17
# PLASTIC 0.99 18
# PLASTIC 0.99 19
# PLASTIC 0.99 20
# PLASTIC 0.99 21
# PLASTIC 0.99 22
# PLASTIC 0.99 23
# PLASTIC 0.99 24
# PLASTIC 0.99 25
# PLASTIC 0.99 26
# PLASTIC 0.99 27
# PLASTIC 0.99 28
# PLASTIC 0.99 29
# ELASTIC 0.99 30
# ELASTIC 0.99 31
# ELASTIC 0.99 32
# ELASTIC 0.99 33
# ELASTIC 0.99 34
# ELASTIC 0.99 35
# ELASTIC 0.99 36
# ELASTIC 0.99 37
# ELASTIC 0.99 38
# ELASTIC 0.99 39
# ELASTIC 0.99 40
# ELASTIC 0.99 41
# ELASTIC 0.99 42
# ELASTIC 0.99 43
# ELASTIC 0.99 44
# ELASTIC 0.99 45
# ELASTIC 0.99 46
# ELASTIC 0.99 47
# ELASTIC 0.99 48
# ELASTIC 0.99 49
# ELASTIC 0.99 50
# ELASTIC 0.99 51
# ELASTIC 0.99 52
# ELASTIC 0.99 53
# ELASTIC 0.99 54
# ELASTIC 0.99 55
# ELASTIC 0.99 56
# ELASTIC 0.99 57
# ELASTIC 0.99 58
# ELASTIC 0.99 59
# ELASTIC 0.99 60
# ELASTIC 0.99 61
# ELASTIC 0.99 62
# ELASTIC 0.99 63
# ELASTIC 0.99 64
# ELASTIC 0.99 65
# ELASTIC 0.99 66
# ELASTIC 0.99 67
# ELASTIC 0.99 68
# ELASTIC 0.99 69
# ELASTIC 0.99 70
# ELASTIC 0.99 71
# ELASTIC 0.99 72
# ELASTIC 0.99 73
# ELASTIC 0.99 74
# ELASTIC 0.99 75
# ELASTIC 0.99 76
# ELASTIC 0.99 77
# ELASTIC 0.99 78
# ELASTIC 0.99 79
# ELASTIC 0.99 80
# ELASTIC 0.99 81
# ELASTIC 0.99 82
# ELASTIC 0.99 83
# ELASTIC 0.99 84
# ELASTIC 0.99 85
# ELASTIC 0.99 86
# ELASTIC 0.99 87
# ELASTIC 0.99 88
# ELASTIC 0.99 89
# ELASTIC 0.99 90
# ELASTIC 0.99 91
# ELASTIC 0.99 92
# ELASTIC 0.99 93
# ELASTIC 0.99 94
# ELASTIC 0.99 95
# ELASTIC 0.99 96
# ELASTIC 0.99 97
# ELASTIC 0.99 98
# ELASTIC 0.99 99
