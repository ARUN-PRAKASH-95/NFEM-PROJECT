# %%
import numpy as np
import matplotlib.pyplot as plt

step = 0.01
t=np.arange(step,1,step)

poissons_ratio = 0.2
E = 0.2 
mu = E/(2*(1+poissons_ratio))
Lambda=poissons_ratio*E/((1-2*poissons_ratio)*(1+poissons_ratio))
volumetric_strain = -0.01
yield_stress = 200e-6 #N/micromm^2

# Mesh generation
Inner_radius = 5
Outer_radius = 20
n=10
meshrefinementfactor = 5
q=meshrefinementfactor**(1/(n-1))

l=(Outer_radius-Inner_radius)*(1-q)/(1-meshrefinementfactor*q)
rnode=Inner_radius
coordinate=np.array([Inner_radius])

for i in range(n):
        rnode=rnode+l
        coordinate=np.append(coordinate,rnode)
        l=l*q



C = np.array([[Lambda+2*mu,Lambda,Lambda],
              [Lambda,Lambda+2*mu,Lambda],
              [Lambda,Lambda,Lambda+2*mu]])

#Tangent stiffness parameters
a=np.eye(3)
c=np.outer(a,a)
Kay = 3*Lambda+2*mu
b=np.eye(9)
d=np.zeros((9,9))
d[0,0]=1; d[1,3]=1;d[2,6]=1;d[3,1]=1;d[4,4]=1;d[5,7]=1;d[6,2]=1;d[7,5]=1;d[8,8]=1
I = (1/2*(b+d))-(1/3*c)


Global_F_ext = np.zeros((n+1,1))
Global_plastic_strain = np.zeros((n,3,1))
Global_displacement = np.zeros((n+1,1)) 
Reduced_displacement = np.delete(Global_displacement,(0),axis=0)


for time,tau in enumerate(t):
    Global_displacement[0]=1/3*tau*(-volumetric_strain)*Inner_radius
    print((time+1),''+'-'*100)
    delta_u = np.array([1,1])
    G_red = np.array([1,1])
    Global_F_int = np.array([1,1])
    plastic_strain = np.zeros((n,3,1))
    stress=np.zeros_like(coordinate)
    while np.linalg.norm(delta_u,np.inf)>(0.005*np.linalg.norm(Reduced_displacement,np.inf)) or np.linalg.norm(G_red,np.inf)>(0.005*np.linalg.norm(Global_F_int,np.inf)) :
        Global_K = np.zeros((n+1,n+1))
        Global_F_int= np.zeros((n+1,1))
        print("NEWT")
        for i in range(len(coordinate)-1):

            def element_routine(coordinate,Lambda,mu,tau):
                Derivative_N = np.array([-1/2,1/2])
                Jacobian = Derivative_N@np.array([[coordinate[i]],
                                                  [coordinate[i+1]]])
                J_inv = np.asscalar(1/Jacobian)

                B = np.array([[-1/2*J_inv,1/2*J_inv],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])]])
                B_T = np.transpose(B)
                C_matrix,I_stress = material_routine(coordinate)
                Element_stiffness = 2*(B_T@C_matrix@B)*Jacobian*((coordinate[i]+coordinate[i+1])/2)**2
                Internal_force = 2*(B_T@I_stress)*Jacobian*((coordinate[i]+coordinate[i+1])/2)**2
                return Element_stiffness,Internal_force
            


            def material_routine(coordinate):
                Derivative_N = np.array([-1/2,1/2])
                Jacobian = Derivative_N@np.array([[coordinate[i]],
                                                  [coordinate[i+1]]])
                J_inv = np.asscalar(1/Jacobian)

                B_matrix = np.array([[-1/2*J_inv,1/2*J_inv],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])],
                              [1/(coordinate[i]+coordinate[i+1]),1/(coordinate[i]+coordinate[i+1])]])
           
                Current_strain = B_matrix@np.array([Global_displacement[i],Global_displacement[i+1]]) 
                Trial_stress = C@(Current_strain - Global_plastic_strain[i])
                Trial_dev = Trial_stress - 1/3*np.sum(Trial_stress)
                Trial_eq = np.sqrt(3/2*(np.sum(np.square(Trial_dev))))
                dev_tensor = np.diagflat(Trial_dev)
                dev_outer = np.outer(dev_tensor,dev_tensor)

                if Trial_eq - yield_stress < 0:
                    stress[i]=np.asscalar(Trial_stress[1])
                    print('ELASTIC',tau,i)
                    return C,Trial_stress
                else:
                    del_lamda = (Trial_eq - yield_stress)/(3*mu)
                    print('PLASTIC',tau,i)
                    plastic_strain[i] = Global_plastic_strain[i] + del_lamda * 1.5 * (Trial_dev/Trial_eq)
                    new_stress = C@(Current_strain-plastic_strain[i])
                    stress[i]=np.asscalar(new_stress[1])
                    new_dev = new_stress - 1/3*np.sum(new_stress)
                    new_eq = np.sqrt(3/2*(np.sum(np.square(new_dev))))
                    tangent_stiffness = Kay/3*(c)+2*mu*((Trial_eq-3*mu*del_lamda)/Trial_eq)*I-(3*mu*(1/Trial_eq**2)*dev_outer)
                    skip = tangent_stiffness[0::4]
                    C_t = skip[np.nonzero(skip)].reshape(3,3)
                    return C_t,new_stress

            Ke,Fe_int = element_routine(coordinate,Lambda,mu,tau)

            #Assignmnet matrix
            Ae = np.zeros((2,n+1))
            Ae[0,i]=1                                            # [0,n-1]=1 [1,n]=1
            Ae[1,i+1]  =1
            AeT = np.transpose(Ae)


            #Global stiffness matrix
            K=AeT@Ke@Ae                                          # Stiffness matrix  of each element after transformation
            Global_K = np.add(Global_K,K)  
            #Internal force
            F_int = AeT@Fe_int
            Global_F_int = np.add(Global_F_int,F_int)

        K_red = np.delete(Global_K,(0),axis=0)
        K_red = np.delete(K_red,(0),axis=1)

        #Newton Raphson method

        G_matrix = Global_F_int - Global_F_ext
        G_red = np.delete(G_matrix,(0),axis=0)
        delta_u = np.linalg.inv(K_red)@G_red
        Reduced_displacement = Reduced_displacement - delta_u
        Global_displacement = np.insert(Reduced_displacement,(0),(1/3*(tau)*(-volumetric_strain)*Inner_radius)).reshape(n+1,1)
        

    Global_plastic_strain=plastic_strain
    plt.plot(coordinate,stress)

print(stress)
# Out:
# 1 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.01 0
# ELASTIC 0.01 1
# ELASTIC 0.01 2
# ELASTIC 0.01 3
# ELASTIC 0.01 4
# ELASTIC 0.01 5
# ELASTIC 0.01 6
# ELASTIC 0.01 7
# ELASTIC 0.01 8
# ELASTIC 0.01 9
# NEWT
# ELASTIC 0.01 0
# ELASTIC 0.01 1
# ELASTIC 0.01 2
# ELASTIC 0.01 3
# ELASTIC 0.01 4
# ELASTIC 0.01 5
# ELASTIC 0.01 6
# ELASTIC 0.01 7
# ELASTIC 0.01 8
# ELASTIC 0.01 9
# 2 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.02 0
# ELASTIC 0.02 1
# ELASTIC 0.02 2
# ELASTIC 0.02 3
# ELASTIC 0.02 4
# ELASTIC 0.02 5
# ELASTIC 0.02 6
# ELASTIC 0.02 7
# ELASTIC 0.02 8
# ELASTIC 0.02 9
# NEWT
# ELASTIC 0.02 0
# ELASTIC 0.02 1
# ELASTIC 0.02 2
# ELASTIC 0.02 3
# ELASTIC 0.02 4
# ELASTIC 0.02 5
# ELASTIC 0.02 6
# ELASTIC 0.02 7
# ELASTIC 0.02 8
# ELASTIC 0.02 9
# 3 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.03 0
# ELASTIC 0.03 1
# ELASTIC 0.03 2
# ELASTIC 0.03 3
# ELASTIC 0.03 4
# ELASTIC 0.03 5
# ELASTIC 0.03 6
# ELASTIC 0.03 7
# ELASTIC 0.03 8
# ELASTIC 0.03 9
# NEWT
# ELASTIC 0.03 0
# ELASTIC 0.03 1
# ELASTIC 0.03 2
# ELASTIC 0.03 3
# ELASTIC 0.03 4
# ELASTIC 0.03 5
# ELASTIC 0.03 6
# ELASTIC 0.03 7
# ELASTIC 0.03 8
# ELASTIC 0.03 9
# 4 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.04 0
# ELASTIC 0.04 1
# ELASTIC 0.04 2
# ELASTIC 0.04 3
# ELASTIC 0.04 4
# ELASTIC 0.04 5
# ELASTIC 0.04 6
# ELASTIC 0.04 7
# ELASTIC 0.04 8
# ELASTIC 0.04 9
# NEWT
# ELASTIC 0.04 0
# ELASTIC 0.04 1
# ELASTIC 0.04 2
# ELASTIC 0.04 3
# ELASTIC 0.04 4
# ELASTIC 0.04 5
# ELASTIC 0.04 6
# ELASTIC 0.04 7
# ELASTIC 0.04 8
# ELASTIC 0.04 9
# 5 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.05 0
# ELASTIC 0.05 1
# ELASTIC 0.05 2
# ELASTIC 0.05 3
# ELASTIC 0.05 4
# ELASTIC 0.05 5
# ELASTIC 0.05 6
# ELASTIC 0.05 7
# ELASTIC 0.05 8
# ELASTIC 0.05 9
# NEWT
# ELASTIC 0.05 0
# ELASTIC 0.05 1
# ELASTIC 0.05 2
# ELASTIC 0.05 3
# ELASTIC 0.05 4
# ELASTIC 0.05 5
# ELASTIC 0.05 6
# ELASTIC 0.05 7
# ELASTIC 0.05 8
# ELASTIC 0.05 9
# 6 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.060000000000000005 0
# ELASTIC 0.060000000000000005 1
# ELASTIC 0.060000000000000005 2
# ELASTIC 0.060000000000000005 3
# ELASTIC 0.060000000000000005 4
# ELASTIC 0.060000000000000005 5
# ELASTIC 0.060000000000000005 6
# ELASTIC 0.060000000000000005 7
# ELASTIC 0.060000000000000005 8
# ELASTIC 0.060000000000000005 9
# NEWT
# ELASTIC 0.060000000000000005 0
# ELASTIC 0.060000000000000005 1
# ELASTIC 0.060000000000000005 2
# ELASTIC 0.060000000000000005 3
# ELASTIC 0.060000000000000005 4
# ELASTIC 0.060000000000000005 5
# ELASTIC 0.060000000000000005 6
# ELASTIC 0.060000000000000005 7
# ELASTIC 0.060000000000000005 8
# ELASTIC 0.060000000000000005 9
# 7 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.06999999999999999 0
# ELASTIC 0.06999999999999999 1
# ELASTIC 0.06999999999999999 2
# ELASTIC 0.06999999999999999 3
# ELASTIC 0.06999999999999999 4
# ELASTIC 0.06999999999999999 5
# ELASTIC 0.06999999999999999 6
# ELASTIC 0.06999999999999999 7
# ELASTIC 0.06999999999999999 8
# ELASTIC 0.06999999999999999 9
# NEWT
# ELASTIC 0.06999999999999999 0
# ELASTIC 0.06999999999999999 1
# ELASTIC 0.06999999999999999 2
# ELASTIC 0.06999999999999999 3
# ELASTIC 0.06999999999999999 4
# ELASTIC 0.06999999999999999 5
# ELASTIC 0.06999999999999999 6
# ELASTIC 0.06999999999999999 7
# ELASTIC 0.06999999999999999 8
# ELASTIC 0.06999999999999999 9
# 8 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.08 0
# ELASTIC 0.08 1
# ELASTIC 0.08 2
# ELASTIC 0.08 3
# ELASTIC 0.08 4
# ELASTIC 0.08 5
# ELASTIC 0.08 6
# ELASTIC 0.08 7
# ELASTIC 0.08 8
# ELASTIC 0.08 9
# NEWT
# ELASTIC 0.08 0
# ELASTIC 0.08 1
# ELASTIC 0.08 2
# ELASTIC 0.08 3
# ELASTIC 0.08 4
# ELASTIC 0.08 5
# ELASTIC 0.08 6
# ELASTIC 0.08 7
# ELASTIC 0.08 8
# ELASTIC 0.08 9
# 9 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.09 0
# ELASTIC 0.09 1
# ELASTIC 0.09 2
# ELASTIC 0.09 3
# ELASTIC 0.09 4
# ELASTIC 0.09 5
# ELASTIC 0.09 6
# ELASTIC 0.09 7
# ELASTIC 0.09 8
# ELASTIC 0.09 9
# NEWT
# ELASTIC 0.09 0
# ELASTIC 0.09 1
# ELASTIC 0.09 2
# ELASTIC 0.09 3
# ELASTIC 0.09 4
# ELASTIC 0.09 5
# ELASTIC 0.09 6
# ELASTIC 0.09 7
# ELASTIC 0.09 8
# ELASTIC 0.09 9
# 10 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.09999999999999999 0
# ELASTIC 0.09999999999999999 1
# ELASTIC 0.09999999999999999 2
# ELASTIC 0.09999999999999999 3
# ELASTIC 0.09999999999999999 4
# ELASTIC 0.09999999999999999 5
# ELASTIC 0.09999999999999999 6
# ELASTIC 0.09999999999999999 7
# ELASTIC 0.09999999999999999 8
# ELASTIC 0.09999999999999999 9
# NEWT
# ELASTIC 0.09999999999999999 0
# ELASTIC 0.09999999999999999 1
# ELASTIC 0.09999999999999999 2
# ELASTIC 0.09999999999999999 3
# ELASTIC 0.09999999999999999 4
# ELASTIC 0.09999999999999999 5
# ELASTIC 0.09999999999999999 6
# ELASTIC 0.09999999999999999 7
# ELASTIC 0.09999999999999999 8
# ELASTIC 0.09999999999999999 9
# 11 ----------------------------------------------------------------------------------------------------
# NEWT
# ELASTIC 0.11 0
# ELASTIC 0.11 1
# ELASTIC 0.11 2
# ELASTIC 0.11 3
# ELASTIC 0.11 4
# ELASTIC 0.11 5
# ELASTIC 0.11 6
# ELASTIC 0.11 7
# ELASTIC 0.11 8
# ELASTIC 0.11 9
# NEWT
# ELASTIC 0.11 0
# ELASTIC 0.11 1
# ELASTIC 0.11 2
# ELASTIC 0.11 3
# ELASTIC 0.11 4
# ELASTIC 0.11 5
# ELASTIC 0.11 6
# ELASTIC 0.11 7
# ELASTIC 0.11 8
# ELASTIC 0.11 9
# 12 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.12 0
# ELASTIC 0.12 1
# ELASTIC 0.12 2
# ELASTIC 0.12 3
# ELASTIC 0.12 4
# ELASTIC 0.12 5
# ELASTIC 0.12 6
# ELASTIC 0.12 7
# ELASTIC 0.12 8
# ELASTIC 0.12 9
# NEWT
# ELASTIC 0.12 0
# ELASTIC 0.12 1
# ELASTIC 0.12 2
# ELASTIC 0.12 3
# ELASTIC 0.12 4
# ELASTIC 0.12 5
# ELASTIC 0.12 6
# ELASTIC 0.12 7
# ELASTIC 0.12 8
# ELASTIC 0.12 9
# NEWT
# ELASTIC 0.12 0
# ELASTIC 0.12 1
# ELASTIC 0.12 2
# ELASTIC 0.12 3
# ELASTIC 0.12 4
# ELASTIC 0.12 5
# ELASTIC 0.12 6
# ELASTIC 0.12 7
# ELASTIC 0.12 8
# ELASTIC 0.12 9
# 13 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.13 0
# ELASTIC 0.13 1
# ELASTIC 0.13 2
# ELASTIC 0.13 3
# ELASTIC 0.13 4
# ELASTIC 0.13 5
# ELASTIC 0.13 6
# ELASTIC 0.13 7
# ELASTIC 0.13 8
# ELASTIC 0.13 9
# NEWT
# ELASTIC 0.13 0
# ELASTIC 0.13 1
# ELASTIC 0.13 2
# ELASTIC 0.13 3
# ELASTIC 0.13 4
# ELASTIC 0.13 5
# ELASTIC 0.13 6
# ELASTIC 0.13 7
# ELASTIC 0.13 8
# ELASTIC 0.13 9
# NEWT
# ELASTIC 0.13 0
# ELASTIC 0.13 1
# ELASTIC 0.13 2
# ELASTIC 0.13 3
# ELASTIC 0.13 4
# ELASTIC 0.13 5
# ELASTIC 0.13 6
# ELASTIC 0.13 7
# ELASTIC 0.13 8
# ELASTIC 0.13 9
# 14 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.14 0
# ELASTIC 0.14 1
# ELASTIC 0.14 2
# ELASTIC 0.14 3
# ELASTIC 0.14 4
# ELASTIC 0.14 5
# ELASTIC 0.14 6
# ELASTIC 0.14 7
# ELASTIC 0.14 8
# ELASTIC 0.14 9
# NEWT
# ELASTIC 0.14 0
# ELASTIC 0.14 1
# ELASTIC 0.14 2
# ELASTIC 0.14 3
# ELASTIC 0.14 4
# ELASTIC 0.14 5
# ELASTIC 0.14 6
# ELASTIC 0.14 7
# ELASTIC 0.14 8
# ELASTIC 0.14 9
# NEWT
# ELASTIC 0.14 0
# ELASTIC 0.14 1
# ELASTIC 0.14 2
# ELASTIC 0.14 3
# ELASTIC 0.14 4
# ELASTIC 0.14 5
# ELASTIC 0.14 6
# ELASTIC 0.14 7
# ELASTIC 0.14 8
# ELASTIC 0.14 9
# 15 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.15000000000000002 0
# ELASTIC 0.15000000000000002 1
# ELASTIC 0.15000000000000002 2
# ELASTIC 0.15000000000000002 3
# ELASTIC 0.15000000000000002 4
# ELASTIC 0.15000000000000002 5
# ELASTIC 0.15000000000000002 6
# ELASTIC 0.15000000000000002 7
# ELASTIC 0.15000000000000002 8
# ELASTIC 0.15000000000000002 9
# NEWT
# ELASTIC 0.15000000000000002 0
# ELASTIC 0.15000000000000002 1
# ELASTIC 0.15000000000000002 2
# ELASTIC 0.15000000000000002 3
# ELASTIC 0.15000000000000002 4
# ELASTIC 0.15000000000000002 5
# ELASTIC 0.15000000000000002 6
# ELASTIC 0.15000000000000002 7
# ELASTIC 0.15000000000000002 8
# ELASTIC 0.15000000000000002 9
# NEWT
# ELASTIC 0.15000000000000002 0
# ELASTIC 0.15000000000000002 1
# ELASTIC 0.15000000000000002 2
# ELASTIC 0.15000000000000002 3
# ELASTIC 0.15000000000000002 4
# ELASTIC 0.15000000000000002 5
# ELASTIC 0.15000000000000002 6
# ELASTIC 0.15000000000000002 7
# ELASTIC 0.15000000000000002 8
# ELASTIC 0.15000000000000002 9
# 16 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.16 0
# ELASTIC 0.16 1
# ELASTIC 0.16 2
# ELASTIC 0.16 3
# ELASTIC 0.16 4
# ELASTIC 0.16 5
# ELASTIC 0.16 6
# ELASTIC 0.16 7
# ELASTIC 0.16 8
# ELASTIC 0.16 9
# NEWT
# ELASTIC 0.16 0
# ELASTIC 0.16 1
# ELASTIC 0.16 2
# ELASTIC 0.16 3
# ELASTIC 0.16 4
# ELASTIC 0.16 5
# ELASTIC 0.16 6
# ELASTIC 0.16 7
# ELASTIC 0.16 8
# ELASTIC 0.16 9
# NEWT
# ELASTIC 0.16 0
# ELASTIC 0.16 1
# ELASTIC 0.16 2
# ELASTIC 0.16 3
# ELASTIC 0.16 4
# ELASTIC 0.16 5
# ELASTIC 0.16 6
# ELASTIC 0.16 7
# ELASTIC 0.16 8
# ELASTIC 0.16 9
# 17 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.17 0
# ELASTIC 0.17 1
# ELASTIC 0.17 2
# ELASTIC 0.17 3
# ELASTIC 0.17 4
# ELASTIC 0.17 5
# ELASTIC 0.17 6
# ELASTIC 0.17 7
# ELASTIC 0.17 8
# ELASTIC 0.17 9
# NEWT
# ELASTIC 0.17 0
# ELASTIC 0.17 1
# ELASTIC 0.17 2
# ELASTIC 0.17 3
# ELASTIC 0.17 4
# ELASTIC 0.17 5
# ELASTIC 0.17 6
# ELASTIC 0.17 7
# ELASTIC 0.17 8
# ELASTIC 0.17 9
# NEWT
# ELASTIC 0.17 0
# ELASTIC 0.17 1
# ELASTIC 0.17 2
# ELASTIC 0.17 3
# ELASTIC 0.17 4
# ELASTIC 0.17 5
# ELASTIC 0.17 6
# ELASTIC 0.17 7
# ELASTIC 0.17 8
# ELASTIC 0.17 9
# 18 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.18000000000000002 0
# ELASTIC 0.18000000000000002 1
# ELASTIC 0.18000000000000002 2
# ELASTIC 0.18000000000000002 3
# ELASTIC 0.18000000000000002 4
# ELASTIC 0.18000000000000002 5
# ELASTIC 0.18000000000000002 6
# ELASTIC 0.18000000000000002 7
# ELASTIC 0.18000000000000002 8
# ELASTIC 0.18000000000000002 9
# NEWT
# ELASTIC 0.18000000000000002 0
# ELASTIC 0.18000000000000002 1
# ELASTIC 0.18000000000000002 2
# ELASTIC 0.18000000000000002 3
# ELASTIC 0.18000000000000002 4
# ELASTIC 0.18000000000000002 5
# ELASTIC 0.18000000000000002 6
# ELASTIC 0.18000000000000002 7
# ELASTIC 0.18000000000000002 8
# ELASTIC 0.18000000000000002 9
# NEWT
# ELASTIC 0.18000000000000002 0
# ELASTIC 0.18000000000000002 1
# ELASTIC 0.18000000000000002 2
# ELASTIC 0.18000000000000002 3
# ELASTIC 0.18000000000000002 4
# ELASTIC 0.18000000000000002 5
# ELASTIC 0.18000000000000002 6
# ELASTIC 0.18000000000000002 7
# ELASTIC 0.18000000000000002 8
# ELASTIC 0.18000000000000002 9
# 19 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.19 0
# ELASTIC 0.19 1
# ELASTIC 0.19 2
# ELASTIC 0.19 3
# ELASTIC 0.19 4
# ELASTIC 0.19 5
# ELASTIC 0.19 6
# ELASTIC 0.19 7
# ELASTIC 0.19 8
# ELASTIC 0.19 9
# NEWT
# ELASTIC 0.19 0
# ELASTIC 0.19 1
# ELASTIC 0.19 2
# ELASTIC 0.19 3
# ELASTIC 0.19 4
# ELASTIC 0.19 5
# ELASTIC 0.19 6
# ELASTIC 0.19 7
# ELASTIC 0.19 8
# ELASTIC 0.19 9
# NEWT
# ELASTIC 0.19 0
# ELASTIC 0.19 1
# ELASTIC 0.19 2
# ELASTIC 0.19 3
# ELASTIC 0.19 4
# ELASTIC 0.19 5
# ELASTIC 0.19 6
# ELASTIC 0.19 7
# ELASTIC 0.19 8
# ELASTIC 0.19 9
# 20 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.2 0
# ELASTIC 0.2 1
# ELASTIC 0.2 2
# ELASTIC 0.2 3
# ELASTIC 0.2 4
# ELASTIC 0.2 5
# ELASTIC 0.2 6
# ELASTIC 0.2 7
# ELASTIC 0.2 8
# ELASTIC 0.2 9
# NEWT
# ELASTIC 0.2 0
# ELASTIC 0.2 1
# ELASTIC 0.2 2
# ELASTIC 0.2 3
# ELASTIC 0.2 4
# ELASTIC 0.2 5
# ELASTIC 0.2 6
# ELASTIC 0.2 7
# ELASTIC 0.2 8
# ELASTIC 0.2 9
# NEWT
# ELASTIC 0.2 0
# ELASTIC 0.2 1
# ELASTIC 0.2 2
# ELASTIC 0.2 3
# ELASTIC 0.2 4
# ELASTIC 0.2 5
# ELASTIC 0.2 6
# ELASTIC 0.2 7
# ELASTIC 0.2 8
# ELASTIC 0.2 9
# 21 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.21000000000000002 0
# ELASTIC 0.21000000000000002 1
# ELASTIC 0.21000000000000002 2
# ELASTIC 0.21000000000000002 3
# ELASTIC 0.21000000000000002 4
# ELASTIC 0.21000000000000002 5
# ELASTIC 0.21000000000000002 6
# ELASTIC 0.21000000000000002 7
# ELASTIC 0.21000000000000002 8
# ELASTIC 0.21000000000000002 9
# NEWT
# ELASTIC 0.21000000000000002 0
# ELASTIC 0.21000000000000002 1
# ELASTIC 0.21000000000000002 2
# ELASTIC 0.21000000000000002 3
# ELASTIC 0.21000000000000002 4
# ELASTIC 0.21000000000000002 5
# ELASTIC 0.21000000000000002 6
# ELASTIC 0.21000000000000002 7
# ELASTIC 0.21000000000000002 8
# ELASTIC 0.21000000000000002 9
# NEWT
# ELASTIC 0.21000000000000002 0
# ELASTIC 0.21000000000000002 1
# ELASTIC 0.21000000000000002 2
# ELASTIC 0.21000000000000002 3
# ELASTIC 0.21000000000000002 4
# ELASTIC 0.21000000000000002 5
# ELASTIC 0.21000000000000002 6
# ELASTIC 0.21000000000000002 7
# ELASTIC 0.21000000000000002 8
# ELASTIC 0.21000000000000002 9
# 22 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.22 0
# ELASTIC 0.22 1
# ELASTIC 0.22 2
# ELASTIC 0.22 3
# ELASTIC 0.22 4
# ELASTIC 0.22 5
# ELASTIC 0.22 6
# ELASTIC 0.22 7
# ELASTIC 0.22 8
# ELASTIC 0.22 9
# NEWT
# ELASTIC 0.22 0
# PLASTIC 0.22 1
# ELASTIC 0.22 2
# ELASTIC 0.22 3
# ELASTIC 0.22 4
# ELASTIC 0.22 5
# ELASTIC 0.22 6
# ELASTIC 0.22 7
# ELASTIC 0.22 8
# ELASTIC 0.22 9
# NEWT
# ELASTIC 0.22 0
# ELASTIC 0.22 1
# ELASTIC 0.22 2
# ELASTIC 0.22 3
# ELASTIC 0.22 4
# ELASTIC 0.22 5
# ELASTIC 0.22 6
# ELASTIC 0.22 7
# ELASTIC 0.22 8
# ELASTIC 0.22 9
# 23 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.23 0
# ELASTIC 0.23 1
# ELASTIC 0.23 2
# ELASTIC 0.23 3
# ELASTIC 0.23 4
# ELASTIC 0.23 5
# ELASTIC 0.23 6
# ELASTIC 0.23 7
# ELASTIC 0.23 8
# ELASTIC 0.23 9
# NEWT
# ELASTIC 0.23 0
# PLASTIC 0.23 1
# ELASTIC 0.23 2
# ELASTIC 0.23 3
# ELASTIC 0.23 4
# ELASTIC 0.23 5
# ELASTIC 0.23 6
# ELASTIC 0.23 7
# ELASTIC 0.23 8
# ELASTIC 0.23 9
# NEWT
# ELASTIC 0.23 0
# PLASTIC 0.23 1
# ELASTIC 0.23 2
# ELASTIC 0.23 3
# ELASTIC 0.23 4
# ELASTIC 0.23 5
# ELASTIC 0.23 6
# ELASTIC 0.23 7
# ELASTIC 0.23 8
# ELASTIC 0.23 9
# 24 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.24000000000000002 0
# ELASTIC 0.24000000000000002 1
# ELASTIC 0.24000000000000002 2
# ELASTIC 0.24000000000000002 3
# ELASTIC 0.24000000000000002 4
# ELASTIC 0.24000000000000002 5
# ELASTIC 0.24000000000000002 6
# ELASTIC 0.24000000000000002 7
# ELASTIC 0.24000000000000002 8
# ELASTIC 0.24000000000000002 9
# NEWT
# ELASTIC 0.24000000000000002 0
# PLASTIC 0.24000000000000002 1
# ELASTIC 0.24000000000000002 2
# ELASTIC 0.24000000000000002 3
# ELASTIC 0.24000000000000002 4
# ELASTIC 0.24000000000000002 5
# ELASTIC 0.24000000000000002 6
# ELASTIC 0.24000000000000002 7
# ELASTIC 0.24000000000000002 8
# ELASTIC 0.24000000000000002 9
# NEWT
# ELASTIC 0.24000000000000002 0
# PLASTIC 0.24000000000000002 1
# ELASTIC 0.24000000000000002 2
# ELASTIC 0.24000000000000002 3
# ELASTIC 0.24000000000000002 4
# ELASTIC 0.24000000000000002 5
# ELASTIC 0.24000000000000002 6
# ELASTIC 0.24000000000000002 7
# ELASTIC 0.24000000000000002 8
# ELASTIC 0.24000000000000002 9
# 25 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.25 0
# ELASTIC 0.25 1
# ELASTIC 0.25 2
# ELASTIC 0.25 3
# ELASTIC 0.25 4
# ELASTIC 0.25 5
# ELASTIC 0.25 6
# ELASTIC 0.25 7
# ELASTIC 0.25 8
# ELASTIC 0.25 9
# NEWT
# ELASTIC 0.25 0
# PLASTIC 0.25 1
# ELASTIC 0.25 2
# ELASTIC 0.25 3
# ELASTIC 0.25 4
# ELASTIC 0.25 5
# ELASTIC 0.25 6
# ELASTIC 0.25 7
# ELASTIC 0.25 8
# ELASTIC 0.25 9
# NEWT
# ELASTIC 0.25 0
# PLASTIC 0.25 1
# ELASTIC 0.25 2
# ELASTIC 0.25 3
# ELASTIC 0.25 4
# ELASTIC 0.25 5
# ELASTIC 0.25 6
# ELASTIC 0.25 7
# ELASTIC 0.25 8
# ELASTIC 0.25 9
# 26 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.26 0
# ELASTIC 0.26 1
# ELASTIC 0.26 2
# ELASTIC 0.26 3
# ELASTIC 0.26 4
# ELASTIC 0.26 5
# ELASTIC 0.26 6
# ELASTIC 0.26 7
# ELASTIC 0.26 8
# ELASTIC 0.26 9
# NEWT
# ELASTIC 0.26 0
# PLASTIC 0.26 1
# ELASTIC 0.26 2
# ELASTIC 0.26 3
# ELASTIC 0.26 4
# ELASTIC 0.26 5
# ELASTIC 0.26 6
# ELASTIC 0.26 7
# ELASTIC 0.26 8
# ELASTIC 0.26 9
# NEWT
# ELASTIC 0.26 0
# PLASTIC 0.26 1
# ELASTIC 0.26 2
# ELASTIC 0.26 3
# ELASTIC 0.26 4
# ELASTIC 0.26 5
# ELASTIC 0.26 6
# ELASTIC 0.26 7
# ELASTIC 0.26 8
# ELASTIC 0.26 9
# 27 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.27 0
# ELASTIC 0.27 1
# ELASTIC 0.27 2
# ELASTIC 0.27 3
# ELASTIC 0.27 4
# ELASTIC 0.27 5
# ELASTIC 0.27 6
# ELASTIC 0.27 7
# ELASTIC 0.27 8
# ELASTIC 0.27 9
# NEWT
# ELASTIC 0.27 0
# PLASTIC 0.27 1
# ELASTIC 0.27 2
# ELASTIC 0.27 3
# ELASTIC 0.27 4
# ELASTIC 0.27 5
# ELASTIC 0.27 6
# ELASTIC 0.27 7
# ELASTIC 0.27 8
# ELASTIC 0.27 9
# NEWT
# ELASTIC 0.27 0
# PLASTIC 0.27 1
# ELASTIC 0.27 2
# ELASTIC 0.27 3
# ELASTIC 0.27 4
# ELASTIC 0.27 5
# ELASTIC 0.27 6
# ELASTIC 0.27 7
# ELASTIC 0.27 8
# ELASTIC 0.27 9
# 28 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.28 0
# ELASTIC 0.28 1
# ELASTIC 0.28 2
# ELASTIC 0.28 3
# ELASTIC 0.28 4
# ELASTIC 0.28 5
# ELASTIC 0.28 6
# ELASTIC 0.28 7
# ELASTIC 0.28 8
# ELASTIC 0.28 9
# NEWT
# ELASTIC 0.28 0
# PLASTIC 0.28 1
# ELASTIC 0.28 2
# ELASTIC 0.28 3
# ELASTIC 0.28 4
# ELASTIC 0.28 5
# ELASTIC 0.28 6
# ELASTIC 0.28 7
# ELASTIC 0.28 8
# ELASTIC 0.28 9
# NEWT
# ELASTIC 0.28 0
# PLASTIC 0.28 1
# ELASTIC 0.28 2
# ELASTIC 0.28 3
# ELASTIC 0.28 4
# ELASTIC 0.28 5
# ELASTIC 0.28 6
# ELASTIC 0.28 7
# ELASTIC 0.28 8
# ELASTIC 0.28 9
# 29 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.29000000000000004 0
# ELASTIC 0.29000000000000004 1
# ELASTIC 0.29000000000000004 2
# ELASTIC 0.29000000000000004 3
# ELASTIC 0.29000000000000004 4
# ELASTIC 0.29000000000000004 5
# ELASTIC 0.29000000000000004 6
# ELASTIC 0.29000000000000004 7
# ELASTIC 0.29000000000000004 8
# ELASTIC 0.29000000000000004 9
# NEWT
# ELASTIC 0.29000000000000004 0
# PLASTIC 0.29000000000000004 1
# ELASTIC 0.29000000000000004 2
# ELASTIC 0.29000000000000004 3
# ELASTIC 0.29000000000000004 4
# ELASTIC 0.29000000000000004 5
# ELASTIC 0.29000000000000004 6
# ELASTIC 0.29000000000000004 7
# ELASTIC 0.29000000000000004 8
# ELASTIC 0.29000000000000004 9
# NEWT
# ELASTIC 0.29000000000000004 0
# PLASTIC 0.29000000000000004 1
# ELASTIC 0.29000000000000004 2
# ELASTIC 0.29000000000000004 3
# ELASTIC 0.29000000000000004 4
# ELASTIC 0.29000000000000004 5
# ELASTIC 0.29000000000000004 6
# ELASTIC 0.29000000000000004 7
# ELASTIC 0.29000000000000004 8
# ELASTIC 0.29000000000000004 9
# 30 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.3 0
# ELASTIC 0.3 1
# ELASTIC 0.3 2
# ELASTIC 0.3 3
# ELASTIC 0.3 4
# ELASTIC 0.3 5
# ELASTIC 0.3 6
# ELASTIC 0.3 7
# ELASTIC 0.3 8
# ELASTIC 0.3 9
# NEWT
# ELASTIC 0.3 0
# PLASTIC 0.3 1
# ELASTIC 0.3 2
# ELASTIC 0.3 3
# ELASTIC 0.3 4
# ELASTIC 0.3 5
# ELASTIC 0.3 6
# ELASTIC 0.3 7
# ELASTIC 0.3 8
# ELASTIC 0.3 9
# NEWT
# ELASTIC 0.3 0
# PLASTIC 0.3 1
# ELASTIC 0.3 2
# ELASTIC 0.3 3
# ELASTIC 0.3 4
# ELASTIC 0.3 5
# ELASTIC 0.3 6
# ELASTIC 0.3 7
# ELASTIC 0.3 8
# ELASTIC 0.3 9
# 31 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.31 0
# ELASTIC 0.31 1
# ELASTIC 0.31 2
# ELASTIC 0.31 3
# ELASTIC 0.31 4
# ELASTIC 0.31 5
# ELASTIC 0.31 6
# ELASTIC 0.31 7
# ELASTIC 0.31 8
# ELASTIC 0.31 9
# NEWT
# ELASTIC 0.31 0
# PLASTIC 0.31 1
# ELASTIC 0.31 2
# ELASTIC 0.31 3
# ELASTIC 0.31 4
# ELASTIC 0.31 5
# ELASTIC 0.31 6
# ELASTIC 0.31 7
# ELASTIC 0.31 8
# ELASTIC 0.31 9
# NEWT
# ELASTIC 0.31 0
# PLASTIC 0.31 1
# ELASTIC 0.31 2
# ELASTIC 0.31 3
# ELASTIC 0.31 4
# ELASTIC 0.31 5
# ELASTIC 0.31 6
# ELASTIC 0.31 7
# ELASTIC 0.31 8
# ELASTIC 0.31 9
# 32 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.32 0
# ELASTIC 0.32 1
# ELASTIC 0.32 2
# ELASTIC 0.32 3
# ELASTIC 0.32 4
# ELASTIC 0.32 5
# ELASTIC 0.32 6
# ELASTIC 0.32 7
# ELASTIC 0.32 8
# ELASTIC 0.32 9
# NEWT
# ELASTIC 0.32 0
# PLASTIC 0.32 1
# ELASTIC 0.32 2
# ELASTIC 0.32 3
# ELASTIC 0.32 4
# ELASTIC 0.32 5
# ELASTIC 0.32 6
# ELASTIC 0.32 7
# ELASTIC 0.32 8
# ELASTIC 0.32 9
# NEWT
# ELASTIC 0.32 0
# PLASTIC 0.32 1
# ELASTIC 0.32 2
# ELASTIC 0.32 3
# ELASTIC 0.32 4
# ELASTIC 0.32 5
# ELASTIC 0.32 6
# ELASTIC 0.32 7
# ELASTIC 0.32 8
# ELASTIC 0.32 9
# 33 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.33 0
# ELASTIC 0.33 1
# ELASTIC 0.33 2
# ELASTIC 0.33 3
# ELASTIC 0.33 4
# ELASTIC 0.33 5
# ELASTIC 0.33 6
# ELASTIC 0.33 7
# ELASTIC 0.33 8
# ELASTIC 0.33 9
# NEWT
# ELASTIC 0.33 0
# PLASTIC 0.33 1
# ELASTIC 0.33 2
# ELASTIC 0.33 3
# ELASTIC 0.33 4
# ELASTIC 0.33 5
# ELASTIC 0.33 6
# ELASTIC 0.33 7
# ELASTIC 0.33 8
# ELASTIC 0.33 9
# NEWT
# ELASTIC 0.33 0
# PLASTIC 0.33 1
# ELASTIC 0.33 2
# ELASTIC 0.33 3
# ELASTIC 0.33 4
# ELASTIC 0.33 5
# ELASTIC 0.33 6
# ELASTIC 0.33 7
# ELASTIC 0.33 8
# ELASTIC 0.33 9
# 34 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.34 0
# ELASTIC 0.34 1
# ELASTIC 0.34 2
# ELASTIC 0.34 3
# ELASTIC 0.34 4
# ELASTIC 0.34 5
# ELASTIC 0.34 6
# ELASTIC 0.34 7
# ELASTIC 0.34 8
# ELASTIC 0.34 9
# NEWT
# ELASTIC 0.34 0
# PLASTIC 0.34 1
# ELASTIC 0.34 2
# ELASTIC 0.34 3
# ELASTIC 0.34 4
# ELASTIC 0.34 5
# ELASTIC 0.34 6
# ELASTIC 0.34 7
# ELASTIC 0.34 8
# ELASTIC 0.34 9
# NEWT
# ELASTIC 0.34 0
# PLASTIC 0.34 1
# ELASTIC 0.34 2
# ELASTIC 0.34 3
# ELASTIC 0.34 4
# ELASTIC 0.34 5
# ELASTIC 0.34 6
# ELASTIC 0.34 7
# ELASTIC 0.34 8
# ELASTIC 0.34 9
# 35 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.35000000000000003 0
# ELASTIC 0.35000000000000003 1
# ELASTIC 0.35000000000000003 2
# ELASTIC 0.35000000000000003 3
# ELASTIC 0.35000000000000003 4
# ELASTIC 0.35000000000000003 5
# ELASTIC 0.35000000000000003 6
# ELASTIC 0.35000000000000003 7
# ELASTIC 0.35000000000000003 8
# ELASTIC 0.35000000000000003 9
# NEWT
# ELASTIC 0.35000000000000003 0
# PLASTIC 0.35000000000000003 1
# ELASTIC 0.35000000000000003 2
# ELASTIC 0.35000000000000003 3
# ELASTIC 0.35000000000000003 4
# ELASTIC 0.35000000000000003 5
# ELASTIC 0.35000000000000003 6
# ELASTIC 0.35000000000000003 7
# ELASTIC 0.35000000000000003 8
# ELASTIC 0.35000000000000003 9
# NEWT
# ELASTIC 0.35000000000000003 0
# PLASTIC 0.35000000000000003 1
# ELASTIC 0.35000000000000003 2
# ELASTIC 0.35000000000000003 3
# ELASTIC 0.35000000000000003 4
# ELASTIC 0.35000000000000003 5
# ELASTIC 0.35000000000000003 6
# ELASTIC 0.35000000000000003 7
# ELASTIC 0.35000000000000003 8
# ELASTIC 0.35000000000000003 9
# 36 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.36000000000000004 0
# ELASTIC 0.36000000000000004 1
# ELASTIC 0.36000000000000004 2
# ELASTIC 0.36000000000000004 3
# ELASTIC 0.36000000000000004 4
# ELASTIC 0.36000000000000004 5
# ELASTIC 0.36000000000000004 6
# ELASTIC 0.36000000000000004 7
# ELASTIC 0.36000000000000004 8
# ELASTIC 0.36000000000000004 9
# NEWT
# ELASTIC 0.36000000000000004 0
# PLASTIC 0.36000000000000004 1
# PLASTIC 0.36000000000000004 2
# ELASTIC 0.36000000000000004 3
# ELASTIC 0.36000000000000004 4
# ELASTIC 0.36000000000000004 5
# ELASTIC 0.36000000000000004 6
# ELASTIC 0.36000000000000004 7
# ELASTIC 0.36000000000000004 8
# ELASTIC 0.36000000000000004 9
# NEWT
# ELASTIC 0.36000000000000004 0
# PLASTIC 0.36000000000000004 1
# PLASTIC 0.36000000000000004 2
# ELASTIC 0.36000000000000004 3
# ELASTIC 0.36000000000000004 4
# ELASTIC 0.36000000000000004 5
# ELASTIC 0.36000000000000004 6
# ELASTIC 0.36000000000000004 7
# ELASTIC 0.36000000000000004 8
# ELASTIC 0.36000000000000004 9
# 37 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.37 0
# ELASTIC 0.37 1
# PLASTIC 0.37 2
# ELASTIC 0.37 3
# ELASTIC 0.37 4
# ELASTIC 0.37 5
# ELASTIC 0.37 6
# ELASTIC 0.37 7
# ELASTIC 0.37 8
# ELASTIC 0.37 9
# NEWT
# ELASTIC 0.37 0
# PLASTIC 0.37 1
# PLASTIC 0.37 2
# ELASTIC 0.37 3
# ELASTIC 0.37 4
# ELASTIC 0.37 5
# ELASTIC 0.37 6
# ELASTIC 0.37 7
# ELASTIC 0.37 8
# ELASTIC 0.37 9
# NEWT
# ELASTIC 0.37 0
# PLASTIC 0.37 1
# PLASTIC 0.37 2
# ELASTIC 0.37 3
# ELASTIC 0.37 4
# ELASTIC 0.37 5
# ELASTIC 0.37 6
# ELASTIC 0.37 7
# ELASTIC 0.37 8
# ELASTIC 0.37 9
# 38 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.38 0
# ELASTIC 0.38 1
# PLASTIC 0.38 2
# ELASTIC 0.38 3
# ELASTIC 0.38 4
# ELASTIC 0.38 5
# ELASTIC 0.38 6
# ELASTIC 0.38 7
# ELASTIC 0.38 8
# ELASTIC 0.38 9
# NEWT
# ELASTIC 0.38 0
# PLASTIC 0.38 1
# PLASTIC 0.38 2
# ELASTIC 0.38 3
# ELASTIC 0.38 4
# ELASTIC 0.38 5
# ELASTIC 0.38 6
# ELASTIC 0.38 7
# ELASTIC 0.38 8
# ELASTIC 0.38 9
# NEWT
# ELASTIC 0.38 0
# PLASTIC 0.38 1
# PLASTIC 0.38 2
# ELASTIC 0.38 3
# ELASTIC 0.38 4
# ELASTIC 0.38 5
# ELASTIC 0.38 6
# ELASTIC 0.38 7
# ELASTIC 0.38 8
# ELASTIC 0.38 9
# 39 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.39 0
# ELASTIC 0.39 1
# PLASTIC 0.39 2
# ELASTIC 0.39 3
# ELASTIC 0.39 4
# ELASTIC 0.39 5
# ELASTIC 0.39 6
# ELASTIC 0.39 7
# ELASTIC 0.39 8
# ELASTIC 0.39 9
# NEWT
# ELASTIC 0.39 0
# PLASTIC 0.39 1
# PLASTIC 0.39 2
# ELASTIC 0.39 3
# ELASTIC 0.39 4
# ELASTIC 0.39 5
# ELASTIC 0.39 6
# ELASTIC 0.39 7
# ELASTIC 0.39 8
# ELASTIC 0.39 9
# NEWT
# ELASTIC 0.39 0
# PLASTIC 0.39 1
# PLASTIC 0.39 2
# ELASTIC 0.39 3
# ELASTIC 0.39 4
# ELASTIC 0.39 5
# ELASTIC 0.39 6
# ELASTIC 0.39 7
# ELASTIC 0.39 8
# ELASTIC 0.39 9
# 40 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.4 0
# ELASTIC 0.4 1
# PLASTIC 0.4 2
# ELASTIC 0.4 3
# ELASTIC 0.4 4
# ELASTIC 0.4 5
# ELASTIC 0.4 6
# ELASTIC 0.4 7
# ELASTIC 0.4 8
# ELASTIC 0.4 9
# NEWT
# ELASTIC 0.4 0
# PLASTIC 0.4 1
# PLASTIC 0.4 2
# ELASTIC 0.4 3
# ELASTIC 0.4 4
# ELASTIC 0.4 5
# ELASTIC 0.4 6
# ELASTIC 0.4 7
# ELASTIC 0.4 8
# ELASTIC 0.4 9
# NEWT
# ELASTIC 0.4 0
# PLASTIC 0.4 1
# PLASTIC 0.4 2
# ELASTIC 0.4 3
# ELASTIC 0.4 4
# ELASTIC 0.4 5
# ELASTIC 0.4 6
# ELASTIC 0.4 7
# ELASTIC 0.4 8
# ELASTIC 0.4 9
# 41 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.41000000000000003 0
# ELASTIC 0.41000000000000003 1
# PLASTIC 0.41000000000000003 2
# ELASTIC 0.41000000000000003 3
# ELASTIC 0.41000000000000003 4
# ELASTIC 0.41000000000000003 5
# ELASTIC 0.41000000000000003 6
# ELASTIC 0.41000000000000003 7
# ELASTIC 0.41000000000000003 8
# ELASTIC 0.41000000000000003 9
# NEWT
# ELASTIC 0.41000000000000003 0
# PLASTIC 0.41000000000000003 1
# PLASTIC 0.41000000000000003 2
# ELASTIC 0.41000000000000003 3
# ELASTIC 0.41000000000000003 4
# ELASTIC 0.41000000000000003 5
# ELASTIC 0.41000000000000003 6
# ELASTIC 0.41000000000000003 7
# ELASTIC 0.41000000000000003 8
# ELASTIC 0.41000000000000003 9
# NEWT
# ELASTIC 0.41000000000000003 0
# PLASTIC 0.41000000000000003 1
# PLASTIC 0.41000000000000003 2
# ELASTIC 0.41000000000000003 3
# ELASTIC 0.41000000000000003 4
# ELASTIC 0.41000000000000003 5
# ELASTIC 0.41000000000000003 6
# ELASTIC 0.41000000000000003 7
# ELASTIC 0.41000000000000003 8
# ELASTIC 0.41000000000000003 9
# 42 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.42000000000000004 0
# ELASTIC 0.42000000000000004 1
# PLASTIC 0.42000000000000004 2
# ELASTIC 0.42000000000000004 3
# ELASTIC 0.42000000000000004 4
# ELASTIC 0.42000000000000004 5
# ELASTIC 0.42000000000000004 6
# ELASTIC 0.42000000000000004 7
# ELASTIC 0.42000000000000004 8
# ELASTIC 0.42000000000000004 9
# NEWT
# ELASTIC 0.42000000000000004 0
# PLASTIC 0.42000000000000004 1
# PLASTIC 0.42000000000000004 2
# ELASTIC 0.42000000000000004 3
# ELASTIC 0.42000000000000004 4
# ELASTIC 0.42000000000000004 5
# ELASTIC 0.42000000000000004 6
# ELASTIC 0.42000000000000004 7
# ELASTIC 0.42000000000000004 8
# ELASTIC 0.42000000000000004 9
# NEWT
# ELASTIC 0.42000000000000004 0
# PLASTIC 0.42000000000000004 1
# PLASTIC 0.42000000000000004 2
# ELASTIC 0.42000000000000004 3
# ELASTIC 0.42000000000000004 4
# ELASTIC 0.42000000000000004 5
# ELASTIC 0.42000000000000004 6
# ELASTIC 0.42000000000000004 7
# ELASTIC 0.42000000000000004 8
# ELASTIC 0.42000000000000004 9
# 43 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.43 0
# ELASTIC 0.43 1
# PLASTIC 0.43 2
# ELASTIC 0.43 3
# ELASTIC 0.43 4
# ELASTIC 0.43 5
# ELASTIC 0.43 6
# ELASTIC 0.43 7
# ELASTIC 0.43 8
# ELASTIC 0.43 9
# NEWT
# ELASTIC 0.43 0
# PLASTIC 0.43 1
# PLASTIC 0.43 2
# ELASTIC 0.43 3
# ELASTIC 0.43 4
# ELASTIC 0.43 5
# ELASTIC 0.43 6
# ELASTIC 0.43 7
# ELASTIC 0.43 8
# ELASTIC 0.43 9
# NEWT
# ELASTIC 0.43 0
# PLASTIC 0.43 1
# PLASTIC 0.43 2
# ELASTIC 0.43 3
# ELASTIC 0.43 4
# ELASTIC 0.43 5
# ELASTIC 0.43 6
# ELASTIC 0.43 7
# ELASTIC 0.43 8
# ELASTIC 0.43 9
# 44 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.44 0
# ELASTIC 0.44 1
# PLASTIC 0.44 2
# ELASTIC 0.44 3
# ELASTIC 0.44 4
# ELASTIC 0.44 5
# ELASTIC 0.44 6
# ELASTIC 0.44 7
# ELASTIC 0.44 8
# ELASTIC 0.44 9
# NEWT
# ELASTIC 0.44 0
# PLASTIC 0.44 1
# PLASTIC 0.44 2
# ELASTIC 0.44 3
# ELASTIC 0.44 4
# ELASTIC 0.44 5
# ELASTIC 0.44 6
# ELASTIC 0.44 7
# ELASTIC 0.44 8
# ELASTIC 0.44 9
# NEWT
# ELASTIC 0.44 0
# PLASTIC 0.44 1
# PLASTIC 0.44 2
# ELASTIC 0.44 3
# ELASTIC 0.44 4
# ELASTIC 0.44 5
# ELASTIC 0.44 6
# ELASTIC 0.44 7
# ELASTIC 0.44 8
# ELASTIC 0.44 9
# 45 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.45 0
# ELASTIC 0.45 1
# PLASTIC 0.45 2
# ELASTIC 0.45 3
# ELASTIC 0.45 4
# ELASTIC 0.45 5
# ELASTIC 0.45 6
# ELASTIC 0.45 7
# ELASTIC 0.45 8
# ELASTIC 0.45 9
# NEWT
# ELASTIC 0.45 0
# PLASTIC 0.45 1
# PLASTIC 0.45 2
# ELASTIC 0.45 3
# ELASTIC 0.45 4
# ELASTIC 0.45 5
# ELASTIC 0.45 6
# ELASTIC 0.45 7
# ELASTIC 0.45 8
# ELASTIC 0.45 9
# NEWT
# ELASTIC 0.45 0
# PLASTIC 0.45 1
# PLASTIC 0.45 2
# ELASTIC 0.45 3
# ELASTIC 0.45 4
# ELASTIC 0.45 5
# ELASTIC 0.45 6
# ELASTIC 0.45 7
# ELASTIC 0.45 8
# ELASTIC 0.45 9
# 46 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.46 0
# ELASTIC 0.46 1
# PLASTIC 0.46 2
# ELASTIC 0.46 3
# ELASTIC 0.46 4
# ELASTIC 0.46 5
# ELASTIC 0.46 6
# ELASTIC 0.46 7
# ELASTIC 0.46 8
# ELASTIC 0.46 9
# NEWT
# ELASTIC 0.46 0
# PLASTIC 0.46 1
# PLASTIC 0.46 2
# ELASTIC 0.46 3
# ELASTIC 0.46 4
# ELASTIC 0.46 5
# ELASTIC 0.46 6
# ELASTIC 0.46 7
# ELASTIC 0.46 8
# ELASTIC 0.46 9
# NEWT
# ELASTIC 0.46 0
# PLASTIC 0.46 1
# PLASTIC 0.46 2
# ELASTIC 0.46 3
# ELASTIC 0.46 4
# ELASTIC 0.46 5
# ELASTIC 0.46 6
# ELASTIC 0.46 7
# ELASTIC 0.46 8
# ELASTIC 0.46 9
# 47 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.47000000000000003 0
# ELASTIC 0.47000000000000003 1
# PLASTIC 0.47000000000000003 2
# ELASTIC 0.47000000000000003 3
# ELASTIC 0.47000000000000003 4
# ELASTIC 0.47000000000000003 5
# ELASTIC 0.47000000000000003 6
# ELASTIC 0.47000000000000003 7
# ELASTIC 0.47000000000000003 8
# ELASTIC 0.47000000000000003 9
# NEWT
# ELASTIC 0.47000000000000003 0
# PLASTIC 0.47000000000000003 1
# PLASTIC 0.47000000000000003 2
# ELASTIC 0.47000000000000003 3
# ELASTIC 0.47000000000000003 4
# ELASTIC 0.47000000000000003 5
# ELASTIC 0.47000000000000003 6
# ELASTIC 0.47000000000000003 7
# ELASTIC 0.47000000000000003 8
# ELASTIC 0.47000000000000003 9
# NEWT
# ELASTIC 0.47000000000000003 0
# PLASTIC 0.47000000000000003 1
# PLASTIC 0.47000000000000003 2
# ELASTIC 0.47000000000000003 3
# ELASTIC 0.47000000000000003 4
# ELASTIC 0.47000000000000003 5
# ELASTIC 0.47000000000000003 6
# ELASTIC 0.47000000000000003 7
# ELASTIC 0.47000000000000003 8
# ELASTIC 0.47000000000000003 9
# 48 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.48000000000000004 0
# ELASTIC 0.48000000000000004 1
# PLASTIC 0.48000000000000004 2
# ELASTIC 0.48000000000000004 3
# ELASTIC 0.48000000000000004 4
# ELASTIC 0.48000000000000004 5
# ELASTIC 0.48000000000000004 6
# ELASTIC 0.48000000000000004 7
# ELASTIC 0.48000000000000004 8
# ELASTIC 0.48000000000000004 9
# NEWT
# ELASTIC 0.48000000000000004 0
# PLASTIC 0.48000000000000004 1
# PLASTIC 0.48000000000000004 2
# ELASTIC 0.48000000000000004 3
# ELASTIC 0.48000000000000004 4
# ELASTIC 0.48000000000000004 5
# ELASTIC 0.48000000000000004 6
# ELASTIC 0.48000000000000004 7
# ELASTIC 0.48000000000000004 8
# ELASTIC 0.48000000000000004 9
# NEWT
# ELASTIC 0.48000000000000004 0
# PLASTIC 0.48000000000000004 1
# PLASTIC 0.48000000000000004 2
# ELASTIC 0.48000000000000004 3
# ELASTIC 0.48000000000000004 4
# ELASTIC 0.48000000000000004 5
# ELASTIC 0.48000000000000004 6
# ELASTIC 0.48000000000000004 7
# ELASTIC 0.48000000000000004 8
# ELASTIC 0.48000000000000004 9
# 49 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.49 0
# ELASTIC 0.49 1
# PLASTIC 0.49 2
# ELASTIC 0.49 3
# ELASTIC 0.49 4
# ELASTIC 0.49 5
# ELASTIC 0.49 6
# ELASTIC 0.49 7
# ELASTIC 0.49 8
# ELASTIC 0.49 9
# NEWT
# ELASTIC 0.49 0
# PLASTIC 0.49 1
# PLASTIC 0.49 2
# ELASTIC 0.49 3
# ELASTIC 0.49 4
# ELASTIC 0.49 5
# ELASTIC 0.49 6
# ELASTIC 0.49 7
# ELASTIC 0.49 8
# ELASTIC 0.49 9
# NEWT
# ELASTIC 0.49 0
# PLASTIC 0.49 1
# PLASTIC 0.49 2
# ELASTIC 0.49 3
# ELASTIC 0.49 4
# ELASTIC 0.49 5
# ELASTIC 0.49 6
# ELASTIC 0.49 7
# ELASTIC 0.49 8
# ELASTIC 0.49 9
# 50 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.5 0
# ELASTIC 0.5 1
# PLASTIC 0.5 2
# ELASTIC 0.5 3
# ELASTIC 0.5 4
# ELASTIC 0.5 5
# ELASTIC 0.5 6
# ELASTIC 0.5 7
# ELASTIC 0.5 8
# ELASTIC 0.5 9
# NEWT
# ELASTIC 0.5 0
# PLASTIC 0.5 1
# PLASTIC 0.5 2
# ELASTIC 0.5 3
# ELASTIC 0.5 4
# ELASTIC 0.5 5
# ELASTIC 0.5 6
# ELASTIC 0.5 7
# ELASTIC 0.5 8
# ELASTIC 0.5 9
# NEWT
# ELASTIC 0.5 0
# PLASTIC 0.5 1
# PLASTIC 0.5 2
# ELASTIC 0.5 3
# ELASTIC 0.5 4
# ELASTIC 0.5 5
# ELASTIC 0.5 6
# ELASTIC 0.5 7
# ELASTIC 0.5 8
# ELASTIC 0.5 9
# 51 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.51 0
# ELASTIC 0.51 1
# PLASTIC 0.51 2
# ELASTIC 0.51 3
# ELASTIC 0.51 4
# ELASTIC 0.51 5
# ELASTIC 0.51 6
# ELASTIC 0.51 7
# ELASTIC 0.51 8
# ELASTIC 0.51 9
# NEWT
# ELASTIC 0.51 0
# PLASTIC 0.51 1
# PLASTIC 0.51 2
# ELASTIC 0.51 3
# ELASTIC 0.51 4
# ELASTIC 0.51 5
# ELASTIC 0.51 6
# ELASTIC 0.51 7
# ELASTIC 0.51 8
# ELASTIC 0.51 9
# NEWT
# ELASTIC 0.51 0
# PLASTIC 0.51 1
# PLASTIC 0.51 2
# ELASTIC 0.51 3
# ELASTIC 0.51 4
# ELASTIC 0.51 5
# ELASTIC 0.51 6
# ELASTIC 0.51 7
# ELASTIC 0.51 8
# ELASTIC 0.51 9
# 52 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.52 0
# ELASTIC 0.52 1
# PLASTIC 0.52 2
# ELASTIC 0.52 3
# ELASTIC 0.52 4
# ELASTIC 0.52 5
# ELASTIC 0.52 6
# ELASTIC 0.52 7
# ELASTIC 0.52 8
# ELASTIC 0.52 9
# NEWT
# ELASTIC 0.52 0
# PLASTIC 0.52 1
# PLASTIC 0.52 2
# ELASTIC 0.52 3
# ELASTIC 0.52 4
# ELASTIC 0.52 5
# ELASTIC 0.52 6
# ELASTIC 0.52 7
# ELASTIC 0.52 8
# ELASTIC 0.52 9
# NEWT
# ELASTIC 0.52 0
# PLASTIC 0.52 1
# PLASTIC 0.52 2
# ELASTIC 0.52 3
# ELASTIC 0.52 4
# ELASTIC 0.52 5
# ELASTIC 0.52 6
# ELASTIC 0.52 7
# ELASTIC 0.52 8
# ELASTIC 0.52 9
# 53 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.53 0
# ELASTIC 0.53 1
# PLASTIC 0.53 2
# ELASTIC 0.53 3
# ELASTIC 0.53 4
# ELASTIC 0.53 5
# ELASTIC 0.53 6
# ELASTIC 0.53 7
# ELASTIC 0.53 8
# ELASTIC 0.53 9
# NEWT
# ELASTIC 0.53 0
# PLASTIC 0.53 1
# PLASTIC 0.53 2
# ELASTIC 0.53 3
# ELASTIC 0.53 4
# ELASTIC 0.53 5
# ELASTIC 0.53 6
# ELASTIC 0.53 7
# ELASTIC 0.53 8
# ELASTIC 0.53 9
# NEWT
# ELASTIC 0.53 0
# PLASTIC 0.53 1
# PLASTIC 0.53 2
# ELASTIC 0.53 3
# ELASTIC 0.53 4
# ELASTIC 0.53 5
# ELASTIC 0.53 6
# ELASTIC 0.53 7
# ELASTIC 0.53 8
# ELASTIC 0.53 9
# 54 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.54 0
# ELASTIC 0.54 1
# PLASTIC 0.54 2
# ELASTIC 0.54 3
# ELASTIC 0.54 4
# ELASTIC 0.54 5
# ELASTIC 0.54 6
# ELASTIC 0.54 7
# ELASTIC 0.54 8
# ELASTIC 0.54 9
# NEWT
# ELASTIC 0.54 0
# PLASTIC 0.54 1
# PLASTIC 0.54 2
# ELASTIC 0.54 3
# ELASTIC 0.54 4
# ELASTIC 0.54 5
# ELASTIC 0.54 6
# ELASTIC 0.54 7
# ELASTIC 0.54 8
# ELASTIC 0.54 9
# NEWT
# ELASTIC 0.54 0
# PLASTIC 0.54 1
# PLASTIC 0.54 2
# ELASTIC 0.54 3
# ELASTIC 0.54 4
# ELASTIC 0.54 5
# ELASTIC 0.54 6
# ELASTIC 0.54 7
# ELASTIC 0.54 8
# ELASTIC 0.54 9
# 55 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.55 0
# ELASTIC 0.55 1
# PLASTIC 0.55 2
# ELASTIC 0.55 3
# ELASTIC 0.55 4
# ELASTIC 0.55 5
# ELASTIC 0.55 6
# ELASTIC 0.55 7
# ELASTIC 0.55 8
# ELASTIC 0.55 9
# NEWT
# ELASTIC 0.55 0
# PLASTIC 0.55 1
# PLASTIC 0.55 2
# ELASTIC 0.55 3
# ELASTIC 0.55 4
# ELASTIC 0.55 5
# ELASTIC 0.55 6
# ELASTIC 0.55 7
# ELASTIC 0.55 8
# ELASTIC 0.55 9
# NEWT
# ELASTIC 0.55 0
# PLASTIC 0.55 1
# PLASTIC 0.55 2
# ELASTIC 0.55 3
# ELASTIC 0.55 4
# ELASTIC 0.55 5
# ELASTIC 0.55 6
# ELASTIC 0.55 7
# ELASTIC 0.55 8
# ELASTIC 0.55 9
# 56 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.56 0
# ELASTIC 0.56 1
# PLASTIC 0.56 2
# ELASTIC 0.56 3
# ELASTIC 0.56 4
# ELASTIC 0.56 5
# ELASTIC 0.56 6
# ELASTIC 0.56 7
# ELASTIC 0.56 8
# ELASTIC 0.56 9
# NEWT
# ELASTIC 0.56 0
# PLASTIC 0.56 1
# PLASTIC 0.56 2
# ELASTIC 0.56 3
# ELASTIC 0.56 4
# ELASTIC 0.56 5
# ELASTIC 0.56 6
# ELASTIC 0.56 7
# ELASTIC 0.56 8
# ELASTIC 0.56 9
# NEWT
# ELASTIC 0.56 0
# PLASTIC 0.56 1
# PLASTIC 0.56 2
# ELASTIC 0.56 3
# ELASTIC 0.56 4
# ELASTIC 0.56 5
# ELASTIC 0.56 6
# ELASTIC 0.56 7
# ELASTIC 0.56 8
# ELASTIC 0.56 9
# 57 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.5700000000000001 0
# ELASTIC 0.5700000000000001 1
# PLASTIC 0.5700000000000001 2
# ELASTIC 0.5700000000000001 3
# ELASTIC 0.5700000000000001 4
# ELASTIC 0.5700000000000001 5
# ELASTIC 0.5700000000000001 6
# ELASTIC 0.5700000000000001 7
# ELASTIC 0.5700000000000001 8
# ELASTIC 0.5700000000000001 9
# NEWT
# ELASTIC 0.5700000000000001 0
# PLASTIC 0.5700000000000001 1
# PLASTIC 0.5700000000000001 2
# ELASTIC 0.5700000000000001 3
# ELASTIC 0.5700000000000001 4
# ELASTIC 0.5700000000000001 5
# ELASTIC 0.5700000000000001 6
# ELASTIC 0.5700000000000001 7
# ELASTIC 0.5700000000000001 8
# ELASTIC 0.5700000000000001 9
# NEWT
# ELASTIC 0.5700000000000001 0
# PLASTIC 0.5700000000000001 1
# PLASTIC 0.5700000000000001 2
# ELASTIC 0.5700000000000001 3
# ELASTIC 0.5700000000000001 4
# ELASTIC 0.5700000000000001 5
# ELASTIC 0.5700000000000001 6
# ELASTIC 0.5700000000000001 7
# ELASTIC 0.5700000000000001 8
# ELASTIC 0.5700000000000001 9
# 58 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.5800000000000001 0
# ELASTIC 0.5800000000000001 1
# PLASTIC 0.5800000000000001 2
# ELASTIC 0.5800000000000001 3
# ELASTIC 0.5800000000000001 4
# ELASTIC 0.5800000000000001 5
# ELASTIC 0.5800000000000001 6
# ELASTIC 0.5800000000000001 7
# ELASTIC 0.5800000000000001 8
# ELASTIC 0.5800000000000001 9
# NEWT
# ELASTIC 0.5800000000000001 0
# PLASTIC 0.5800000000000001 1
# PLASTIC 0.5800000000000001 2
# ELASTIC 0.5800000000000001 3
# ELASTIC 0.5800000000000001 4
# ELASTIC 0.5800000000000001 5
# ELASTIC 0.5800000000000001 6
# ELASTIC 0.5800000000000001 7
# ELASTIC 0.5800000000000001 8
# ELASTIC 0.5800000000000001 9
# NEWT
# ELASTIC 0.5800000000000001 0
# PLASTIC 0.5800000000000001 1
# PLASTIC 0.5800000000000001 2
# ELASTIC 0.5800000000000001 3
# ELASTIC 0.5800000000000001 4
# ELASTIC 0.5800000000000001 5
# ELASTIC 0.5800000000000001 6
# ELASTIC 0.5800000000000001 7
# ELASTIC 0.5800000000000001 8
# ELASTIC 0.5800000000000001 9
# 59 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.59 0
# ELASTIC 0.59 1
# PLASTIC 0.59 2
# ELASTIC 0.59 3
# ELASTIC 0.59 4
# ELASTIC 0.59 5
# ELASTIC 0.59 6
# ELASTIC 0.59 7
# ELASTIC 0.59 8
# ELASTIC 0.59 9
# NEWT
# ELASTIC 0.59 0
# PLASTIC 0.59 1
# PLASTIC 0.59 2
# PLASTIC 0.59 3
# ELASTIC 0.59 4
# ELASTIC 0.59 5
# ELASTIC 0.59 6
# ELASTIC 0.59 7
# ELASTIC 0.59 8
# ELASTIC 0.59 9
# NEWT
# ELASTIC 0.59 0
# PLASTIC 0.59 1
# PLASTIC 0.59 2
# PLASTIC 0.59 3
# ELASTIC 0.59 4
# ELASTIC 0.59 5
# ELASTIC 0.59 6
# ELASTIC 0.59 7
# ELASTIC 0.59 8
# ELASTIC 0.59 9
# 60 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.6 0
# ELASTIC 0.6 1
# PLASTIC 0.6 2
# ELASTIC 0.6 3
# ELASTIC 0.6 4
# ELASTIC 0.6 5
# ELASTIC 0.6 6
# ELASTIC 0.6 7
# ELASTIC 0.6 8
# ELASTIC 0.6 9
# NEWT
# ELASTIC 0.6 0
# PLASTIC 0.6 1
# PLASTIC 0.6 2
# PLASTIC 0.6 3
# ELASTIC 0.6 4
# ELASTIC 0.6 5
# ELASTIC 0.6 6
# ELASTIC 0.6 7
# ELASTIC 0.6 8
# ELASTIC 0.6 9
# NEWT
# ELASTIC 0.6 0
# PLASTIC 0.6 1
# PLASTIC 0.6 2
# PLASTIC 0.6 3
# ELASTIC 0.6 4
# ELASTIC 0.6 5
# ELASTIC 0.6 6
# ELASTIC 0.6 7
# ELASTIC 0.6 8
# ELASTIC 0.6 9
# 61 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.61 0
# ELASTIC 0.61 1
# PLASTIC 0.61 2
# ELASTIC 0.61 3
# ELASTIC 0.61 4
# ELASTIC 0.61 5
# ELASTIC 0.61 6
# ELASTIC 0.61 7
# ELASTIC 0.61 8
# ELASTIC 0.61 9
# NEWT
# ELASTIC 0.61 0
# PLASTIC 0.61 1
# PLASTIC 0.61 2
# PLASTIC 0.61 3
# ELASTIC 0.61 4
# ELASTIC 0.61 5
# ELASTIC 0.61 6
# ELASTIC 0.61 7
# ELASTIC 0.61 8
# ELASTIC 0.61 9
# NEWT
# ELASTIC 0.61 0
# PLASTIC 0.61 1
# PLASTIC 0.61 2
# PLASTIC 0.61 3
# ELASTIC 0.61 4
# ELASTIC 0.61 5
# ELASTIC 0.61 6
# ELASTIC 0.61 7
# ELASTIC 0.61 8
# ELASTIC 0.61 9
# 62 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.62 0
# ELASTIC 0.62 1
# PLASTIC 0.62 2
# ELASTIC 0.62 3
# ELASTIC 0.62 4
# ELASTIC 0.62 5
# ELASTIC 0.62 6
# ELASTIC 0.62 7
# ELASTIC 0.62 8
# ELASTIC 0.62 9
# NEWT
# ELASTIC 0.62 0
# PLASTIC 0.62 1
# PLASTIC 0.62 2
# PLASTIC 0.62 3
# ELASTIC 0.62 4
# ELASTIC 0.62 5
# ELASTIC 0.62 6
# ELASTIC 0.62 7
# ELASTIC 0.62 8
# ELASTIC 0.62 9
# NEWT
# ELASTIC 0.62 0
# PLASTIC 0.62 1
# PLASTIC 0.62 2
# PLASTIC 0.62 3
# ELASTIC 0.62 4
# ELASTIC 0.62 5
# ELASTIC 0.62 6
# ELASTIC 0.62 7
# ELASTIC 0.62 8
# ELASTIC 0.62 9
# 63 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.63 0
# ELASTIC 0.63 1
# PLASTIC 0.63 2
# ELASTIC 0.63 3
# ELASTIC 0.63 4
# ELASTIC 0.63 5
# ELASTIC 0.63 6
# ELASTIC 0.63 7
# ELASTIC 0.63 8
# ELASTIC 0.63 9
# NEWT
# ELASTIC 0.63 0
# PLASTIC 0.63 1
# PLASTIC 0.63 2
# PLASTIC 0.63 3
# ELASTIC 0.63 4
# ELASTIC 0.63 5
# ELASTIC 0.63 6
# ELASTIC 0.63 7
# ELASTIC 0.63 8
# ELASTIC 0.63 9
# NEWT
# ELASTIC 0.63 0
# PLASTIC 0.63 1
# PLASTIC 0.63 2
# PLASTIC 0.63 3
# ELASTIC 0.63 4
# ELASTIC 0.63 5
# ELASTIC 0.63 6
# ELASTIC 0.63 7
# ELASTIC 0.63 8
# ELASTIC 0.63 9
# 64 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.64 0
# ELASTIC 0.64 1
# PLASTIC 0.64 2
# ELASTIC 0.64 3
# ELASTIC 0.64 4
# ELASTIC 0.64 5
# ELASTIC 0.64 6
# ELASTIC 0.64 7
# ELASTIC 0.64 8
# ELASTIC 0.64 9
# NEWT
# ELASTIC 0.64 0
# PLASTIC 0.64 1
# PLASTIC 0.64 2
# PLASTIC 0.64 3
# ELASTIC 0.64 4
# ELASTIC 0.64 5
# ELASTIC 0.64 6
# ELASTIC 0.64 7
# ELASTIC 0.64 8
# ELASTIC 0.64 9
# NEWT
# ELASTIC 0.64 0
# PLASTIC 0.64 1
# PLASTIC 0.64 2
# PLASTIC 0.64 3
# ELASTIC 0.64 4
# ELASTIC 0.64 5
# ELASTIC 0.64 6
# ELASTIC 0.64 7
# ELASTIC 0.64 8
# ELASTIC 0.64 9
# 65 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.65 0
# ELASTIC 0.65 1
# PLASTIC 0.65 2
# ELASTIC 0.65 3
# ELASTIC 0.65 4
# ELASTIC 0.65 5
# ELASTIC 0.65 6
# ELASTIC 0.65 7
# ELASTIC 0.65 8
# ELASTIC 0.65 9
# NEWT
# ELASTIC 0.65 0
# PLASTIC 0.65 1
# PLASTIC 0.65 2
# PLASTIC 0.65 3
# ELASTIC 0.65 4
# ELASTIC 0.65 5
# ELASTIC 0.65 6
# ELASTIC 0.65 7
# ELASTIC 0.65 8
# ELASTIC 0.65 9
# NEWT
# ELASTIC 0.65 0
# PLASTIC 0.65 1
# PLASTIC 0.65 2
# PLASTIC 0.65 3
# ELASTIC 0.65 4
# ELASTIC 0.65 5
# ELASTIC 0.65 6
# ELASTIC 0.65 7
# ELASTIC 0.65 8
# ELASTIC 0.65 9
# 66 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.66 0
# ELASTIC 0.66 1
# PLASTIC 0.66 2
# ELASTIC 0.66 3
# ELASTIC 0.66 4
# ELASTIC 0.66 5
# ELASTIC 0.66 6
# ELASTIC 0.66 7
# ELASTIC 0.66 8
# ELASTIC 0.66 9
# NEWT
# ELASTIC 0.66 0
# PLASTIC 0.66 1
# PLASTIC 0.66 2
# PLASTIC 0.66 3
# ELASTIC 0.66 4
# ELASTIC 0.66 5
# ELASTIC 0.66 6
# ELASTIC 0.66 7
# ELASTIC 0.66 8
# ELASTIC 0.66 9
# NEWT
# ELASTIC 0.66 0
# PLASTIC 0.66 1
# PLASTIC 0.66 2
# PLASTIC 0.66 3
# ELASTIC 0.66 4
# ELASTIC 0.66 5
# ELASTIC 0.66 6
# ELASTIC 0.66 7
# ELASTIC 0.66 8
# ELASTIC 0.66 9
# 67 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.67 0
# ELASTIC 0.67 1
# PLASTIC 0.67 2
# ELASTIC 0.67 3
# ELASTIC 0.67 4
# ELASTIC 0.67 5
# ELASTIC 0.67 6
# ELASTIC 0.67 7
# ELASTIC 0.67 8
# ELASTIC 0.67 9
# NEWT
# ELASTIC 0.67 0
# PLASTIC 0.67 1
# PLASTIC 0.67 2
# PLASTIC 0.67 3
# ELASTIC 0.67 4
# ELASTIC 0.67 5
# ELASTIC 0.67 6
# ELASTIC 0.67 7
# ELASTIC 0.67 8
# ELASTIC 0.67 9
# NEWT
# ELASTIC 0.67 0
# PLASTIC 0.67 1
# PLASTIC 0.67 2
# PLASTIC 0.67 3
# ELASTIC 0.67 4
# ELASTIC 0.67 5
# ELASTIC 0.67 6
# ELASTIC 0.67 7
# ELASTIC 0.67 8
# ELASTIC 0.67 9
# 68 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.68 0
# ELASTIC 0.68 1
# PLASTIC 0.68 2
# ELASTIC 0.68 3
# ELASTIC 0.68 4
# ELASTIC 0.68 5
# ELASTIC 0.68 6
# ELASTIC 0.68 7
# ELASTIC 0.68 8
# ELASTIC 0.68 9
# NEWT
# ELASTIC 0.68 0
# PLASTIC 0.68 1
# PLASTIC 0.68 2
# PLASTIC 0.68 3
# ELASTIC 0.68 4
# ELASTIC 0.68 5
# ELASTIC 0.68 6
# ELASTIC 0.68 7
# ELASTIC 0.68 8
# ELASTIC 0.68 9
# NEWT
# ELASTIC 0.68 0
# PLASTIC 0.68 1
# PLASTIC 0.68 2
# PLASTIC 0.68 3
# ELASTIC 0.68 4
# ELASTIC 0.68 5
# ELASTIC 0.68 6
# ELASTIC 0.68 7
# ELASTIC 0.68 8
# ELASTIC 0.68 9
# 69 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.6900000000000001 0
# ELASTIC 0.6900000000000001 1
# PLASTIC 0.6900000000000001 2
# ELASTIC 0.6900000000000001 3
# ELASTIC 0.6900000000000001 4
# ELASTIC 0.6900000000000001 5
# ELASTIC 0.6900000000000001 6
# ELASTIC 0.6900000000000001 7
# ELASTIC 0.6900000000000001 8
# ELASTIC 0.6900000000000001 9
# NEWT
# ELASTIC 0.6900000000000001 0
# PLASTIC 0.6900000000000001 1
# PLASTIC 0.6900000000000001 2
# PLASTIC 0.6900000000000001 3
# ELASTIC 0.6900000000000001 4
# ELASTIC 0.6900000000000001 5
# ELASTIC 0.6900000000000001 6
# ELASTIC 0.6900000000000001 7
# ELASTIC 0.6900000000000001 8
# ELASTIC 0.6900000000000001 9
# NEWT
# ELASTIC 0.6900000000000001 0
# PLASTIC 0.6900000000000001 1
# PLASTIC 0.6900000000000001 2
# PLASTIC 0.6900000000000001 3
# ELASTIC 0.6900000000000001 4
# ELASTIC 0.6900000000000001 5
# ELASTIC 0.6900000000000001 6
# ELASTIC 0.6900000000000001 7
# ELASTIC 0.6900000000000001 8
# ELASTIC 0.6900000000000001 9
# 70 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.7000000000000001 0
# ELASTIC 0.7000000000000001 1
# PLASTIC 0.7000000000000001 2
# ELASTIC 0.7000000000000001 3
# ELASTIC 0.7000000000000001 4
# ELASTIC 0.7000000000000001 5
# ELASTIC 0.7000000000000001 6
# ELASTIC 0.7000000000000001 7
# ELASTIC 0.7000000000000001 8
# ELASTIC 0.7000000000000001 9
# NEWT
# ELASTIC 0.7000000000000001 0
# PLASTIC 0.7000000000000001 1
# PLASTIC 0.7000000000000001 2
# PLASTIC 0.7000000000000001 3
# ELASTIC 0.7000000000000001 4
# ELASTIC 0.7000000000000001 5
# ELASTIC 0.7000000000000001 6
# ELASTIC 0.7000000000000001 7
# ELASTIC 0.7000000000000001 8
# ELASTIC 0.7000000000000001 9
# NEWT
# ELASTIC 0.7000000000000001 0
# PLASTIC 0.7000000000000001 1
# PLASTIC 0.7000000000000001 2
# PLASTIC 0.7000000000000001 3
# ELASTIC 0.7000000000000001 4
# ELASTIC 0.7000000000000001 5
# ELASTIC 0.7000000000000001 6
# ELASTIC 0.7000000000000001 7
# ELASTIC 0.7000000000000001 8
# ELASTIC 0.7000000000000001 9
# 71 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.7100000000000001 0
# ELASTIC 0.7100000000000001 1
# PLASTIC 0.7100000000000001 2
# ELASTIC 0.7100000000000001 3
# ELASTIC 0.7100000000000001 4
# ELASTIC 0.7100000000000001 5
# ELASTIC 0.7100000000000001 6
# ELASTIC 0.7100000000000001 7
# ELASTIC 0.7100000000000001 8
# ELASTIC 0.7100000000000001 9
# NEWT
# ELASTIC 0.7100000000000001 0
# PLASTIC 0.7100000000000001 1
# PLASTIC 0.7100000000000001 2
# PLASTIC 0.7100000000000001 3
# ELASTIC 0.7100000000000001 4
# ELASTIC 0.7100000000000001 5
# ELASTIC 0.7100000000000001 6
# ELASTIC 0.7100000000000001 7
# ELASTIC 0.7100000000000001 8
# ELASTIC 0.7100000000000001 9
# NEWT
# ELASTIC 0.7100000000000001 0
# PLASTIC 0.7100000000000001 1
# PLASTIC 0.7100000000000001 2
# PLASTIC 0.7100000000000001 3
# ELASTIC 0.7100000000000001 4
# ELASTIC 0.7100000000000001 5
# ELASTIC 0.7100000000000001 6
# ELASTIC 0.7100000000000001 7
# ELASTIC 0.7100000000000001 8
# ELASTIC 0.7100000000000001 9
# 72 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.72 0
# ELASTIC 0.72 1
# PLASTIC 0.72 2
# ELASTIC 0.72 3
# ELASTIC 0.72 4
# ELASTIC 0.72 5
# ELASTIC 0.72 6
# ELASTIC 0.72 7
# ELASTIC 0.72 8
# ELASTIC 0.72 9
# NEWT
# ELASTIC 0.72 0
# PLASTIC 0.72 1
# PLASTIC 0.72 2
# PLASTIC 0.72 3
# ELASTIC 0.72 4
# ELASTIC 0.72 5
# ELASTIC 0.72 6
# ELASTIC 0.72 7
# ELASTIC 0.72 8
# ELASTIC 0.72 9
# NEWT
# ELASTIC 0.72 0
# PLASTIC 0.72 1
# PLASTIC 0.72 2
# PLASTIC 0.72 3
# ELASTIC 0.72 4
# ELASTIC 0.72 5
# ELASTIC 0.72 6
# ELASTIC 0.72 7
# ELASTIC 0.72 8
# ELASTIC 0.72 9
# 73 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.73 0
# ELASTIC 0.73 1
# PLASTIC 0.73 2
# ELASTIC 0.73 3
# ELASTIC 0.73 4
# ELASTIC 0.73 5
# ELASTIC 0.73 6
# ELASTIC 0.73 7
# ELASTIC 0.73 8
# ELASTIC 0.73 9
# NEWT
# ELASTIC 0.73 0
# PLASTIC 0.73 1
# PLASTIC 0.73 2
# PLASTIC 0.73 3
# ELASTIC 0.73 4
# ELASTIC 0.73 5
# ELASTIC 0.73 6
# ELASTIC 0.73 7
# ELASTIC 0.73 8
# ELASTIC 0.73 9
# NEWT
# ELASTIC 0.73 0
# PLASTIC 0.73 1
# PLASTIC 0.73 2
# PLASTIC 0.73 3
# ELASTIC 0.73 4
# ELASTIC 0.73 5
# ELASTIC 0.73 6
# ELASTIC 0.73 7
# ELASTIC 0.73 8
# ELASTIC 0.73 9
# 74 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.74 0
# ELASTIC 0.74 1
# PLASTIC 0.74 2
# ELASTIC 0.74 3
# ELASTIC 0.74 4
# ELASTIC 0.74 5
# ELASTIC 0.74 6
# ELASTIC 0.74 7
# ELASTIC 0.74 8
# ELASTIC 0.74 9
# NEWT
# ELASTIC 0.74 0
# PLASTIC 0.74 1
# PLASTIC 0.74 2
# PLASTIC 0.74 3
# ELASTIC 0.74 4
# ELASTIC 0.74 5
# ...
# PLASTIC 0.76 3
# ELASTIC 0.76 4
# ELASTIC 0.76 5
# ELASTIC 0.76 6
# ELASTIC 0.76 7
# ELASTIC 0.76 8
# ELASTIC 0.76 9
# NEWT
# ELASTIC 0.76 0
# PLASTIC 0.76 1
# PLASTIC 0.76 2
# PLASTIC 0.76 3
# ELASTIC 0.76 4
# ELASTIC 0.76 5
# ELASTIC 0.76 6
# ELASTIC 0.76 7
# ELASTIC 0.76 8
# ELASTIC 0.76 9
# 77 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.77 0
# ELASTIC 0.77 1
# PLASTIC 0.77 2
# ELASTIC 0.77 3
# ELASTIC 0.77 4
# ELASTIC 0.77 5
# ELASTIC 0.77 6
# ELASTIC 0.77 7
# ELASTIC 0.77 8
# ELASTIC 0.77 9
# NEWT
# ELASTIC 0.77 0
# PLASTIC 0.77 1
# PLASTIC 0.77 2
# PLASTIC 0.77 3
# ELASTIC 0.77 4
# ELASTIC 0.77 5
# ELASTIC 0.77 6
# ELASTIC 0.77 7
# ELASTIC 0.77 8
# ELASTIC 0.77 9
# NEWT
# ELASTIC 0.77 0
# PLASTIC 0.77 1
# PLASTIC 0.77 2
# PLASTIC 0.77 3
# ELASTIC 0.77 4
# ELASTIC 0.77 5
# ELASTIC 0.77 6
# ELASTIC 0.77 7
# ELASTIC 0.77 8
# ELASTIC 0.77 9
# 78 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.78 0
# ELASTIC 0.78 1
# PLASTIC 0.78 2
# ELASTIC 0.78 3
# ELASTIC 0.78 4
# ELASTIC 0.78 5
# ELASTIC 0.78 6
# ELASTIC 0.78 7
# ELASTIC 0.78 8
# ELASTIC 0.78 9
# NEWT
# ELASTIC 0.78 0
# PLASTIC 0.78 1
# PLASTIC 0.78 2
# PLASTIC 0.78 3
# ELASTIC 0.78 4
# ELASTIC 0.78 5
# ELASTIC 0.78 6
# ELASTIC 0.78 7
# ELASTIC 0.78 8
# ELASTIC 0.78 9
# NEWT
# ELASTIC 0.78 0
# PLASTIC 0.78 1
# PLASTIC 0.78 2
# PLASTIC 0.78 3
# ELASTIC 0.78 4
# ELASTIC 0.78 5
# ELASTIC 0.78 6
# ELASTIC 0.78 7
# ELASTIC 0.78 8
# ELASTIC 0.78 9
# 79 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.79 0
# ELASTIC 0.79 1
# PLASTIC 0.79 2
# ELASTIC 0.79 3
# ELASTIC 0.79 4
# ELASTIC 0.79 5
# ELASTIC 0.79 6
# ELASTIC 0.79 7
# ELASTIC 0.79 8
# ELASTIC 0.79 9
# NEWT
# ELASTIC 0.79 0
# PLASTIC 0.79 1
# PLASTIC 0.79 2
# PLASTIC 0.79 3
# ELASTIC 0.79 4
# ELASTIC 0.79 5
# ELASTIC 0.79 6
# ELASTIC 0.79 7
# ELASTIC 0.79 8
# ELASTIC 0.79 9
# NEWT
# ELASTIC 0.79 0
# PLASTIC 0.79 1
# PLASTIC 0.79 2
# PLASTIC 0.79 3
# ELASTIC 0.79 4
# ELASTIC 0.79 5
# ELASTIC 0.79 6
# ELASTIC 0.79 7
# ELASTIC 0.79 8
# ELASTIC 0.79 9
# 80 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.8 0
# ELASTIC 0.8 1
# PLASTIC 0.8 2
# ELASTIC 0.8 3
# ELASTIC 0.8 4
# ELASTIC 0.8 5
# ELASTIC 0.8 6
# ELASTIC 0.8 7
# ELASTIC 0.8 8
# ELASTIC 0.8 9
# NEWT
# ELASTIC 0.8 0
# PLASTIC 0.8 1
# PLASTIC 0.8 2
# PLASTIC 0.8 3
# ELASTIC 0.8 4
# ELASTIC 0.8 5
# ELASTIC 0.8 6
# ELASTIC 0.8 7
# ELASTIC 0.8 8
# ELASTIC 0.8 9
# NEWT
# ELASTIC 0.8 0
# PLASTIC 0.8 1
# PLASTIC 0.8 2
# PLASTIC 0.8 3
# ELASTIC 0.8 4
# ELASTIC 0.8 5
# ELASTIC 0.8 6
# ELASTIC 0.8 7
# ELASTIC 0.8 8
# ELASTIC 0.8 9
# 81 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.81 0
# ELASTIC 0.81 1
# PLASTIC 0.81 2
# ELASTIC 0.81 3
# ELASTIC 0.81 4
# ELASTIC 0.81 5
# ELASTIC 0.81 6
# ELASTIC 0.81 7
# ELASTIC 0.81 8
# ELASTIC 0.81 9
# NEWT
# ELASTIC 0.81 0
# PLASTIC 0.81 1
# PLASTIC 0.81 2
# PLASTIC 0.81 3
# ELASTIC 0.81 4
# ELASTIC 0.81 5
# ELASTIC 0.81 6
# ELASTIC 0.81 7
# ELASTIC 0.81 8
# ELASTIC 0.81 9
# NEWT
# ELASTIC 0.81 0
# PLASTIC 0.81 1
# PLASTIC 0.81 2
# PLASTIC 0.81 3
# ELASTIC 0.81 4
# ELASTIC 0.81 5
# ELASTIC 0.81 6
# ELASTIC 0.81 7
# ELASTIC 0.81 8
# ELASTIC 0.81 9
# 82 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.8200000000000001 0
# ELASTIC 0.8200000000000001 1
# PLASTIC 0.8200000000000001 2
# ELASTIC 0.8200000000000001 3
# ELASTIC 0.8200000000000001 4
# ELASTIC 0.8200000000000001 5
# ELASTIC 0.8200000000000001 6
# ELASTIC 0.8200000000000001 7
# ELASTIC 0.8200000000000001 8
# ELASTIC 0.8200000000000001 9
# NEWT
# ELASTIC 0.8200000000000001 0
# PLASTIC 0.8200000000000001 1
# PLASTIC 0.8200000000000001 2
# PLASTIC 0.8200000000000001 3
# ELASTIC 0.8200000000000001 4
# ELASTIC 0.8200000000000001 5
# ELASTIC 0.8200000000000001 6
# ELASTIC 0.8200000000000001 7
# ELASTIC 0.8200000000000001 8
# ELASTIC 0.8200000000000001 9
# NEWT
# ELASTIC 0.8200000000000001 0
# PLASTIC 0.8200000000000001 1
# PLASTIC 0.8200000000000001 2
# PLASTIC 0.8200000000000001 3
# ELASTIC 0.8200000000000001 4
# ELASTIC 0.8200000000000001 5
# ELASTIC 0.8200000000000001 6
# ELASTIC 0.8200000000000001 7
# ELASTIC 0.8200000000000001 8
# ELASTIC 0.8200000000000001 9
# 83 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.8300000000000001 0
# ELASTIC 0.8300000000000001 1
# PLASTIC 0.8300000000000001 2
# ELASTIC 0.8300000000000001 3
# ELASTIC 0.8300000000000001 4
# ELASTIC 0.8300000000000001 5
# ELASTIC 0.8300000000000001 6
# ELASTIC 0.8300000000000001 7
# ELASTIC 0.8300000000000001 8
# ELASTIC 0.8300000000000001 9
# NEWT
# ELASTIC 0.8300000000000001 0
# PLASTIC 0.8300000000000001 1
# PLASTIC 0.8300000000000001 2
# PLASTIC 0.8300000000000001 3
# ELASTIC 0.8300000000000001 4
# ELASTIC 0.8300000000000001 5
# ELASTIC 0.8300000000000001 6
# ELASTIC 0.8300000000000001 7
# ELASTIC 0.8300000000000001 8
# ELASTIC 0.8300000000000001 9
# NEWT
# ELASTIC 0.8300000000000001 0
# PLASTIC 0.8300000000000001 1
# PLASTIC 0.8300000000000001 2
# PLASTIC 0.8300000000000001 3
# ELASTIC 0.8300000000000001 4
# ELASTIC 0.8300000000000001 5
# ELASTIC 0.8300000000000001 6
# ELASTIC 0.8300000000000001 7
# ELASTIC 0.8300000000000001 8
# ELASTIC 0.8300000000000001 9
# 84 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.8400000000000001 0
# ELASTIC 0.8400000000000001 1
# PLASTIC 0.8400000000000001 2
# ELASTIC 0.8400000000000001 3
# ELASTIC 0.8400000000000001 4
# ELASTIC 0.8400000000000001 5
# ELASTIC 0.8400000000000001 6
# ELASTIC 0.8400000000000001 7
# ELASTIC 0.8400000000000001 8
# ELASTIC 0.8400000000000001 9
# NEWT
# ELASTIC 0.8400000000000001 0
# PLASTIC 0.8400000000000001 1
# PLASTIC 0.8400000000000001 2
# PLASTIC 0.8400000000000001 3
# ELASTIC 0.8400000000000001 4
# ELASTIC 0.8400000000000001 5
# ELASTIC 0.8400000000000001 6
# ELASTIC 0.8400000000000001 7
# ELASTIC 0.8400000000000001 8
# ELASTIC 0.8400000000000001 9
# NEWT
# ELASTIC 0.8400000000000001 0
# PLASTIC 0.8400000000000001 1
# PLASTIC 0.8400000000000001 2
# PLASTIC 0.8400000000000001 3
# ELASTIC 0.8400000000000001 4
# ELASTIC 0.8400000000000001 5
# ELASTIC 0.8400000000000001 6
# ELASTIC 0.8400000000000001 7
# ELASTIC 0.8400000000000001 8
# ELASTIC 0.8400000000000001 9
# 85 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.85 0
# ELASTIC 0.85 1
# PLASTIC 0.85 2
# ELASTIC 0.85 3
# ELASTIC 0.85 4
# ELASTIC 0.85 5
# ELASTIC 0.85 6
# ELASTIC 0.85 7
# ELASTIC 0.85 8
# ELASTIC 0.85 9
# NEWT
# ELASTIC 0.85 0
# PLASTIC 0.85 1
# PLASTIC 0.85 2
# PLASTIC 0.85 3
# ELASTIC 0.85 4
# ELASTIC 0.85 5
# ELASTIC 0.85 6
# ELASTIC 0.85 7
# ELASTIC 0.85 8
# ELASTIC 0.85 9
# NEWT
# ELASTIC 0.85 0
# PLASTIC 0.85 1
# PLASTIC 0.85 2
# PLASTIC 0.85 3
# ELASTIC 0.85 4
# ELASTIC 0.85 5
# ELASTIC 0.85 6
# ELASTIC 0.85 7
# ELASTIC 0.85 8
# ELASTIC 0.85 9
# 86 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.86 0
# ELASTIC 0.86 1
# PLASTIC 0.86 2
# ELASTIC 0.86 3
# ELASTIC 0.86 4
# ELASTIC 0.86 5
# ELASTIC 0.86 6
# ELASTIC 0.86 7
# ELASTIC 0.86 8
# ELASTIC 0.86 9
# NEWT
# ELASTIC 0.86 0
# PLASTIC 0.86 1
# PLASTIC 0.86 2
# PLASTIC 0.86 3
# ELASTIC 0.86 4
# ELASTIC 0.86 5
# ELASTIC 0.86 6
# ELASTIC 0.86 7
# ELASTIC 0.86 8
# ELASTIC 0.86 9
# NEWT
# ELASTIC 0.86 0
# PLASTIC 0.86 1
# PLASTIC 0.86 2
# PLASTIC 0.86 3
# ELASTIC 0.86 4
# ELASTIC 0.86 5
# ELASTIC 0.86 6
# ELASTIC 0.86 7
# ELASTIC 0.86 8
# ELASTIC 0.86 9
# 87 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.87 0
# ELASTIC 0.87 1
# PLASTIC 0.87 2
# ELASTIC 0.87 3
# ELASTIC 0.87 4
# ELASTIC 0.87 5
# ELASTIC 0.87 6
# ELASTIC 0.87 7
# ELASTIC 0.87 8
# ELASTIC 0.87 9
# NEWT
# ELASTIC 0.87 0
# PLASTIC 0.87 1
# PLASTIC 0.87 2
# PLASTIC 0.87 3
# ELASTIC 0.87 4
# ELASTIC 0.87 5
# ELASTIC 0.87 6
# ELASTIC 0.87 7
# ELASTIC 0.87 8
# ELASTIC 0.87 9
# NEWT
# ELASTIC 0.87 0
# PLASTIC 0.87 1
# PLASTIC 0.87 2
# PLASTIC 0.87 3
# ELASTIC 0.87 4
# ELASTIC 0.87 5
# ELASTIC 0.87 6
# ELASTIC 0.87 7
# ELASTIC 0.87 8
# ELASTIC 0.87 9
# 88 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.88 0
# ELASTIC 0.88 1
# PLASTIC 0.88 2
# ELASTIC 0.88 3
# ELASTIC 0.88 4
# ELASTIC 0.88 5
# ELASTIC 0.88 6
# ELASTIC 0.88 7
# ELASTIC 0.88 8
# ELASTIC 0.88 9
# NEWT
# ELASTIC 0.88 0
# PLASTIC 0.88 1
# PLASTIC 0.88 2
# PLASTIC 0.88 3
# ELASTIC 0.88 4
# ELASTIC 0.88 5
# ELASTIC 0.88 6
# ELASTIC 0.88 7
# ELASTIC 0.88 8
# ELASTIC 0.88 9
# NEWT
# ELASTIC 0.88 0
# PLASTIC 0.88 1
# PLASTIC 0.88 2
# PLASTIC 0.88 3
# ELASTIC 0.88 4
# ELASTIC 0.88 5
# ELASTIC 0.88 6
# ELASTIC 0.88 7
# ELASTIC 0.88 8
# ELASTIC 0.88 9
# 89 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.89 0
# ELASTIC 0.89 1
# PLASTIC 0.89 2
# ELASTIC 0.89 3
# ELASTIC 0.89 4
# ELASTIC 0.89 5
# ELASTIC 0.89 6
# ELASTIC 0.89 7
# ELASTIC 0.89 8
# ELASTIC 0.89 9
# NEWT
# ELASTIC 0.89 0
# PLASTIC 0.89 1
# PLASTIC 0.89 2
# PLASTIC 0.89 3
# ELASTIC 0.89 4
# ELASTIC 0.89 5
# ELASTIC 0.89 6
# ELASTIC 0.89 7
# ELASTIC 0.89 8
# ELASTIC 0.89 9
# NEWT
# ELASTIC 0.89 0
# PLASTIC 0.89 1
# PLASTIC 0.89 2
# PLASTIC 0.89 3
# ELASTIC 0.89 4
# ELASTIC 0.89 5
# ELASTIC 0.89 6
# ELASTIC 0.89 7
# ELASTIC 0.89 8
# ELASTIC 0.89 9
# 90 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.9 0
# ELASTIC 0.9 1
# PLASTIC 0.9 2
# ELASTIC 0.9 3
# ELASTIC 0.9 4
# ELASTIC 0.9 5
# ELASTIC 0.9 6
# ELASTIC 0.9 7
# ELASTIC 0.9 8
# ELASTIC 0.9 9
# NEWT
# ELASTIC 0.9 0
# PLASTIC 0.9 1
# PLASTIC 0.9 2
# PLASTIC 0.9 3
# ELASTIC 0.9 4
# ELASTIC 0.9 5
# ELASTIC 0.9 6
# ELASTIC 0.9 7
# ELASTIC 0.9 8
# ELASTIC 0.9 9
# NEWT
# ELASTIC 0.9 0
# PLASTIC 0.9 1
# PLASTIC 0.9 2
# PLASTIC 0.9 3
# ELASTIC 0.9 4
# ELASTIC 0.9 5
# ELASTIC 0.9 6
# ELASTIC 0.9 7
# ELASTIC 0.9 8
# ELASTIC 0.9 9
# 91 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.91 0
# ELASTIC 0.91 1
# PLASTIC 0.91 2
# ELASTIC 0.91 3
# ELASTIC 0.91 4
# ELASTIC 0.91 5
# ELASTIC 0.91 6
# ELASTIC 0.91 7
# ELASTIC 0.91 8
# ELASTIC 0.91 9
# NEWT
# ELASTIC 0.91 0
# PLASTIC 0.91 1
# PLASTIC 0.91 2
# PLASTIC 0.91 3
# ELASTIC 0.91 4
# ELASTIC 0.91 5
# ELASTIC 0.91 6
# ELASTIC 0.91 7
# ELASTIC 0.91 8
# ELASTIC 0.91 9
# NEWT
# ELASTIC 0.91 0
# PLASTIC 0.91 1
# PLASTIC 0.91 2
# PLASTIC 0.91 3
# ELASTIC 0.91 4
# ELASTIC 0.91 5
# ELASTIC 0.91 6
# ELASTIC 0.91 7
# ELASTIC 0.91 8
# ELASTIC 0.91 9
# 92 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.92 0
# ELASTIC 0.92 1
# PLASTIC 0.92 2
# ELASTIC 0.92 3
# ELASTIC 0.92 4
# ELASTIC 0.92 5
# ELASTIC 0.92 6
# ELASTIC 0.92 7
# ELASTIC 0.92 8
# ELASTIC 0.92 9
# NEWT
# ELASTIC 0.92 0
# PLASTIC 0.92 1
# PLASTIC 0.92 2
# PLASTIC 0.92 3
# ELASTIC 0.92 4
# ELASTIC 0.92 5
# ELASTIC 0.92 6
# ELASTIC 0.92 7
# ELASTIC 0.92 8
# ELASTIC 0.92 9
# NEWT
# ELASTIC 0.92 0
# PLASTIC 0.92 1
# PLASTIC 0.92 2
# PLASTIC 0.92 3
# ELASTIC 0.92 4
# ELASTIC 0.92 5
# ELASTIC 0.92 6
# ELASTIC 0.92 7
# ELASTIC 0.92 8
# ELASTIC 0.92 9
# 93 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.93 0
# ELASTIC 0.93 1
# PLASTIC 0.93 2
# ELASTIC 0.93 3
# ELASTIC 0.93 4
# ELASTIC 0.93 5
# ELASTIC 0.93 6
# ELASTIC 0.93 7
# ELASTIC 0.93 8
# ELASTIC 0.93 9
# NEWT
# ELASTIC 0.93 0
# PLASTIC 0.93 1
# PLASTIC 0.93 2
# PLASTIC 0.93 3
# ELASTIC 0.93 4
# ELASTIC 0.93 5
# ELASTIC 0.93 6
# ELASTIC 0.93 7
# ELASTIC 0.93 8
# ELASTIC 0.93 9
# NEWT
# ELASTIC 0.93 0
# PLASTIC 0.93 1
# PLASTIC 0.93 2
# PLASTIC 0.93 3
# ELASTIC 0.93 4
# ELASTIC 0.93 5
# ELASTIC 0.93 6
# ELASTIC 0.93 7
# ELASTIC 0.93 8
# ELASTIC 0.93 9
# 94 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.9400000000000001 0
# ELASTIC 0.9400000000000001 1
# PLASTIC 0.9400000000000001 2
# ELASTIC 0.9400000000000001 3
# ELASTIC 0.9400000000000001 4
# ELASTIC 0.9400000000000001 5
# ELASTIC 0.9400000000000001 6
# ELASTIC 0.9400000000000001 7
# ELASTIC 0.9400000000000001 8
# ELASTIC 0.9400000000000001 9
# NEWT
# ELASTIC 0.9400000000000001 0
# PLASTIC 0.9400000000000001 1
# PLASTIC 0.9400000000000001 2
# PLASTIC 0.9400000000000001 3
# ELASTIC 0.9400000000000001 4
# ELASTIC 0.9400000000000001 5
# ELASTIC 0.9400000000000001 6
# ELASTIC 0.9400000000000001 7
# ELASTIC 0.9400000000000001 8
# ELASTIC 0.9400000000000001 9
# NEWT
# ELASTIC 0.9400000000000001 0
# PLASTIC 0.9400000000000001 1
# PLASTIC 0.9400000000000001 2
# PLASTIC 0.9400000000000001 3
# ELASTIC 0.9400000000000001 4
# ELASTIC 0.9400000000000001 5
# ELASTIC 0.9400000000000001 6
# ELASTIC 0.9400000000000001 7
# ELASTIC 0.9400000000000001 8
# ELASTIC 0.9400000000000001 9
# 95 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.9500000000000001 0
# ELASTIC 0.9500000000000001 1
# PLASTIC 0.9500000000000001 2
# ELASTIC 0.9500000000000001 3
# ELASTIC 0.9500000000000001 4
# ELASTIC 0.9500000000000001 5
# ELASTIC 0.9500000000000001 6
# ELASTIC 0.9500000000000001 7
# ELASTIC 0.9500000000000001 8
# ELASTIC 0.9500000000000001 9
# NEWT
# ELASTIC 0.9500000000000001 0
# PLASTIC 0.9500000000000001 1
# PLASTIC 0.9500000000000001 2
# PLASTIC 0.9500000000000001 3
# ELASTIC 0.9500000000000001 4
# ELASTIC 0.9500000000000001 5
# ELASTIC 0.9500000000000001 6
# ELASTIC 0.9500000000000001 7
# ELASTIC 0.9500000000000001 8
# ELASTIC 0.9500000000000001 9
# NEWT
# ELASTIC 0.9500000000000001 0
# PLASTIC 0.9500000000000001 1
# PLASTIC 0.9500000000000001 2
# PLASTIC 0.9500000000000001 3
# ELASTIC 0.9500000000000001 4
# ELASTIC 0.9500000000000001 5
# ELASTIC 0.9500000000000001 6
# ELASTIC 0.9500000000000001 7
# ELASTIC 0.9500000000000001 8
# ELASTIC 0.9500000000000001 9
# 96 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.9600000000000001 0
# ELASTIC 0.9600000000000001 1
# PLASTIC 0.9600000000000001 2
# ELASTIC 0.9600000000000001 3
# ELASTIC 0.9600000000000001 4
# ELASTIC 0.9600000000000001 5
# ELASTIC 0.9600000000000001 6
# ELASTIC 0.9600000000000001 7
# ELASTIC 0.9600000000000001 8
# ELASTIC 0.9600000000000001 9
# NEWT
# ELASTIC 0.9600000000000001 0
# PLASTIC 0.9600000000000001 1
# PLASTIC 0.9600000000000001 2
# PLASTIC 0.9600000000000001 3
# ELASTIC 0.9600000000000001 4
# ELASTIC 0.9600000000000001 5
# ELASTIC 0.9600000000000001 6
# ELASTIC 0.9600000000000001 7
# ELASTIC 0.9600000000000001 8
# ELASTIC 0.9600000000000001 9
# NEWT
# ELASTIC 0.9600000000000001 0
# PLASTIC 0.9600000000000001 1
# PLASTIC 0.9600000000000001 2
# PLASTIC 0.9600000000000001 3
# ELASTIC 0.9600000000000001 4
# ELASTIC 0.9600000000000001 5
# ELASTIC 0.9600000000000001 6
# ELASTIC 0.9600000000000001 7
# ELASTIC 0.9600000000000001 8
# ELASTIC 0.9600000000000001 9
# 97 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.97 0
# ELASTIC 0.97 1
# PLASTIC 0.97 2
# ELASTIC 0.97 3
# ELASTIC 0.97 4
# ELASTIC 0.97 5
# ELASTIC 0.97 6
# ELASTIC 0.97 7
# ELASTIC 0.97 8
# ELASTIC 0.97 9
# NEWT
# ELASTIC 0.97 0
# PLASTIC 0.97 1
# PLASTIC 0.97 2
# PLASTIC 0.97 3
# PLASTIC 0.97 4
# ELASTIC 0.97 5
# ELASTIC 0.97 6
# ELASTIC 0.97 7
# ELASTIC 0.97 8
# ELASTIC 0.97 9
# NEWT
# ELASTIC 0.97 0
# PLASTIC 0.97 1
# PLASTIC 0.97 2
# PLASTIC 0.97 3
# PLASTIC 0.97 4
# ELASTIC 0.97 5
# ELASTIC 0.97 6
# ELASTIC 0.97 7
# ELASTIC 0.97 8
# ELASTIC 0.97 9
# 98 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.98 0
# ELASTIC 0.98 1
# PLASTIC 0.98 2
# ELASTIC 0.98 3
# ELASTIC 0.98 4
# ELASTIC 0.98 5
# ELASTIC 0.98 6
# ELASTIC 0.98 7
# ELASTIC 0.98 8
# ELASTIC 0.98 9
# NEWT
# ELASTIC 0.98 0
# PLASTIC 0.98 1
# PLASTIC 0.98 2
# PLASTIC 0.98 3
# PLASTIC 0.98 4
# ELASTIC 0.98 5
# ELASTIC 0.98 6
# ELASTIC 0.98 7
# ELASTIC 0.98 8
# ELASTIC 0.98 9
# NEWT
# ELASTIC 0.98 0
# PLASTIC 0.98 1
# PLASTIC 0.98 2
# PLASTIC 0.98 3
# PLASTIC 0.98 4
# ELASTIC 0.98 5
# ELASTIC 0.98 6
# ELASTIC 0.98 7
# ELASTIC 0.98 8
# ELASTIC 0.98 9
# 99 ----------------------------------------------------------------------------------------------------
# NEWT
# PLASTIC 0.99 0
# ELASTIC 0.99 1
# PLASTIC 0.99 2
# ELASTIC 0.99 3
# ELASTIC 0.99 4
# ELASTIC 0.99 5
# ELASTIC 0.99 6
# ELASTIC 0.99 7
# ELASTIC 0.99 8
# ELASTIC 0.99 9
# NEWT
# ELASTIC 0.99 0
# PLASTIC 0.99 1
# PLASTIC 0.99 2
# PLASTIC 0.99 3
# PLASTIC 0.99 4
# ELASTIC 0.99 5
# ELASTIC 0.99 6
# ELASTIC 0.99 7
# ELASTIC 0.99 8
# ELASTIC 0.99 9
# NEWT
# ELASTIC 0.99 0
# PLASTIC 0.99 1
# PLASTIC 0.99 2
# PLASTIC 0.99 3
# PLASTIC 0.99 4
# ELASTIC 0.99 5
# ELASTIC 0.99 6
# ELASTIC 0.99 7
# ELASTIC 0.99 8
# ELASTIC 0.99 9
# [-1.44530609e-04 -8.11104451e-05 -3.11363276e-05  2.10189171e-05
#   7.60578051e-05  5.58548861e-05  4.00523858e-05  2.96026995e-05
#   2.28128006e-05  1.84696808e-05  0.00000000e+00]
